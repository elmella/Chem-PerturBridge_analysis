# %% [markdown]
# # Overlap Group-Rep Signature Similarity
#
# This notebook starts from the overlap-filtered `.h5ad` files produced by `scripts/build_overlap_filtered_h5ads.py` to determine the retained lines and matched grouped-replicate samples, then loads the corresponding per-line DE files from the source result directories.
#
# For each dataset pair, it reconstructs matches using the same rule as the overlap script / heatmap notebook:
#
# - same `pubchem_cid`
# - same `cell_type`
# - same `pert_time_h`
# - mutual nearest neighbors in `log10(pert_dose_uM)`
# - `|Δ log10 dose| <= 1`
# - a `cell_type + pert_time_h` context is included for a dataset pair only if that pair shares at least `10` matched drugs in that context
#
# For every matched grouped-replicate sample pair, the notebook computes:
#
# - signed Spearman correlation across genes on `logFC`
# - signed Spearman correlation across genes on `t`
# - signed overlap@50 on `t`, using the top 50 and bottom 50 genes
#
# All signature metrics are computed twice:
#
# - on the usual pairwise shared gene set for that dataset pair / line comparison
# - on the line-specific multi-dataset gene set for that `cell_type`, defined as the genes shared across all active datasets that retain that line, exposed via `*_global` columns in the saved tables
#
# It also computes a baseline for each matched sample: the average signature across other non-control compounds from the same dataset, line, dose, and time. Baseline metrics are evaluated on the same gene space as the corresponding observed metric, both for the pairwise shared-gene evaluation and for the line-specific multi-dataset shared-gene evaluation.
#
# For summary tables, matched sample pairs are first averaged within each `pubchem_cid + cell_type + pert_time_h` case across all matched doses, then those drug-line-time cases are averaged to get the dataset-pair and dataset-pair-line summaries.
#
# Outputs are written to `results/overlap_signature_similarity_group_rep/`.

# %%
import os

# Use every configured dataset.
os.environ.pop("CPB_DATASET_SUBSET", None)

# Keep production results separate from smoke-test outputs.
os.environ["CPB_RUN_TAG"] = "full_production"

# Use the complete dataset populations for W4 standardization.
os.environ.pop("CPB_W4_SMOKE_COMPARISON_POPULATION", None)

# Wait for the W4 precomputation if it is still running.
os.environ["CPB_W4_PRECOMPUTE_MODE"] = "wait"

# Reuse valid saved outputs and checkpoints.
os.environ.pop("CPB_FORCE_RECOMPUTE", None)

print("Configured full production run with cache reuse.")
# Out:
# Configured full production run with cache reuse.

# %%
from __future__ import annotations

from collections import defaultdict
from dataclasses import dataclass, field
from pathlib import Path
from typing import Optional
import itertools
import os

import anndata as ad
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from IPython.display import display
from scipy.stats import rankdata


sns.set_theme(style="whitegrid")

# %%
# Set this to a list such as ["tahoe", "sciplex"] for an isolated test run.
# Leave it as None for the production dataset set and production output directory.
DATASET_SUBSET_ENV = os.environ.get("CPB_DATASET_SUBSET", "").strip()
TEST_DATASET_SUBSET = (
    None
    if not DATASET_SUBSET_ENV
    else [value.strip() for value in DATASET_SUBSET_ENV.split(",") if value.strip()]
)

def find_repo_root(start=None) -> Path:
    start = (start or Path.cwd()).resolve()
    for candidate in [start, *start.parents]:
        if (candidate / "results" / "overlap_filtered_h5ads").exists():
            return candidate
    raise FileNotFoundError("Could not locate the repository root from the current working directory.")


REPO_ROOT = find_repo_root()
import sys
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))
import scripts.cross_source_core as cross_source_core

ANALYSIS_PROFILE = "signature"
PRODUCTION_DATASET_ORDER = cross_source_core.production_dataset_order(ANALYSIS_PROFILE)
DATASET_ORDER = cross_source_core.selected_dataset_order(ANALYSIS_PROFILE, TEST_DATASET_SUBSET)
DISPLAY_LABELS = dict(cross_source_core.DISPLAY_LABELS)
MATCH_SETTINGS = cross_source_core.DEFAULT_MATCH_SETTINGS
MAX_LOG10_DOSE_DIFF = MATCH_SETTINGS.max_log10_dose_diff
MIN_CONTEXT_SHARED_DRUGS = MATCH_SETTINGS.min_context_shared_drugs
TOP_K = cross_source_core.TOP_K
NUMERIC_SIG_FIGS = cross_source_core.NUMERIC_SIG_FIGS
INVALID_STRING_VALUES = cross_source_core.INVALID_STRING_VALUES
DATA_ROOT = REPO_ROOT / "data" / "theislab_temp"
SOURCE_DATASET_DIRS = cross_source_core.source_dataset_dirs(DATA_ROOT, ANALYSIS_PROFILE)
OVERLAP_DIR = REPO_ROOT / "results" / "overlap_filtered_h5ads"
PRODUCTION_OUTPUT_DIR = REPO_ROOT / "results" / "overlap_signature_similarity_group_rep"
RUN_TAG = os.environ.get("CPB_RUN_TAG", "").strip()
OUTPUT_DIR = cross_source_core.analysis_output_dir(
    PRODUCTION_OUTPUT_DIR,
    dataset_subset=TEST_DATASET_SUBSET,
    dataset_names=DATASET_ORDER,
    run_tag=RUN_TAG,
)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

print(f"Repository root: {REPO_ROOT}")
print(f"Overlap directory: {OVERLAP_DIR}")
print(f"Datasets selected: {', '.join(DATASET_ORDER)}")
print(f"Output directory: {OUTPUT_DIR}")

# --- Resumability -----------------------------------------------------------------
# Expensive stages below go through cached_frame: if the stage's output TSV already
# exists it is reloaded instead of recomputed, so this notebook can be restarted after
# a crash without redoing the work above the failure.
#
#   force_recompute("peer_baselines")   # rebuild one stage
#   CPB_FORCE_RECOMPUTE=all jupyter lab # ignore every cache
# Deleting a stage's TSV has the same effect as naming it.
# Stages here: matched_pairs, signature_metrics, signature_ci, peer_baselines, peer_ci,
# w4_signature_metrics, and w4_signature_ci.
import sys

if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

from scripts.cross_source_strata import SignatureStratum
from scripts.notebook_cache import (
    ProgressReporter,
    cache_summary,
    cached_frame,
    force_recompute,
    frame_identity_fingerprint,
    is_cached,
    stable_json_fingerprint,
)
# Out:
# Repository root: /home/cirro/Chem-PerturBridge_analysis
# Overlap directory: /home/cirro/Chem-PerturBridge_analysis/results/overlap_filtered_h5ads
# Datasets selected: l1000_phase1, l1000_phase2, tahoe, cigs_mce, novartis_batch_2500, vcpi_0001, cigs_tcm, vcpi_0002, sciplex, op3
# Output directory: /home/cirro/Chem-PerturBridge_analysis/results/production_runs/overlap_signature_similarity_group_rep/full_production

# %%
# Shared cross-source utilities.
pretty_label = cross_source_core.pretty_label
format_numeric = cross_source_core.format_numeric

# %%
# One shared source catalog owns backed H5AD handles and gene-position caches.
SOURCE_CATALOG = cross_source_core.LineSourceCatalog(SOURCE_DATASET_DIRS)
LineSource = cross_source_core.LineSource
resolve_line_path = SOURCE_CATALOG.resolve_line_path
get_line_source = SOURCE_CATALOG.get_line_source
shared_gene_positions = SOURCE_CATALOG.shared_gene_positions
set_global_shared_gene_keys = SOURCE_CATALOG.set_global_shared_gene_keys
global_gene_positions = SOURCE_CATALOG.global_gene_positions
close_all_line_sources = SOURCE_CATALOG.close

# Compatibility aliases used by the metric-specific cells below.
filter_finite_pair = cross_source_core.filter_finite_pair
signed_spearman = cross_source_core.signed_spearman
signed_overlap_at_k = cross_source_core.signed_overlap_at_k
score_signature_pair = cross_source_core.score_signature_pair
mean_available = cross_source_core.mean_available
empty_score_dict = cross_source_core.empty_score_dict


# Table 6 signature-specific record construction.
def compute_metric_record(match_row: pd.Series) -> dict[str, object]:
    left_source = get_line_source(str(match_row["dataset_a"]), str(match_row["cell_type"]))
    right_source = get_line_source(str(match_row["dataset_b"]), str(match_row["cell_type"]))
    shared_genes, left_gene_pos, right_gene_pos = shared_gene_positions(left_source, right_source)
    if shared_genes.size < 2:
        raise ValueError(
            f"Fewer than two shared genes for {match_row['dataset_a']} vs {match_row['dataset_b']} / {match_row['cell_type']}"
        )

    global_shared_genes, left_global_gene_pos = global_gene_positions(left_source)
    _, right_global_gene_pos = global_gene_positions(right_source)

    left_obs_id = str(match_row["left_obs_id"])
    right_obs_id = str(match_row["right_obs_id"])
    pubchem_cid = str(match_row["pubchem_cid"])
    time_key = str(match_row["time_key"])

    left_lookup = {
        "pubchem_cid": pubchem_cid,
        "dose_key": str(match_row["left_dose_key"]),
        "time_key": time_key,
    }
    right_lookup = {
        "pubchem_cid": pubchem_cid,
        "dose_key": str(match_row["right_dose_key"]),
        "time_key": time_key,
    }

    left_logfc_full = left_source.get_vector(left_obs_id, "logFC", **left_lookup)
    right_logfc_full = right_source.get_vector(right_obs_id, "logFC", **right_lookup)
    left_t_full = left_source.get_vector(left_obs_id, "t", **left_lookup)
    right_t_full = right_source.get_vector(right_obs_id, "t", **right_lookup)

    observed_scores = score_signature_pair(
        left_logfc=left_logfc_full[left_gene_pos],
        right_logfc=right_logfc_full[right_gene_pos],
        left_t=left_t_full[left_gene_pos],
        right_t=right_t_full[right_gene_pos],
    )

    observed_scores_global = empty_score_dict()
    if global_shared_genes.size >= 2:
        observed_scores_global = score_signature_pair(
            left_logfc=left_logfc_full[left_global_gene_pos],
            right_logfc=right_logfc_full[right_global_gene_pos],
            left_t=left_t_full[left_global_gene_pos],
            right_t=right_t_full[right_global_gene_pos],
        )

    left_mean_abs_t = mean_available(np.abs(left_t_full[left_gene_pos]).tolist())
    right_mean_abs_t = mean_available(np.abs(right_t_full[right_gene_pos]).tolist())
    pair_mean_abs_t = mean_available([left_mean_abs_t, right_mean_abs_t])

    left_mean_abs_t_global = float("nan")
    right_mean_abs_t_global = float("nan")
    pair_mean_abs_t_global = float("nan")
    if global_shared_genes.size >= 2:
        left_mean_abs_t_global = mean_available(np.abs(left_t_full[left_global_gene_pos]).tolist())
        right_mean_abs_t_global = mean_available(np.abs(right_t_full[right_global_gene_pos]).tolist())
        pair_mean_abs_t_global = mean_available([left_mean_abs_t_global, right_mean_abs_t_global])

    left_baseline_logfc_full = left_source.get_baseline_vector(left_obs_id, "logFC", **left_lookup)
    left_baseline_t_full = left_source.get_baseline_vector(left_obs_id, "t", **left_lookup)
    right_baseline_logfc_full = right_source.get_baseline_vector(right_obs_id, "logFC", **right_lookup)
    right_baseline_t_full = right_source.get_baseline_vector(right_obs_id, "t", **right_lookup)

    left_baseline_scores = empty_score_dict()
    left_baseline_scores_global = empty_score_dict()
    if left_baseline_logfc_full is not None and left_baseline_t_full is not None:
        left_baseline_scores = score_signature_pair(
            left_logfc=left_logfc_full[left_gene_pos],
            right_logfc=left_baseline_logfc_full[left_gene_pos],
            left_t=left_t_full[left_gene_pos],
            right_t=left_baseline_t_full[left_gene_pos],
        )
        if global_shared_genes.size >= 2:
            left_baseline_scores_global = score_signature_pair(
                left_logfc=left_logfc_full[left_global_gene_pos],
                right_logfc=left_baseline_logfc_full[left_global_gene_pos],
                left_t=left_t_full[left_global_gene_pos],
                right_t=left_baseline_t_full[left_global_gene_pos],
            )

    right_baseline_scores = empty_score_dict()
    right_baseline_scores_global = empty_score_dict()
    if right_baseline_logfc_full is not None and right_baseline_t_full is not None:
        right_baseline_scores = score_signature_pair(
            left_logfc=right_logfc_full[right_gene_pos],
            right_logfc=right_baseline_logfc_full[right_gene_pos],
            left_t=right_t_full[right_gene_pos],
            right_t=right_baseline_t_full[right_gene_pos],
        )
        if global_shared_genes.size >= 2:
            right_baseline_scores_global = score_signature_pair(
                left_logfc=right_logfc_full[right_global_gene_pos],
                right_logfc=right_baseline_logfc_full[right_global_gene_pos],
                left_t=right_t_full[right_global_gene_pos],
                right_t=right_baseline_t_full[right_global_gene_pos],
            )

    overlap_column = f"signed_overlap_t_top{TOP_K}"
    return {
        **match_row.to_dict(),
        "n_common_genes": int(shared_genes.size),
        "n_global_common_genes": int(global_shared_genes.size),
        "left_mean_abs_t": left_mean_abs_t,
        "right_mean_abs_t": right_mean_abs_t,
        "pair_mean_abs_t": pair_mean_abs_t,
        "left_mean_abs_t_global": left_mean_abs_t_global,
        "right_mean_abs_t_global": right_mean_abs_t_global,
        "pair_mean_abs_t_global": pair_mean_abs_t_global,
        "observed_spearman_logfc": observed_scores["spearman_logfc"],
        "observed_spearman_logfc_global": observed_scores_global["spearman_logfc"],
        "observed_spearman_t": observed_scores["spearman_t"],
        "observed_spearman_t_global": observed_scores_global["spearman_t"],
        f"observed_{overlap_column}": observed_scores[overlap_column],
        f"observed_{overlap_column}_global": observed_scores_global[overlap_column],
        "left_baseline_peer_count": left_source.baseline_peer_count(left_obs_id, **left_lookup),
        "left_baseline_spearman_logfc": left_baseline_scores["spearman_logfc"],
        "left_baseline_spearman_logfc_global": left_baseline_scores_global["spearman_logfc"],
        "left_baseline_spearman_t": left_baseline_scores["spearman_t"],
        "left_baseline_spearman_t_global": left_baseline_scores_global["spearman_t"],
        f"left_baseline_{overlap_column}": left_baseline_scores[overlap_column],
        f"left_baseline_{overlap_column}_global": left_baseline_scores_global[overlap_column],
        "right_baseline_peer_count": right_source.baseline_peer_count(right_obs_id, **right_lookup),
        "right_baseline_spearman_logfc": right_baseline_scores["spearman_logfc"],
        "right_baseline_spearman_logfc_global": right_baseline_scores_global["spearman_logfc"],
        "right_baseline_spearman_t": right_baseline_scores["spearman_t"],
        "right_baseline_spearman_t_global": right_baseline_scores_global["spearman_t"],
        f"right_baseline_{overlap_column}": right_baseline_scores[overlap_column],
        f"right_baseline_{overlap_column}_global": right_baseline_scores_global[overlap_column],
        "baseline_pair_mean_spearman_logfc": mean_available(
            [left_baseline_scores["spearman_logfc"], right_baseline_scores["spearman_logfc"]]
        ),
        "baseline_pair_mean_spearman_logfc_global": mean_available(
            [left_baseline_scores_global["spearman_logfc"], right_baseline_scores_global["spearman_logfc"]]
        ),
        "baseline_pair_mean_spearman_t": mean_available(
            [left_baseline_scores["spearman_t"], right_baseline_scores["spearman_t"]]
        ),
        "baseline_pair_mean_spearman_t_global": mean_available(
            [left_baseline_scores_global["spearman_t"], right_baseline_scores_global["spearman_t"]]
        ),
        f"baseline_pair_mean_{overlap_column}": mean_available(
            [left_baseline_scores[overlap_column], right_baseline_scores[overlap_column]]
        ),
        f"baseline_pair_mean_{overlap_column}_global": mean_available(
            [left_baseline_scores_global[overlap_column], right_baseline_scores_global[overlap_column]]
        ),
    }

# %%
cross_source_scope = cross_source_core.prepare_cross_source_scope(
    dataset_order=DATASET_ORDER,
    overlap_dir=OVERLAP_DIR,
    output_dir=OUTPUT_DIR,
    source_catalog=SOURCE_CATALOG,
    settings=MATCH_SETTINGS,
)
dataset_indices = cross_source_scope.dataset_indices
active_datasets = cross_source_scope.active_datasets
retained_lines = cross_source_scope.retained_lines
matched_pairs = cross_source_scope.matched_pairs
MATCHED_PAIRS_FINGERPRINT = cross_source_scope.matched_pairs_fingerprint
matched_lines = cross_source_scope.matched_lines
matched_active_datasets = cross_source_scope.matched_active_datasets
global_gene_lines = cross_source_scope.global_gene_lines
line_global_gene_keys = cross_source_scope.line_global_gene_keys
pair_match_summary = cross_source_scope.pair_match_summary
line_match_summary = cross_source_scope.line_match_summary

print("Datasets in scope:", ", ".join(
    pretty_label(dataset_name) for dataset_name in active_datasets
))
retained_lines_display = pd.DataFrame(
    {
        "dataset": [pretty_label(name) for name in retained_lines],
        "cell_types": [", ".join(lines) for lines in retained_lines.values()],
    }
)
display(retained_lines_display)

line_global_gene_counts = {
    cell_type: int(gene_keys.size)
    for cell_type, gene_keys in line_global_gene_keys.items()
}
n_opened_gene_sources = sum(len(lines) for lines in global_gene_lines.values())
n_available_gene_sources = sum(len(lines) for lines in retained_lines.values())
print(
    f"Line-specific shared-gene sets computed for {len(line_global_gene_counts):,} "
    f"matched cell types using {n_opened_gene_sources:,}/{n_available_gene_sources:,} "
    "available line sources."
)
if not line_global_gene_counts or max(line_global_gene_counts.values()) < 2:
    print(
        "Line-specific shared-gene evaluation will be unavailable because no "
        "matched line has at least two genes shared across the datasets that retain it."
    )
else:
    print(
        "Line-specific shared-gene count range across matched lines: "
        f"{min(line_global_gene_counts.values()):,} to "
        f"{max(line_global_gene_counts.values()):,}"
    )

pair_match_summary_display = pair_match_summary.copy()
pair_match_summary_display["dataset_a"] = pair_match_summary_display["dataset_a"].map(pretty_label)
pair_match_summary_display["dataset_b"] = pair_match_summary_display["dataset_b"].map(pretty_label)
display(pair_match_summary_display)

line_match_summary_display = line_match_summary.copy()
line_match_summary_display["dataset_a"] = line_match_summary_display["dataset_a"].map(pretty_label)
line_match_summary_display["dataset_b"] = line_match_summary_display["dataset_b"].map(pretty_label)
display(line_match_summary_display)
# Out:
# [matched_pairs] computed and saved 76,717 rows to matched_sample_pairs.tsv
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/cirro/Chem-PerturBridge_analysis/.venv/lib/python3.9/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# Datasets in scope: L1000 Phase I, L1000 Phase II, Tahoe-100M, CIGS-MCE, CIGS-TCM, sci-Plex
#           dataset                                         cell_types
# 0   L1000 Phase I  CVCL_0023, CVCL_0027, CVCL_0031, CVCL_0033, CV...
# 1  L1000 Phase II  CVCL_0023, CVCL_0027, CVCL_0031, CVCL_0033, CV...
# 2      Tahoe-100M                    CVCL_0023, CVCL_0320, CVCL_0332
# 3        CIGS-MCE                               CVCL_0062, CVCL_0063
# 4        CIGS-TCM                               CVCL_0062, CVCL_0063
# 5        sci-Plex                               CVCL_0023, CVCL_0031
# Line-specific shared-gene sets computed for 16 matched cell types using 40/42 available line sources.
# Line-specific shared-gene count range across matched lines: 599 to 978
#         dataset_a       dataset_b  n_matched_sample_pairs  n_matching_drugs  \
# 0        CIGS-MCE        CIGS-TCM                   15973               974
# 1   L1000 Phase I        CIGS-MCE                    1401               124
# 2   L1000 Phase I  L1000 Phase II                   50695               257
# 3   L1000 Phase I        sci-Plex                    2695                90
# 4   L1000 Phase I      Tahoe-100M                     610                86
# 5  L1000 Phase II        CIGS-MCE                     508                68
# 6  L1000 Phase II        sci-Plex                    3192                83
# 7  L1000 Phase II      Tahoe-100M                    1473               110
# 8      Tahoe-100M        sci-Plex                     170                23
#
#    n_matching_lines  n_matching_conditions
# 0                 2                   1911
# 1                 2                    127
# 2                15                   2836
# 3                 2                    291
# 4                 3                    152
# 5                 1                     68
# 6                 2                    381
# 7                 2                    402
# 8                 1                     69
#          dataset_a       dataset_b  cell_type  n_matched_sample_pairs  \
# 0         CIGS-MCE        CIGS-TCM  CVCL_0062                    7842
# 1         CIGS-MCE        CIGS-TCM  CVCL_0063                    8131
# 2    L1000 Phase I        CIGS-MCE  CVCL_0062                    1047
# 3    L1000 Phase I        CIGS-MCE  CVCL_0063                     354
# 4    L1000 Phase I  L1000 Phase II  CVCL_0023                    8049
# 5    L1000 Phase I  L1000 Phase II  CVCL_0031                   11741
# 6    L1000 Phase I  L1000 Phase II  CVCL_0033                    3143
# 7    L1000 Phase I  L1000 Phase II  CVCL_0035                    6722
# 8    L1000 Phase I  L1000 Phase II  CVCL_0062                    3739
# 9    L1000 Phase I  L1000 Phase II  CVCL_0132                    3121
# 10   L1000 Phase I  L1000 Phase II  CVCL_0178                    2670
# 11   L1000 Phase I  L1000 Phase II  CVCL_0320                    1824
# 12   L1000 Phase I  L1000 Phase II  CVCL_0332                    2220
# 13   L1000 Phase I  L1000 Phase II  CVCL_0598                    2348
# 14   L1000 Phase I  L1000 Phase II  CVCL_5136                    1014
# 15   L1000 Phase I  L1000 Phase II  CVCL_U602                     763
# 16   L1000 Phase I  L1000 Phase II  CVCL_VU89                    1696
# 17   L1000 Phase I  L1000 Phase II        NEU                     617
# 18   L1000 Phase I  L1000 Phase II        NPC                    1028
# 19   L1000 Phase I        sci-Plex  CVCL_0023                     904
# 20   L1000 Phase I        sci-Plex  CVCL_0031                    1791
# 21   L1000 Phase I      Tahoe-100M  CVCL_0023                     402
# 22   L1000 Phase I      Tahoe-100M  CVCL_0320                      96
# 23   L1000 Phase I      Tahoe-100M  CVCL_0332                     112
# 24  L1000 Phase II        CIGS-MCE  CVCL_0062                     508
# 25  L1000 Phase II        sci-Plex  CVCL_0023                    1400
# 26  L1000 Phase II        sci-Plex  CVCL_0031                    1792
# 27  L1000 Phase II      Tahoe-100M  CVCL_0023                     389
# 28  L1000 Phase II      Tahoe-100M  CVCL_0320                    1084
# 29      Tahoe-100M        sci-Plex  CVCL_0023                     170
#
#     n_matching_drugs  n_matching_conditions
# 0                948                    948
# 1                963                    963
# 2                113                    113
# 3                 14                     14
# 4                152                    237
# 5                179                    615
# 6                 63                    247
# 7                118                    190
# 8                 94                    370
# 9                 43                    114
# 10                63                    251
# 11                34                     68
# 12                63                    251
# 13                63                    250
# 14                31                     61
# 15                34                     34
# 16                39                     74
# 17                33                     36
# 18                35                     38
# 19                75                    113
# 20                90                    178
# 21                83                     95
# 22                20                     24
# 23                11                     33
# 24                68                     68
# 25                44                    132
# 26                83                    249
# 27                24                     72
# 28               110                    330
# 29                23                     69

# %%
metric_records: list[dict[str, object]] = []
unresolved_records: list[dict[str, object]] = []
context_join_columns = [
    "dataset_a",
    "dataset_b",
    "cell_type",
    "time_key",
    "left_dose_key",
    "right_dose_key",
]
matched_pair_metrics_path = OUTPUT_DIR / "matched_sample_pair_metrics.tsv"
SIGNATURE_METRICS_FINGERPRINT = stable_json_fingerprint(
    {
        "version": "signature-metrics-v4-shared-core",
        "datasets": DATASET_ORDER,
        "matched_pairs": frame_identity_fingerprint(
            matched_pairs,
            cross_source_core.MATCH_PAIR_IDENTITY_COLUMNS,
        ),
        "top_k": TOP_K,
        "sources": cross_source_core.line_source_inventory(
            global_gene_lines,
            resolve_line_path,
        ),
    }
)
signature_metrics_is_cached = is_cached(
    "signature_metrics",
    matched_pair_metrics_path,
    fingerprint=SIGNATURE_METRICS_FINGERPRINT,
)
signature_progress = ProgressReporter(
    total=len(matched_pairs),
    label="signature_metrics",
    every=100,
    min_interval_seconds=20.0,
)
signature_metric_input = matched_pairs.iloc[0:0] if signature_metrics_is_cached else matched_pairs
for (dataset_a, dataset_b, cell_type, time_key, left_dose_key, right_dose_key), group in signature_metric_input.groupby(
    context_join_columns,
    sort=False,
):
    print(
        f"Scoring {pretty_label(dataset_a)} vs {pretty_label(dataset_b)} / {cell_type} / time={time_key} / doses={left_dose_key} vs {right_dose_key}: "
        f"{len(group)} matched sample pairs across {group['pubchem_cid'].nunique()} shared compounds"
    )
    for _, match_row in group.iterrows():
        try:
            metric_records.append(compute_metric_record(match_row))
        except KeyError as exc:
            unresolved_records.append(
                {
                    **match_row.to_dict(),
                    "error": str(exc),
                }
            )
        finally:
            signature_progress.update(
                detail=f"{pretty_label(dataset_a)} vs {pretty_label(dataset_b)} / {cell_type}"
            )

def build_signature_metrics() -> pd.DataFrame:
    matched_pair_metrics = pd.DataFrame(metric_records)
    return matched_pair_metrics


matched_pair_metrics = cached_frame(
    "signature_metrics",
    matched_pair_metrics_path,
    build_signature_metrics,
    fingerprint=SIGNATURE_METRICS_FINGERPRINT,
)
if matched_pair_metrics.empty:
    raise ValueError("No matched sample pairs could be resolved in the source line files.")

print(f"Scored {len(matched_pair_metrics):,} matched sample pairs")

unresolved_matches = pd.DataFrame(unresolved_records)
if unresolved_matches.empty:
    print("All matched sample pairs were resolved in the source line files.")
else:
    unresolved_matches_path = OUTPUT_DIR / "unresolved_matched_sample_pairs.tsv"
    unresolved_matches.to_csv(unresolved_matches_path, sep="	", index=False)
    print(
        f"Skipped {len(unresolved_matches):,} matched sample pairs with no corresponding grouped result in the source line files. "
        f"Saved details to {unresolved_matches_path}"
    )
    display(
        unresolved_matches.groupby(context_join_columns, as_index=False)
        .agg(n_unresolved=("error", "size"))
        .sort_values(context_join_columns)
        .reset_index(drop=True)
    )

matched_pair_metrics.head()
# Out:
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_0023 / time=24 / doses=10 vs 10: 5788 matched sample pairs across 128 shared compounds
# [signature_metrics] 100/76,717 (0.1%) | elapsed 00:02 | 57.42/s | ETA 22:14 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 200/76,717 (0.3%) | elapsed 00:03 | 61.65/s | ETA 20:41 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 300/76,717 (0.4%) | elapsed 00:05 | 63.41/s | ETA 20:05 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 400/76,717 (0.5%) | elapsed 00:06 | 64.54/s | ETA 19:43 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 500/76,717 (0.7%) | elapsed 00:08 | 65.52/s | ETA 19:23 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 600/76,717 (0.8%) | elapsed 00:09 | 66.52/s | ETA 19:04 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 700/76,717 (0.9%) | elapsed 00:10 | 67.48/s | ETA 18:47 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 800/76,717 (1.0%) | elapsed 00:12 | 68.01/s | ETA 18:36 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 900/76,717 (1.2%) | elapsed 00:13 | 68.55/s | ETA 18:26 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 1,000/76,717 (1.3%) | elapsed 00:15 | 68.90/s | ETA 18:19 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 1,100/76,717 (1.4%) | elapsed 00:16 | 69.19/s | ETA 18:13 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 1,200/76,717 (1.6%) | elapsed 00:17 | 69.26/s | ETA 18:10 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 1,300/76,717 (1.7%) | elapsed 00:19 | 69.01/s | ETA 18:13 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 1,400/76,717 (1.8%) | elapsed 00:20 | 68.86/s | ETA 18:14 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 1,500/76,717 (2.0%) | elapsed 00:22 | 68.62/s | ETA 18:16 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 1,600/76,717 (2.1%) | elapsed 00:23 | 68.50/s | ETA 18:17 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 1,700/76,717 (2.2%) | elapsed 00:25 | 68.60/s | ETA 18:14 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 1,800/76,717 (2.3%) | elapsed 00:26 | 68.74/s | ETA 18:10 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 1,900/76,717 (2.5%) | elapsed 00:28 | 68.81/s | ETA 18:07 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 2,000/76,717 (2.6%) | elapsed 00:29 | 68.78/s | ETA 18:06 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 2,100/76,717 (2.7%) | elapsed 00:31 | 68.70/s | ETA 18:06 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 2,200/76,717 (2.9%) | elapsed 00:32 | 68.64/s | ETA 18:06 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 2,300/76,717 (3.0%) | elapsed 00:33 | 68.75/s | ETA 18:02 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 2,400/76,717 (3.1%) | elapsed 00:35 | 68.92/s | ETA 17:58 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 2,500/76,717 (3.3%) | elapsed 00:36 | 69.08/s | ETA 17:54 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 2,600/76,717 (3.4%) | elapsed 00:38 | 69.22/s | ETA 17:51 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 2,700/76,717 (3.5%) | elapsed 00:39 | 69.34/s | ETA 17:47 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 2,800/76,717 (3.6%) | elapsed 00:40 | 69.44/s | ETA 17:44 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 2,900/76,717 (3.8%) | elapsed 00:42 | 69.60/s | ETA 17:41 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 3,000/76,717 (3.9%) | elapsed 00:43 | 69.68/s | ETA 17:38 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 3,100/76,717 (4.0%) | elapsed 00:44 | 69.82/s | ETA 17:34 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 3,200/76,717 (4.2%) | elapsed 00:46 | 69.90/s | ETA 17:32 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 3,300/76,717 (4.3%) | elapsed 00:47 | 70.02/s | ETA 17:29 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 3,400/76,717 (4.4%) | elapsed 00:49 | 70.08/s | ETA 17:26 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 3,500/76,717 (4.6%) | elapsed 00:50 | 70.18/s | ETA 17:23 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 3,600/76,717 (4.7%) | elapsed 00:51 | 70.25/s | ETA 17:21 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 3,700/76,717 (4.8%) | elapsed 00:53 | 70.31/s | ETA 17:18 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 3,800/76,717 (5.0%) | elapsed 00:54 | 70.38/s | ETA 17:16 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 3,900/76,717 (5.1%) | elapsed 00:55 | 70.45/s | ETA 17:14 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 4,000/76,717 (5.2%) | elapsed 00:57 | 70.51/s | ETA 17:11 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 4,100/76,717 (5.3%) | elapsed 00:58 | 70.56/s | ETA 17:09 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 4,200/76,717 (5.5%) | elapsed 00:59 | 70.62/s | ETA 17:07 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 4,300/76,717 (5.6%) | elapsed 01:01 | 70.67/s | ETA 17:05 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 4,400/76,717 (5.7%) | elapsed 01:02 | 70.73/s | ETA 17:02 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 4,500/76,717 (5.9%) | elapsed 01:04 | 70.78/s | ETA 17:00 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 4,600/76,717 (6.0%) | elapsed 01:05 | 70.82/s | ETA 16:58 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 4,700/76,717 (6.1%) | elapsed 01:06 | 70.75/s | ETA 16:58 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 4,800/76,717 (6.3%) | elapsed 01:08 | 70.80/s | ETA 16:56 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 4,900/76,717 (6.4%) | elapsed 01:09 | 70.77/s | ETA 16:55 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 5,000/76,717 (6.5%) | elapsed 01:11 | 70.71/s | ETA 16:54 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 5,100/76,717 (6.6%) | elapsed 01:12 | 70.66/s | ETA 16:54 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 5,200/76,717 (6.8%) | elapsed 01:14 | 70.61/s | ETA 16:53 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 5,300/76,717 (6.9%) | elapsed 01:15 | 70.61/s | ETA 16:51 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 5,400/76,717 (7.0%) | elapsed 01:17 | 70.56/s | ETA 16:51 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 5,500/76,717 (7.2%) | elapsed 01:18 | 70.57/s | ETA 16:49 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 5,600/76,717 (7.3%) | elapsed 01:19 | 70.56/s | ETA 16:48 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# [signature_metrics] 5,700/76,717 (7.4%) | elapsed 01:21 | 70.50/s | ETA 16:47 | L1000 Phase I vs L1000 Phase II / CVCL_0023
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_0031 / time=24 / doses=10 vs 10: 7803 matched sample pairs across 178 shared compounds
# [signature_metrics] 5,800/76,717 (7.6%) | elapsed 01:23 | 70.21/s | ETA 16:50 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 5,900/76,717 (7.7%) | elapsed 01:24 | 70.10/s | ETA 16:50 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 6,000/76,717 (7.8%) | elapsed 01:26 | 70.07/s | ETA 16:49 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 6,100/76,717 (8.0%) | elapsed 01:27 | 69.97/s | ETA 16:49 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 6,200/76,717 (8.1%) | elapsed 01:29 | 69.88/s | ETA 16:49 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 6,300/76,717 (8.2%) | elapsed 01:30 | 69.82/s | ETA 16:48 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 6,400/76,717 (8.3%) | elapsed 01:32 | 69.74/s | ETA 16:48 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 6,500/76,717 (8.5%) | elapsed 01:33 | 69.62/s | ETA 16:49 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 6,600/76,717 (8.6%) | elapsed 01:35 | 69.53/s | ETA 16:48 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 6,700/76,717 (8.7%) | elapsed 01:36 | 69.48/s | ETA 16:48 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 6,800/76,717 (8.9%) | elapsed 01:38 | 69.41/s | ETA 16:47 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 6,900/76,717 (9.0%) | elapsed 01:39 | 69.39/s | ETA 16:46 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 7,000/76,717 (9.1%) | elapsed 01:41 | 69.36/s | ETA 16:45 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 7,100/76,717 (9.3%) | elapsed 01:42 | 69.30/s | ETA 16:45 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 7,200/76,717 (9.4%) | elapsed 01:44 | 69.27/s | ETA 16:44 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 7,300/76,717 (9.5%) | elapsed 01:46 | 69.12/s | ETA 16:44 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 7,400/76,717 (9.6%) | elapsed 01:47 | 69.07/s | ETA 16:44 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 7,500/76,717 (9.8%) | elapsed 01:49 | 69.02/s | ETA 16:43 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 7,600/76,717 (9.9%) | elapsed 01:50 | 68.97/s | ETA 16:42 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 7,700/76,717 (10.0%) | elapsed 01:52 | 68.90/s | ETA 16:42 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 7,800/76,717 (10.2%) | elapsed 01:53 | 68.80/s | ETA 16:42 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 7,900/76,717 (10.3%) | elapsed 01:55 | 68.74/s | ETA 16:41 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 8,000/76,717 (10.4%) | elapsed 01:57 | 68.66/s | ETA 16:41 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 8,100/76,717 (10.6%) | elapsed 01:58 | 68.60/s | ETA 16:40 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 8,200/76,717 (10.7%) | elapsed 02:00 | 68.60/s | ETA 16:39 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 8,300/76,717 (10.8%) | elapsed 02:01 | 68.58/s | ETA 16:38 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 8,400/76,717 (10.9%) | elapsed 02:03 | 68.52/s | ETA 16:37 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 8,500/76,717 (11.1%) | elapsed 02:04 | 68.51/s | ETA 16:36 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 8,600/76,717 (11.2%) | elapsed 02:06 | 68.49/s | ETA 16:35 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 8,700/76,717 (11.3%) | elapsed 02:07 | 68.42/s | ETA 16:34 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 8,800/76,717 (11.5%) | elapsed 02:09 | 68.37/s | ETA 16:33 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 8,900/76,717 (11.6%) | elapsed 02:10 | 68.37/s | ETA 16:32 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 9,000/76,717 (11.7%) | elapsed 02:12 | 68.34/s | ETA 16:31 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 9,100/76,717 (11.9%) | elapsed 02:13 | 68.32/s | ETA 16:30 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 9,200/76,717 (12.0%) | elapsed 02:15 | 68.30/s | ETA 16:29 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 9,300/76,717 (12.1%) | elapsed 02:16 | 68.25/s | ETA 16:28 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 9,400/76,717 (12.3%) | elapsed 02:18 | 68.22/s | ETA 16:27 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 9,500/76,717 (12.4%) | elapsed 02:19 | 68.16/s | ETA 16:26 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 9,600/76,717 (12.5%) | elapsed 02:21 | 68.11/s | ETA 16:25 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 9,700/76,717 (12.6%) | elapsed 02:22 | 68.09/s | ETA 16:24 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 9,800/76,717 (12.8%) | elapsed 02:24 | 68.09/s | ETA 16:23 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 9,900/76,717 (12.9%) | elapsed 02:25 | 68.10/s | ETA 16:21 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 10,000/76,717 (13.0%) | elapsed 02:27 | 68.12/s | ETA 16:19 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 10,100/76,717 (13.2%) | elapsed 02:28 | 68.11/s | ETA 16:18 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 10,200/76,717 (13.3%) | elapsed 02:30 | 68.13/s | ETA 16:16 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 10,300/76,717 (13.4%) | elapsed 02:31 | 68.14/s | ETA 16:15 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 10,400/76,717 (13.6%) | elapsed 02:33 | 68.15/s | ETA 16:13 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 10,500/76,717 (13.7%) | elapsed 02:34 | 68.17/s | ETA 16:11 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 10,600/76,717 (13.8%) | elapsed 02:35 | 68.18/s | ETA 16:10 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 10,700/76,717 (13.9%) | elapsed 02:37 | 68.19/s | ETA 16:08 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 10,800/76,717 (14.1%) | elapsed 02:38 | 68.20/s | ETA 16:07 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 10,900/76,717 (14.2%) | elapsed 02:40 | 68.22/s | ETA 16:05 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 11,000/76,717 (14.3%) | elapsed 02:41 | 68.22/s | ETA 16:03 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 11,100/76,717 (14.5%) | elapsed 02:43 | 68.24/s | ETA 16:02 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 11,200/76,717 (14.6%) | elapsed 02:44 | 68.25/s | ETA 16:00 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 11,300/76,717 (14.7%) | elapsed 02:46 | 68.25/s | ETA 15:58 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 11,400/76,717 (14.9%) | elapsed 02:47 | 68.27/s | ETA 15:57 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 11,500/76,717 (15.0%) | elapsed 02:48 | 68.28/s | ETA 15:55 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 11,600/76,717 (15.1%) | elapsed 02:50 | 68.29/s | ETA 15:54 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 11,700/76,717 (15.3%) | elapsed 02:51 | 68.30/s | ETA 15:52 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 11,800/76,717 (15.4%) | elapsed 02:53 | 68.31/s | ETA 15:50 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 11,900/76,717 (15.5%) | elapsed 02:54 | 68.31/s | ETA 15:49 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 12,000/76,717 (15.6%) | elapsed 02:56 | 68.33/s | ETA 15:47 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 12,100/76,717 (15.8%) | elapsed 02:57 | 68.30/s | ETA 15:46 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 12,200/76,717 (15.9%) | elapsed 02:59 | 68.27/s | ETA 15:45 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 12,300/76,717 (16.0%) | elapsed 03:00 | 68.28/s | ETA 15:43 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 12,400/76,717 (16.2%) | elapsed 03:02 | 68.27/s | ETA 15:42 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 12,500/76,717 (16.3%) | elapsed 03:03 | 68.24/s | ETA 15:41 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 12,600/76,717 (16.4%) | elapsed 03:05 | 68.20/s | ETA 15:40 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 12,700/76,717 (16.6%) | elapsed 03:06 | 68.17/s | ETA 15:39 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 12,800/76,717 (16.7%) | elapsed 03:08 | 68.15/s | ETA 15:38 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 12,900/76,717 (16.8%) | elapsed 03:09 | 68.08/s | ETA 15:37 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 13,000/76,717 (16.9%) | elapsed 03:11 | 68.04/s | ETA 15:36 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 13,100/76,717 (17.1%) | elapsed 03:13 | 68.05/s | ETA 15:35 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 13,200/76,717 (17.2%) | elapsed 03:14 | 68.04/s | ETA 15:34 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 13,300/76,717 (17.3%) | elapsed 03:16 | 68.02/s | ETA 15:32 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 13,400/76,717 (17.5%) | elapsed 03:17 | 68.00/s | ETA 15:31 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 13,500/76,717 (17.6%) | elapsed 03:19 | 67.99/s | ETA 15:30 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_0031 / time=24 / doses=2 vs 3.33: 746 matched sample pairs across 96 shared compounds
# [signature_metrics] 13,600/76,717 (17.7%) | elapsed 03:20 | 67.92/s | ETA 15:29 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 13,700/76,717 (17.9%) | elapsed 03:22 | 67.90/s | ETA 15:28 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 13,800/76,717 (18.0%) | elapsed 03:23 | 67.89/s | ETA 15:27 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 13,900/76,717 (18.1%) | elapsed 03:25 | 67.89/s | ETA 15:25 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 14,000/76,717 (18.2%) | elapsed 03:26 | 67.88/s | ETA 15:24 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 14,100/76,717 (18.4%) | elapsed 03:28 | 67.87/s | ETA 15:23 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 14,200/76,717 (18.5%) | elapsed 03:29 | 67.86/s | ETA 15:21 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 14,300/76,717 (18.6%) | elapsed 03:31 | 67.86/s | ETA 15:20 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_0031 / time=24 / doses=0.4 vs 0.37037: 278 matched sample pairs across 48 shared compounds
# [signature_metrics] 14,400/76,717 (18.8%) | elapsed 03:32 | 67.81/s | ETA 15:19 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 14,500/76,717 (18.9%) | elapsed 03:34 | 67.78/s | ETA 15:18 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 14,600/76,717 (19.0%) | elapsed 03:35 | 67.75/s | ETA 15:17 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_0031 / time=24 / doses=0.08 vs 0.12: 807 matched sample pairs across 103 shared compounds
# [signature_metrics] 14,700/76,717 (19.2%) | elapsed 03:37 | 67.72/s | ETA 15:16 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 14,800/76,717 (19.3%) | elapsed 03:39 | 67.71/s | ETA 15:14 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 14,900/76,717 (19.4%) | elapsed 03:40 | 67.71/s | ETA 15:13 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 15,000/76,717 (19.6%) | elapsed 03:42 | 67.70/s | ETA 15:12 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 15,100/76,717 (19.7%) | elapsed 03:43 | 67.70/s | ETA 15:10 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 15,200/76,717 (19.8%) | elapsed 03:45 | 67.68/s | ETA 15:09 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 15,300/76,717 (19.9%) | elapsed 03:46 | 67.67/s | ETA 15:08 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 15,400/76,717 (20.1%) | elapsed 03:48 | 67.66/s | ETA 15:06 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_0035 / time=24 / doses=10 vs 10: 5660 matched sample pairs across 112 shared compounds
# [signature_metrics] 15,500/76,717 (20.2%) | elapsed 03:49 | 67.56/s | ETA 15:06 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 15,600/76,717 (20.3%) | elapsed 03:51 | 67.55/s | ETA 15:05 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 15,700/76,717 (20.5%) | elapsed 03:53 | 67.53/s | ETA 15:04 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 15,800/76,717 (20.6%) | elapsed 03:54 | 67.51/s | ETA 15:02 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 15,900/76,717 (20.7%) | elapsed 03:56 | 67.49/s | ETA 15:01 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 16,000/76,717 (20.9%) | elapsed 03:57 | 67.47/s | ETA 15:00 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 16,100/76,717 (21.0%) | elapsed 03:59 | 67.44/s | ETA 14:59 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 16,200/76,717 (21.1%) | elapsed 04:00 | 67.44/s | ETA 14:57 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 16,300/76,717 (21.2%) | elapsed 04:02 | 67.43/s | ETA 14:56 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 16,400/76,717 (21.4%) | elapsed 04:03 | 67.41/s | ETA 14:55 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 16,500/76,717 (21.5%) | elapsed 04:05 | 67.38/s | ETA 14:54 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 16,600/76,717 (21.6%) | elapsed 04:06 | 67.37/s | ETA 14:52 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 16,700/76,717 (21.8%) | elapsed 04:08 | 67.36/s | ETA 14:51 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 16,800/76,717 (21.9%) | elapsed 04:10 | 67.33/s | ETA 14:50 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 16,900/76,717 (22.0%) | elapsed 04:11 | 67.30/s | ETA 14:49 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 17,000/76,717 (22.2%) | elapsed 04:13 | 67.29/s | ETA 14:47 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 17,100/76,717 (22.3%) | elapsed 04:14 | 67.27/s | ETA 14:46 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 17,200/76,717 (22.4%) | elapsed 04:16 | 67.25/s | ETA 14:45 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 17,300/76,717 (22.6%) | elapsed 04:17 | 67.23/s | ETA 14:44 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 17,400/76,717 (22.7%) | elapsed 04:19 | 67.20/s | ETA 14:43 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 17,500/76,717 (22.8%) | elapsed 04:20 | 67.21/s | ETA 14:41 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 17,600/76,717 (22.9%) | elapsed 04:22 | 67.19/s | ETA 14:40 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 17,700/76,717 (23.1%) | elapsed 04:24 | 67.17/s | ETA 14:39 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 17,800/76,717 (23.2%) | elapsed 04:25 | 67.13/s | ETA 14:38 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 17,900/76,717 (23.3%) | elapsed 04:27 | 67.11/s | ETA 14:36 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 18,000/76,717 (23.5%) | elapsed 04:28 | 67.10/s | ETA 14:35 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 18,100/76,717 (23.6%) | elapsed 04:30 | 67.10/s | ETA 14:34 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 18,200/76,717 (23.7%) | elapsed 04:31 | 67.11/s | ETA 14:32 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 18,300/76,717 (23.9%) | elapsed 04:33 | 67.11/s | ETA 14:30 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 18,400/76,717 (24.0%) | elapsed 04:34 | 67.12/s | ETA 14:29 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 18,500/76,717 (24.1%) | elapsed 04:36 | 67.13/s | ETA 14:27 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 18,600/76,717 (24.2%) | elapsed 04:37 | 67.13/s | ETA 14:26 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 18,700/76,717 (24.4%) | elapsed 04:39 | 67.13/s | ETA 14:24 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 18,800/76,717 (24.5%) | elapsed 04:40 | 67.14/s | ETA 14:23 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 18,900/76,717 (24.6%) | elapsed 04:42 | 67.14/s | ETA 14:21 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 19,000/76,717 (24.8%) | elapsed 04:43 | 67.15/s | ETA 14:20 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 19,100/76,717 (24.9%) | elapsed 04:44 | 67.14/s | ETA 14:18 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 19,200/76,717 (25.0%) | elapsed 04:46 | 67.14/s | ETA 14:17 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 19,300/76,717 (25.2%) | elapsed 04:47 | 67.15/s | ETA 14:15 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 19,400/76,717 (25.3%) | elapsed 04:49 | 67.15/s | ETA 14:14 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 19,500/76,717 (25.4%) | elapsed 04:50 | 67.16/s | ETA 14:12 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 19,600/76,717 (25.5%) | elapsed 04:52 | 67.16/s | ETA 14:10 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 19,700/76,717 (25.7%) | elapsed 04:53 | 67.16/s | ETA 14:09 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 19,800/76,717 (25.8%) | elapsed 04:55 | 67.16/s | ETA 14:07 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 19,900/76,717 (25.9%) | elapsed 04:56 | 67.17/s | ETA 14:06 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 20,000/76,717 (26.1%) | elapsed 04:58 | 67.17/s | ETA 14:04 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 20,100/76,717 (26.2%) | elapsed 04:59 | 67.16/s | ETA 14:03 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 20,200/76,717 (26.3%) | elapsed 05:01 | 67.17/s | ETA 14:01 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 20,300/76,717 (26.5%) | elapsed 05:02 | 67.15/s | ETA 14:00 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 20,400/76,717 (26.6%) | elapsed 05:04 | 67.12/s | ETA 13:59 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 20,500/76,717 (26.7%) | elapsed 05:05 | 67.11/s | ETA 13:58 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 20,600/76,717 (26.9%) | elapsed 05:07 | 67.08/s | ETA 13:57 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 20,700/76,717 (27.0%) | elapsed 05:09 | 67.08/s | ETA 13:55 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 20,800/76,717 (27.1%) | elapsed 05:10 | 67.08/s | ETA 13:54 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 20,900/76,717 (27.2%) | elapsed 05:12 | 67.08/s | ETA 13:52 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# [signature_metrics] 21,000/76,717 (27.4%) | elapsed 05:13 | 67.06/s | ETA 13:51 | L1000 Phase I vs L1000 Phase II / CVCL_0035
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_U602 / time=24 / doses=10 vs 10: 763 matched sample pairs across 34 shared compounds
# [signature_metrics] 21,100/76,717 (27.5%) | elapsed 05:15 | 67.03/s | ETA 13:50 | L1000 Phase I vs L1000 Phase II / CVCL_U602
# [signature_metrics] 21,200/76,717 (27.6%) | elapsed 05:16 | 67.02/s | ETA 13:48 | L1000 Phase I vs L1000 Phase II / CVCL_U602
# [signature_metrics] 21,300/76,717 (27.8%) | elapsed 05:18 | 67.00/s | ETA 13:47 | L1000 Phase I vs L1000 Phase II / CVCL_U602
# [signature_metrics] 21,400/76,717 (27.9%) | elapsed 05:19 | 66.98/s | ETA 13:46 | L1000 Phase I vs L1000 Phase II / CVCL_U602
# [signature_metrics] 21,500/76,717 (28.0%) | elapsed 05:21 | 66.99/s | ETA 13:44 | L1000 Phase I vs L1000 Phase II / CVCL_U602
# [signature_metrics] 21,600/76,717 (28.2%) | elapsed 05:22 | 66.99/s | ETA 13:43 | L1000 Phase I vs L1000 Phase II / CVCL_U602
# [signature_metrics] 21,700/76,717 (28.3%) | elapsed 05:24 | 66.99/s | ETA 13:41 | L1000 Phase I vs L1000 Phase II / CVCL_U602
# [signature_metrics] 21,800/76,717 (28.4%) | elapsed 05:25 | 66.99/s | ETA 13:40 | L1000 Phase I vs L1000 Phase II / CVCL_U602
# Scoring L1000 Phase I vs L1000 Phase II / NEU / time=24 / doses=10 vs 10: 573 matched sample pairs across 31 shared compounds
# [signature_metrics] 21,900/76,717 (28.5%) | elapsed 05:27 | 66.95/s | ETA 13:39 | L1000 Phase I vs L1000 Phase II / NEU
# [signature_metrics] 22,000/76,717 (28.7%) | elapsed 05:29 | 66.94/s | ETA 13:37 | L1000 Phase I vs L1000 Phase II / NEU
# [signature_metrics] 22,100/76,717 (28.8%) | elapsed 05:30 | 66.92/s | ETA 13:36 | L1000 Phase I vs L1000 Phase II / NEU
# [signature_metrics] 22,200/76,717 (28.9%) | elapsed 05:32 | 66.93/s | ETA 13:35 | L1000 Phase I vs L1000 Phase II / NEU
# [signature_metrics] 22,300/76,717 (29.1%) | elapsed 05:33 | 66.93/s | ETA 13:33 | L1000 Phase I vs L1000 Phase II / NEU
# [signature_metrics] 22,400/76,717 (29.2%) | elapsed 05:35 | 66.91/s | ETA 13:32 | L1000 Phase I vs L1000 Phase II / NEU
# Scoring L1000 Phase I vs L1000 Phase II / NPC / time=24 / doses=10 vs 10: 971 matched sample pairs across 34 shared compounds
# [signature_metrics] 22,500/76,717 (29.3%) | elapsed 05:36 | 66.88/s | ETA 13:31 | L1000 Phase I vs L1000 Phase II / NPC
# [signature_metrics] 22,600/76,717 (29.5%) | elapsed 05:38 | 66.86/s | ETA 13:29 | L1000 Phase I vs L1000 Phase II / NPC
# [signature_metrics] 22,700/76,717 (29.6%) | elapsed 05:40 | 66.85/s | ETA 13:28 | L1000 Phase I vs L1000 Phase II / NPC
# [signature_metrics] 22,800/76,717 (29.7%) | elapsed 05:41 | 66.84/s | ETA 13:27 | L1000 Phase I vs L1000 Phase II / NPC
# [signature_metrics] 22,900/76,717 (29.8%) | elapsed 05:43 | 66.84/s | ETA 13:25 | L1000 Phase I vs L1000 Phase II / NPC
# [signature_metrics] 23,000/76,717 (30.0%) | elapsed 05:44 | 66.84/s | ETA 13:24 | L1000 Phase I vs L1000 Phase II / NPC
# [signature_metrics] 23,100/76,717 (30.1%) | elapsed 05:46 | 66.84/s | ETA 13:22 | L1000 Phase I vs L1000 Phase II / NPC
# [signature_metrics] 23,200/76,717 (30.2%) | elapsed 05:47 | 66.84/s | ETA 13:21 | L1000 Phase I vs L1000 Phase II / NPC
# [signature_metrics] 23,300/76,717 (30.4%) | elapsed 05:49 | 66.83/s | ETA 13:19 | L1000 Phase I vs L1000 Phase II / NPC
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_0031 / time=24 / doses=0.4 vs 0.37: 367 matched sample pairs across 54 shared compounds
# [signature_metrics] 23,400/76,717 (30.5%) | elapsed 05:50 | 66.82/s | ETA 13:18 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 23,500/76,717 (30.6%) | elapsed 05:52 | 66.82/s | ETA 13:16 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 23,600/76,717 (30.8%) | elapsed 05:53 | 66.81/s | ETA 13:15 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# [signature_metrics] 23,700/76,717 (30.9%) | elapsed 05:55 | 66.81/s | ETA 13:14 | L1000 Phase I vs L1000 Phase II / CVCL_0031
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_0033 / time=24 / doses=10 vs 10: 730 matched sample pairs across 59 shared compounds
# [signature_metrics] 23,800/76,717 (31.0%) | elapsed 05:56 | 66.80/s | ETA 13:12 | L1000 Phase I vs L1000 Phase II / CVCL_0033
# [signature_metrics] 23,900/76,717 (31.2%) | elapsed 05:58 | 66.80/s | ETA 13:11 | L1000 Phase I vs L1000 Phase II / CVCL_0033
# [signature_metrics] 24,000/76,717 (31.3%) | elapsed 05:59 | 66.80/s | ETA 13:09 | L1000 Phase I vs L1000 Phase II / CVCL_0033
# [signature_metrics] 24,100/76,717 (31.4%) | elapsed 06:01 | 66.80/s | ETA 13:08 | L1000 Phase I vs L1000 Phase II / CVCL_0033
# [signature_metrics] 24,200/76,717 (31.5%) | elapsed 06:02 | 66.80/s | ETA 13:06 | L1000 Phase I vs L1000 Phase II / CVCL_0033
# [signature_metrics] 24,300/76,717 (31.7%) | elapsed 06:04 | 66.79/s | ETA 13:05 | L1000 Phase I vs L1000 Phase II / CVCL_0033
# [signature_metrics] 24,400/76,717 (31.8%) | elapsed 06:05 | 66.79/s | ETA 13:03 | L1000 Phase I vs L1000 Phase II / CVCL_0033
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_0033 / time=24 / doses=2 vs 1.11: 5 matched sample pairs across 1 shared compounds
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_0033 / time=24 / doses=0.4 vs 0.37: 811 matched sample pairs across 63 shared compounds
# [signature_metrics] 24,500/76,717 (31.9%) | elapsed 06:07 | 66.78/s | ETA 13:02 | L1000 Phase I vs L1000 Phase II / CVCL_0033
# [signature_metrics] 24,600/76,717 (32.1%) | elapsed 06:08 | 66.78/s | ETA 13:00 | L1000 Phase I vs L1000 Phase II / CVCL_0033
# [signature_metrics] 24,700/76,717 (32.2%) | elapsed 06:10 | 66.77/s | ETA 12:59 | L1000 Phase I vs L1000 Phase II / CVCL_0033
# [signature_metrics] 24,800/76,717 (32.3%) | elapsed 06:11 | 66.77/s | ETA 12:58 | L1000 Phase I vs L1000 Phase II / CVCL_0033
# [signature_metrics] 24,900/76,717 (32.5%) | elapsed 06:13 | 66.77/s | ETA 12:56 | L1000 Phase I vs L1000 Phase II / CVCL_0033
# [signature_metrics] 25,000/76,717 (32.6%) | elapsed 06:14 | 66.77/s | ETA 12:55 | L1000 Phase I vs L1000 Phase II / CVCL_0033
# [signature_metrics] 25,100/76,717 (32.7%) | elapsed 06:16 | 66.77/s | ETA 12:53 | L1000 Phase I vs L1000 Phase II / CVCL_0033
# [signature_metrics] 25,200/76,717 (32.8%) | elapsed 06:17 | 66.76/s | ETA 12:52 | L1000 Phase I vs L1000 Phase II / CVCL_0033
# [signature_metrics] 25,300/76,717 (33.0%) | elapsed 06:19 | 66.77/s | ETA 12:50 | L1000 Phase I vs L1000 Phase II / CVCL_0033
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_0033 / time=24 / doses=0.08 vs 0.12: 825 matched sample pairs across 63 shared compounds
# [signature_metrics] 25,400/76,717 (33.1%) | elapsed 06:20 | 66.76/s | ETA 12:49 | L1000 Phase I vs L1000 Phase II / CVCL_0033
# [signature_metrics] 25,500/76,717 (33.2%) | elapsed 06:22 | 66.76/s | ETA 12:47 | L1000 Phase I vs L1000 Phase II / CVCL_0033
# [signature_metrics] 25,600/76,717 (33.4%) | elapsed 06:23 | 66.76/s | ETA 12:46 | L1000 Phase I vs L1000 Phase II / CVCL_0033
# [signature_metrics] 25,700/76,717 (33.5%) | elapsed 06:25 | 66.76/s | ETA 12:44 | L1000 Phase I vs L1000 Phase II / CVCL_0033
# [signature_metrics] 25,800/76,717 (33.6%) | elapsed 06:26 | 66.76/s | ETA 12:43 | L1000 Phase I vs L1000 Phase II / CVCL_0033
# [signature_metrics] 25,900/76,717 (33.8%) | elapsed 06:28 | 66.76/s | ETA 12:41 | L1000 Phase I vs L1000 Phase II / CVCL_0033
# [signature_metrics] 26,000/76,717 (33.9%) | elapsed 06:29 | 66.76/s | ETA 12:40 | L1000 Phase I vs L1000 Phase II / CVCL_0033
# [signature_metrics] 26,100/76,717 (34.0%) | elapsed 06:31 | 66.76/s | ETA 12:38 | L1000 Phase I vs L1000 Phase II / CVCL_0033
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_0062 / time=24 / doses=10 vs 10: 827 matched sample pairs across 89 shared compounds
# [signature_metrics] 26,200/76,717 (34.2%) | elapsed 06:32 | 66.76/s | ETA 12:37 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 26,300/76,717 (34.3%) | elapsed 06:34 | 66.77/s | ETA 12:35 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 26,400/76,717 (34.4%) | elapsed 06:35 | 66.77/s | ETA 12:34 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 26,500/76,717 (34.5%) | elapsed 06:37 | 66.78/s | ETA 12:32 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 26,600/76,717 (34.7%) | elapsed 06:38 | 66.78/s | ETA 12:30 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 26,700/76,717 (34.8%) | elapsed 06:40 | 66.79/s | ETA 12:29 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 26,800/76,717 (34.9%) | elapsed 06:41 | 66.80/s | ETA 12:27 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 26,900/76,717 (35.1%) | elapsed 06:43 | 66.81/s | ETA 12:26 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_0062 / time=24 / doses=2 vs 3.33: 944 matched sample pairs across 93 shared compounds
# [signature_metrics] 27,000/76,717 (35.2%) | elapsed 06:44 | 66.81/s | ETA 12:24 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 27,100/76,717 (35.3%) | elapsed 06:46 | 66.82/s | ETA 12:23 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 27,200/76,717 (35.5%) | elapsed 06:47 | 66.83/s | ETA 12:21 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 27,300/76,717 (35.6%) | elapsed 06:48 | 66.84/s | ETA 12:19 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 27,400/76,717 (35.7%) | elapsed 06:50 | 66.85/s | ETA 12:18 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 27,500/76,717 (35.8%) | elapsed 06:51 | 66.85/s | ETA 12:16 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 27,600/76,717 (36.0%) | elapsed 06:53 | 66.86/s | ETA 12:15 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 27,700/76,717 (36.1%) | elapsed 06:54 | 66.87/s | ETA 12:13 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 27,800/76,717 (36.2%) | elapsed 06:56 | 66.88/s | ETA 12:11 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_0062 / time=24 / doses=0.4 vs 0.37: 989 matched sample pairs across 94 shared compounds
# [signature_metrics] 27,900/76,717 (36.4%) | elapsed 06:57 | 66.88/s | ETA 12:10 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 28,000/76,717 (36.5%) | elapsed 06:59 | 66.89/s | ETA 12:08 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 28,100/76,717 (36.6%) | elapsed 07:00 | 66.90/s | ETA 12:07 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 28,200/76,717 (36.8%) | elapsed 07:02 | 66.90/s | ETA 12:05 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 28,300/76,717 (36.9%) | elapsed 07:03 | 66.91/s | ETA 12:04 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 28,400/76,717 (37.0%) | elapsed 07:04 | 66.92/s | ETA 12:02 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 28,500/76,717 (37.1%) | elapsed 07:06 | 66.93/s | ETA 12:00 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 28,600/76,717 (37.3%) | elapsed 07:07 | 66.93/s | ETA 11:59 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 28,700/76,717 (37.4%) | elapsed 07:09 | 66.94/s | ETA 11:57 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 28,800/76,717 (37.5%) | elapsed 07:10 | 66.95/s | ETA 11:56 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_0062 / time=24 / doses=0.08 vs 0.12: 979 matched sample pairs across 94 shared compounds
# [signature_metrics] 28,900/76,717 (37.7%) | elapsed 07:12 | 66.96/s | ETA 11:54 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 29,000/76,717 (37.8%) | elapsed 07:13 | 66.96/s | ETA 11:53 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 29,100/76,717 (37.9%) | elapsed 07:14 | 66.97/s | ETA 11:51 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 29,200/76,717 (38.1%) | elapsed 07:16 | 66.98/s | ETA 11:49 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 29,300/76,717 (38.2%) | elapsed 07:17 | 66.99/s | ETA 11:48 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 29,400/76,717 (38.3%) | elapsed 07:19 | 66.99/s | ETA 11:46 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 29,500/76,717 (38.5%) | elapsed 07:20 | 67.00/s | ETA 11:45 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 29,600/76,717 (38.6%) | elapsed 07:22 | 67.01/s | ETA 11:43 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 29,700/76,717 (38.7%) | elapsed 07:23 | 67.02/s | ETA 11:42 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# [signature_metrics] 29,800/76,717 (38.8%) | elapsed 07:25 | 67.02/s | ETA 11:40 | L1000 Phase I vs L1000 Phase II / CVCL_0062
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_0178 / time=24 / doses=10 vs 10: 638 matched sample pairs across 62 shared compounds
# [signature_metrics] 29,900/76,717 (39.0%) | elapsed 07:26 | 67.02/s | ETA 11:39 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# [signature_metrics] 30,000/76,717 (39.1%) | elapsed 07:28 | 67.02/s | ETA 11:37 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# [signature_metrics] 30,100/76,717 (39.2%) | elapsed 07:29 | 67.02/s | ETA 11:36 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# [signature_metrics] 30,200/76,717 (39.4%) | elapsed 07:31 | 67.02/s | ETA 11:34 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# [signature_metrics] 30,300/76,717 (39.5%) | elapsed 07:32 | 67.03/s | ETA 11:33 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# [signature_metrics] 30,400/76,717 (39.6%) | elapsed 07:34 | 67.02/s | ETA 11:31 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# [signature_metrics] 30,500/76,717 (39.8%) | elapsed 07:35 | 67.02/s | ETA 11:30 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_0178 / time=24 / doses=2 vs 3.33: 665 matched sample pairs across 63 shared compounds
# [signature_metrics] 30,600/76,717 (39.9%) | elapsed 07:37 | 67.01/s | ETA 11:28 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# [signature_metrics] 30,700/76,717 (40.0%) | elapsed 07:38 | 67.01/s | ETA 11:27 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# [signature_metrics] 30,800/76,717 (40.1%) | elapsed 07:40 | 67.01/s | ETA 11:25 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# [signature_metrics] 30,900/76,717 (40.3%) | elapsed 07:41 | 67.01/s | ETA 11:24 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# [signature_metrics] 31,000/76,717 (40.4%) | elapsed 07:43 | 67.00/s | ETA 11:22 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# [signature_metrics] 31,100/76,717 (40.5%) | elapsed 07:44 | 67.00/s | ETA 11:21 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_0178 / time=24 / doses=0.4 vs 0.37: 678 matched sample pairs across 63 shared compounds
# [signature_metrics] 31,200/76,717 (40.7%) | elapsed 07:46 | 67.00/s | ETA 11:19 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# [signature_metrics] 31,300/76,717 (40.8%) | elapsed 07:47 | 66.99/s | ETA 11:18 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# [signature_metrics] 31,400/76,717 (40.9%) | elapsed 07:49 | 66.99/s | ETA 11:16 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# [signature_metrics] 31,500/76,717 (41.1%) | elapsed 07:50 | 66.99/s | ETA 11:15 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# [signature_metrics] 31,600/76,717 (41.2%) | elapsed 07:52 | 66.99/s | ETA 11:13 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# [signature_metrics] 31,700/76,717 (41.3%) | elapsed 07:53 | 66.99/s | ETA 11:12 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# [signature_metrics] 31,800/76,717 (41.5%) | elapsed 07:55 | 66.99/s | ETA 11:11 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_0178 / time=24 / doses=0.08 vs 0.12: 689 matched sample pairs across 63 shared compounds
# [signature_metrics] 31,900/76,717 (41.6%) | elapsed 07:56 | 66.98/s | ETA 11:09 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# [signature_metrics] 32,000/76,717 (41.7%) | elapsed 07:58 | 66.98/s | ETA 11:08 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# [signature_metrics] 32,100/76,717 (41.8%) | elapsed 07:59 | 66.98/s | ETA 11:06 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# [signature_metrics] 32,200/76,717 (42.0%) | elapsed 08:01 | 66.97/s | ETA 11:05 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# [signature_metrics] 32,300/76,717 (42.1%) | elapsed 08:02 | 66.96/s | ETA 11:03 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# [signature_metrics] 32,400/76,717 (42.2%) | elapsed 08:04 | 66.96/s | ETA 11:02 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# [signature_metrics] 32,500/76,717 (42.4%) | elapsed 08:05 | 66.96/s | ETA 11:00 | L1000 Phase I vs L1000 Phase II / CVCL_0178
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_0332 / time=24 / doses=10 vs 10: 511 matched sample pairs across 62 shared compounds
# [signature_metrics] 32,600/76,717 (42.5%) | elapsed 08:07 | 66.96/s | ETA 10:59 | L1000 Phase I vs L1000 Phase II / CVCL_0332
# [signature_metrics] 32,700/76,717 (42.6%) | elapsed 08:08 | 66.96/s | ETA 10:57 | L1000 Phase I vs L1000 Phase II / CVCL_0332
# [signature_metrics] 32,800/76,717 (42.8%) | elapsed 08:10 | 66.95/s | ETA 10:56 | L1000 Phase I vs L1000 Phase II / CVCL_0332
# [signature_metrics] 32,900/76,717 (42.9%) | elapsed 08:11 | 66.95/s | ETA 10:54 | L1000 Phase I vs L1000 Phase II / CVCL_0332
# [signature_metrics] 33,000/76,717 (43.0%) | elapsed 08:13 | 66.95/s | ETA 10:53 | L1000 Phase I vs L1000 Phase II / CVCL_0332
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_0332 / time=24 / doses=2 vs 3.33: 560 matched sample pairs across 63 shared compounds
# [signature_metrics] 33,100/76,717 (43.1%) | elapsed 08:14 | 66.94/s | ETA 10:52 | L1000 Phase I vs L1000 Phase II / CVCL_0332
# [signature_metrics] 33,200/76,717 (43.3%) | elapsed 08:16 | 66.94/s | ETA 10:50 | L1000 Phase I vs L1000 Phase II / CVCL_0332
# [signature_metrics] 33,300/76,717 (43.4%) | elapsed 08:18 | 66.93/s | ETA 10:49 | L1000 Phase I vs L1000 Phase II / CVCL_0332
# [signature_metrics] 33,400/76,717 (43.5%) | elapsed 08:19 | 66.93/s | ETA 10:47 | L1000 Phase I vs L1000 Phase II / CVCL_0332
# [signature_metrics] 33,500/76,717 (43.7%) | elapsed 08:21 | 66.93/s | ETA 10:46 | L1000 Phase I vs L1000 Phase II / CVCL_0332
# [signature_metrics] 33,600/76,717 (43.8%) | elapsed 08:22 | 66.93/s | ETA 10:44 | L1000 Phase I vs L1000 Phase II / CVCL_0332
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_0332 / time=24 / doses=0.4 vs 0.37: 564 matched sample pairs across 63 shared compounds
# [signature_metrics] 33,700/76,717 (43.9%) | elapsed 08:24 | 66.93/s | ETA 10:43 | L1000 Phase I vs L1000 Phase II / CVCL_0332
# [signature_metrics] 33,800/76,717 (44.1%) | elapsed 08:25 | 66.92/s | ETA 10:41 | L1000 Phase I vs L1000 Phase II / CVCL_0332
# [signature_metrics] 33,900/76,717 (44.2%) | elapsed 08:27 | 66.92/s | ETA 10:40 | L1000 Phase I vs L1000 Phase II / CVCL_0332
# [signature_metrics] 34,000/76,717 (44.3%) | elapsed 08:28 | 66.91/s | ETA 10:38 | L1000 Phase I vs L1000 Phase II / CVCL_0332
# [signature_metrics] 34,100/76,717 (44.4%) | elapsed 08:30 | 66.91/s | ETA 10:37 | L1000 Phase I vs L1000 Phase II / CVCL_0332
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_0332 / time=24 / doses=0.08 vs 0.12: 585 matched sample pairs across 63 shared compounds
# [signature_metrics] 34,200/76,717 (44.6%) | elapsed 08:31 | 66.90/s | ETA 10:35 | L1000 Phase I vs L1000 Phase II / CVCL_0332
# [signature_metrics] 34,300/76,717 (44.7%) | elapsed 08:33 | 66.90/s | ETA 10:34 | L1000 Phase I vs L1000 Phase II / CVCL_0332
# [signature_metrics] 34,400/76,717 (44.8%) | elapsed 08:34 | 66.90/s | ETA 10:33 | L1000 Phase I vs L1000 Phase II / CVCL_0332
# [signature_metrics] 34,500/76,717 (45.0%) | elapsed 08:36 | 66.90/s | ETA 10:31 | L1000 Phase I vs L1000 Phase II / CVCL_0332
# [signature_metrics] 34,600/76,717 (45.1%) | elapsed 08:37 | 66.90/s | ETA 10:30 | L1000 Phase I vs L1000 Phase II / CVCL_0332
# [signature_metrics] 34,700/76,717 (45.2%) | elapsed 08:39 | 66.90/s | ETA 10:28 | L1000 Phase I vs L1000 Phase II / CVCL_0332
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_0598 / time=24 / doses=10 vs 10: 552 matched sample pairs across 61 shared compounds
# [signature_metrics] 34,800/76,717 (45.4%) | elapsed 08:40 | 66.90/s | ETA 10:27 | L1000 Phase I vs L1000 Phase II / CVCL_0598
# [signature_metrics] 34,900/76,717 (45.5%) | elapsed 08:42 | 66.89/s | ETA 10:25 | L1000 Phase I vs L1000 Phase II / CVCL_0598
# [signature_metrics] 35,000/76,717 (45.6%) | elapsed 08:43 | 66.89/s | ETA 10:24 | L1000 Phase I vs L1000 Phase II / CVCL_0598
# [signature_metrics] 35,100/76,717 (45.8%) | elapsed 08:45 | 66.89/s | ETA 10:22 | L1000 Phase I vs L1000 Phase II / CVCL_0598
# [signature_metrics] 35,200/76,717 (45.9%) | elapsed 08:46 | 66.89/s | ETA 10:21 | L1000 Phase I vs L1000 Phase II / CVCL_0598
# [signature_metrics] 35,300/76,717 (46.0%) | elapsed 08:48 | 66.89/s | ETA 10:19 | L1000 Phase I vs L1000 Phase II / CVCL_0598
# Scoring L1000 Phase I vs L1000 Phase II / CVCL_0598 / time=24 / doses=2 vs 3.33: 587 matched sample pairs across 62 shared compounds
# ...
# [signature_metrics] 68,100/76,717 (88.8%) | elapsed 19:36 | 57.88/s | ETA 02:29 | CIGS-MCE vs CIGS-TCM / CVCL_0062
# [signature_metrics] 68,200/76,717 (88.9%) | elapsed 19:39 | 57.83/s | ETA 02:27 | CIGS-MCE vs CIGS-TCM / CVCL_0062
# [signature_metrics] 68,300/76,717 (89.0%) | elapsed 19:42 | 57.77/s | ETA 02:26 | CIGS-MCE vs CIGS-TCM / CVCL_0062
# [signature_metrics] 68,400/76,717 (89.2%) | elapsed 19:45 | 57.71/s | ETA 02:24 | CIGS-MCE vs CIGS-TCM / CVCL_0062
# [signature_metrics] 68,500/76,717 (89.3%) | elapsed 19:48 | 57.66/s | ETA 02:23 | CIGS-MCE vs CIGS-TCM / CVCL_0062
# Scoring CIGS-MCE vs CIGS-TCM / CVCL_0063 / time=24 / doses=10 vs 10: 8064 matched sample pairs across 953 shared compounds
# [signature_metrics] 68,600/76,717 (89.4%) | elapsed 19:51 | 57.59/s | ETA 02:21 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 68,700/76,717 (89.5%) | elapsed 19:54 | 57.53/s | ETA 02:19 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 68,800/76,717 (89.7%) | elapsed 19:57 | 57.46/s | ETA 02:18 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 68,900/76,717 (89.8%) | elapsed 20:00 | 57.39/s | ETA 02:16 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 69,000/76,717 (89.9%) | elapsed 20:04 | 57.32/s | ETA 02:15 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 69,100/76,717 (90.1%) | elapsed 20:07 | 57.25/s | ETA 02:13 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 69,200/76,717 (90.2%) | elapsed 20:10 | 57.19/s | ETA 02:11 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 69,300/76,717 (90.3%) | elapsed 20:13 | 57.12/s | ETA 02:10 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 69,400/76,717 (90.5%) | elapsed 20:16 | 57.05/s | ETA 02:08 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 69,500/76,717 (90.6%) | elapsed 20:20 | 56.99/s | ETA 02:07 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 69,600/76,717 (90.7%) | elapsed 20:23 | 56.93/s | ETA 02:05 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 69,700/76,717 (90.9%) | elapsed 20:26 | 56.87/s | ETA 02:03 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 69,800/76,717 (91.0%) | elapsed 20:29 | 56.81/s | ETA 02:02 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 69,900/76,717 (91.1%) | elapsed 20:32 | 56.75/s | ETA 02:00 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 70,000/76,717 (91.2%) | elapsed 20:35 | 56.69/s | ETA 01:58 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 70,100/76,717 (91.4%) | elapsed 20:38 | 56.63/s | ETA 01:57 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 70,200/76,717 (91.5%) | elapsed 20:41 | 56.56/s | ETA 01:55 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 70,300/76,717 (91.6%) | elapsed 20:44 | 56.50/s | ETA 01:54 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 70,400/76,717 (91.8%) | elapsed 20:47 | 56.44/s | ETA 01:52 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 70,500/76,717 (91.9%) | elapsed 20:50 | 56.38/s | ETA 01:50 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 70,600/76,717 (92.0%) | elapsed 20:54 | 56.32/s | ETA 01:49 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 70,700/76,717 (92.2%) | elapsed 20:57 | 56.26/s | ETA 01:47 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 70,800/76,717 (92.3%) | elapsed 21:00 | 56.20/s | ETA 01:45 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 70,900/76,717 (92.4%) | elapsed 21:03 | 56.14/s | ETA 01:44 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 71,000/76,717 (92.5%) | elapsed 21:06 | 56.08/s | ETA 01:42 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 71,100/76,717 (92.7%) | elapsed 21:09 | 56.03/s | ETA 01:40 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 71,200/76,717 (92.8%) | elapsed 21:12 | 55.97/s | ETA 01:39 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 71,300/76,717 (92.9%) | elapsed 21:15 | 55.91/s | ETA 01:37 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 71,400/76,717 (93.1%) | elapsed 21:19 | 55.84/s | ETA 01:35 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 71,500/76,717 (93.2%) | elapsed 21:22 | 55.79/s | ETA 01:34 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 71,600/76,717 (93.3%) | elapsed 21:25 | 55.72/s | ETA 01:32 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 71,700/76,717 (93.5%) | elapsed 21:28 | 55.67/s | ETA 01:30 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 71,800/76,717 (93.6%) | elapsed 21:31 | 55.60/s | ETA 01:28 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 71,900/76,717 (93.7%) | elapsed 21:34 | 55.55/s | ETA 01:27 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 72,000/76,717 (93.9%) | elapsed 21:38 | 55.49/s | ETA 01:25 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 72,100/76,717 (94.0%) | elapsed 21:41 | 55.44/s | ETA 01:23 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 72,200/76,717 (94.1%) | elapsed 21:44 | 55.39/s | ETA 01:22 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 72,300/76,717 (94.2%) | elapsed 21:47 | 55.34/s | ETA 01:20 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 72,400/76,717 (94.4%) | elapsed 21:50 | 55.28/s | ETA 01:18 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 72,500/76,717 (94.5%) | elapsed 21:53 | 55.23/s | ETA 01:16 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 72,600/76,717 (94.6%) | elapsed 21:56 | 55.17/s | ETA 01:15 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 72,700/76,717 (94.8%) | elapsed 21:59 | 55.12/s | ETA 01:13 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 72,800/76,717 (94.9%) | elapsed 22:02 | 55.07/s | ETA 01:11 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 72,900/76,717 (95.0%) | elapsed 22:05 | 55.01/s | ETA 01:09 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 73,000/76,717 (95.2%) | elapsed 22:08 | 54.96/s | ETA 01:08 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 73,100/76,717 (95.3%) | elapsed 22:11 | 54.90/s | ETA 01:06 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 73,200/76,717 (95.4%) | elapsed 22:14 | 54.85/s | ETA 01:04 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 73,300/76,717 (95.5%) | elapsed 22:18 | 54.80/s | ETA 01:02 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 73,400/76,717 (95.7%) | elapsed 22:21 | 54.75/s | ETA 01:01 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 73,500/76,717 (95.8%) | elapsed 22:24 | 54.69/s | ETA 00:59 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 73,600/76,717 (95.9%) | elapsed 22:27 | 54.64/s | ETA 00:57 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 73,700/76,717 (96.1%) | elapsed 22:30 | 54.59/s | ETA 00:55 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 73,800/76,717 (96.2%) | elapsed 22:33 | 54.55/s | ETA 00:53 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 73,900/76,717 (96.3%) | elapsed 22:36 | 54.49/s | ETA 00:52 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 74,000/76,717 (96.5%) | elapsed 22:39 | 54.45/s | ETA 00:50 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 74,100/76,717 (96.6%) | elapsed 22:42 | 54.40/s | ETA 00:48 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 74,200/76,717 (96.7%) | elapsed 22:45 | 54.35/s | ETA 00:46 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 74,300/76,717 (96.8%) | elapsed 22:48 | 54.30/s | ETA 00:45 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 74,400/76,717 (97.0%) | elapsed 22:52 | 54.25/s | ETA 00:43 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 74,500/76,717 (97.1%) | elapsed 22:55 | 54.20/s | ETA 00:41 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 74,600/76,717 (97.2%) | elapsed 22:58 | 54.15/s | ETA 00:39 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 74,700/76,717 (97.4%) | elapsed 23:01 | 54.11/s | ETA 00:37 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 74,800/76,717 (97.5%) | elapsed 23:04 | 54.06/s | ETA 00:35 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 74,900/76,717 (97.6%) | elapsed 23:07 | 54.01/s | ETA 00:34 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 75,000/76,717 (97.8%) | elapsed 23:10 | 53.96/s | ETA 00:32 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 75,100/76,717 (97.9%) | elapsed 23:13 | 53.92/s | ETA 00:30 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 75,200/76,717 (98.0%) | elapsed 23:16 | 53.86/s | ETA 00:28 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 75,300/76,717 (98.2%) | elapsed 23:19 | 53.81/s | ETA 00:26 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 75,400/76,717 (98.3%) | elapsed 23:22 | 53.77/s | ETA 00:24 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 75,500/76,717 (98.4%) | elapsed 23:25 | 53.73/s | ETA 00:23 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 75,600/76,717 (98.5%) | elapsed 23:28 | 53.68/s | ETA 00:21 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 75,700/76,717 (98.7%) | elapsed 23:31 | 53.64/s | ETA 00:19 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 75,800/76,717 (98.8%) | elapsed 23:34 | 53.60/s | ETA 00:17 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 75,900/76,717 (98.9%) | elapsed 23:37 | 53.55/s | ETA 00:15 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 76,000/76,717 (99.1%) | elapsed 23:40 | 53.51/s | ETA 00:13 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 76,100/76,717 (99.2%) | elapsed 23:43 | 53.47/s | ETA 00:12 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 76,200/76,717 (99.3%) | elapsed 23:46 | 53.42/s | ETA 00:10 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 76,300/76,717 (99.5%) | elapsed 23:50 | 53.37/s | ETA 00:08 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 76,400/76,717 (99.6%) | elapsed 23:53 | 53.32/s | ETA 00:06 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 76,500/76,717 (99.7%) | elapsed 23:56 | 53.28/s | ETA 00:04 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 76,600/76,717 (99.8%) | elapsed 23:59 | 53.22/s | ETA 00:02 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# Scoring CIGS-MCE vs CIGS-TCM / CVCL_0062 / time=24 / doses=10 vs 20: 43 matched sample pairs across 6 shared compounds
# Scoring CIGS-MCE vs CIGS-TCM / CVCL_0063 / time=24 / doses=10 vs 20: 67 matched sample pairs across 10 shared compounds
# [signature_metrics] 76,700/76,717 (100.0%) | elapsed 24:03 | 53.16/s | ETA 00:00 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] 76,717/76,717 (100.0%) | elapsed 24:03 | 53.16/s | ETA 00:00 | CIGS-MCE vs CIGS-TCM / CVCL_0063
# [signature_metrics] computed and saved 76,607 rows to matched_sample_pair_metrics.tsv
# Scored 76,607 matched sample pairs
# Skipped 110 matched sample pairs with no corresponding grouped result in the source line files. Saved details to /home/cirro/Chem-PerturBridge_analysis/results/production_runs/overlap_signature_similarity_group_rep/full_production/unresolved_matched_sample_pairs.tsv
#       dataset_a dataset_b  cell_type time_key   left_dose_key right_dose_key  \
# 0      cigs_mce  cigs_tcm  CVCL_0063       24              10             10
# 1  l1000_phase1   sciplex  CVCL_0023       24  0.119999997318            0.1
# 2  l1000_phase1   sciplex  CVCL_0023       24              10             10
# 3  l1000_phase1   sciplex  CVCL_0031       24   1.11000001431              1
# 4  l1000_phase1   sciplex  CVCL_0031       24              10             10
# 5  l1000_phase2   sciplex  CVCL_0023       24            1.11              1
# 6  l1000_phase2   sciplex  CVCL_0023       24              10             10
# 7  l1000_phase2   sciplex  CVCL_0031       24            1.11              1
# 8  l1000_phase2   sciplex  CVCL_0031       24              10             10
#
#    n_unresolved
# 0             9
# 1             6
# 2             6
# 3             6
# 4            24
# 5            22
# 6            22
# 7             8
# 8             7
#       dataset_a     dataset_b  cell_type pubchem_cid time_key  \
# 0  l1000_phase1  l1000_phase2  CVCL_0023    10074640       24
# 1  l1000_phase1  l1000_phase2  CVCL_0023    10074640       24
# 2  l1000_phase1  l1000_phase2  CVCL_0023    10074640       24
# 3  l1000_phase1  l1000_phase2  CVCL_0023    10074640       24
# 4  l1000_phase1  l1000_phase2  CVCL_0023    10074640       24
#
#                                          left_obs_id  \
# 0  CPC014_A549_24H_X1_F1B6_DUO52HI53LO_K20_masiti...
# 1  CPC014_A549_24H_X1_F1B6_DUO52HI53LO_K20_masiti...
# 2  CPC014_A549_24H_X1_F1B6_DUO52HI53LO_K20_masiti...
# 3  CPC014_A549_24H_X1_F1B6_DUO52HI53LO_K20_masiti...
# 4  CPC014_A549_24H_X2_F1B6_DUO52HI53LO_K20_masiti...
#
#                                        right_obs_id  \
# 0  LJP007_A549_24H_X1_F1B19_I13_masitinib_CVCL_0023
# 1  LJP007_A549_24H_X2_F1B19_I13_masitinib_CVCL_0023
# 2  LJP007_A549_24H_X4_F1B19_I13_masitinib_CVCL_0023
# 3  LJP007_A549_24H_X6_F1B19_I13_masitinib_CVCL_0023
# 4  LJP007_A549_24H_X1_F1B19_I13_masitinib_CVCL_0023
#
#                             left_plate               right_plate left_well  \
# 0  CPC014_A549_24H_X1_F1B6_DUO52HI53LO  LJP007_A549_24H_X1_F1B19       K20
# 1  CPC014_A549_24H_X1_F1B6_DUO52HI53LO  LJP007_A549_24H_X2_F1B19       K20
# 2  CPC014_A549_24H_X1_F1B6_DUO52HI53LO  LJP007_A549_24H_X4_F1B19       K20
# 3  CPC014_A549_24H_X1_F1B6_DUO52HI53LO  LJP007_A549_24H_X6_F1B19       K20
# 4  CPC014_A549_24H_X2_F1B6_DUO52HI53LO  LJP007_A549_24H_X1_F1B19       K20
#
#    ... right_baseline_spearman_t right_baseline_spearman_t_global  \
# 0  ...                  0.231432                         0.250305
# 1  ...                  0.231432                         0.250305
# 2  ...                  0.231432                         0.250305
# 3  ...                  0.231432                         0.250305
# 4  ...                  0.231432                         0.250305
#
#   right_baseline_signed_overlap_t_top50  \
# 0                                  0.19
# 1                                  0.19
# 2                                  0.19
# 3                                  0.19
# 4                                  0.19
#
#    right_baseline_signed_overlap_t_top50_global  \
# 0                                          0.21
# 1                                          0.21
# 2                                          0.21
# 3                                          0.21
# 4                                          0.21
#
#    baseline_pair_mean_spearman_logfc  \
# 0                           0.323004
# 1                           0.323004
# 2                           0.323004
# 3                           0.323004
# 4                           0.323004
#
#    baseline_pair_mean_spearman_logfc_global  baseline_pair_mean_spearman_t  \
# 0                                    0.3275                        0.34372
# 1                                    0.3275                        0.34372
# 2                                    0.3275                        0.34372
# 3                                    0.3275                        0.34372
# 4                                    0.3275                        0.34372
#
#    baseline_pair_mean_spearman_t_global  \
# 0                              0.352676
# 1                              0.352676
# 2                              0.352676
# 3                              0.352676
# 4                              0.352676
#
#    baseline_pair_mean_signed_overlap_t_top50  \
# 0                                      0.295
# 1                                      0.295
# 2                                      0.295
# 3                                      0.295
# 4                                      0.295
#
#   baseline_pair_mean_signed_overlap_t_top50_global
# 0                                            0.275
# 1                                            0.275
# 2                                            0.275
# 3                                            0.275
# 4                                            0.275
#
# [5 rows x 55 columns]

# %%
overlap_metric_column = f"observed_signed_overlap_t_top{TOP_K}"
baseline_overlap_column = f"baseline_pair_mean_signed_overlap_t_top{TOP_K}"
left_baseline_overlap_column = f"left_baseline_signed_overlap_t_top{TOP_K}"
right_baseline_overlap_column = f"right_baseline_signed_overlap_t_top{TOP_K}"
drug_line_time_group_columns = ["dataset_a", "dataset_b", "cell_type", "time_key", "pubchem_cid"]

metric_mean_columns = {
    "mean_common_genes": "n_common_genes",
    "mean_global_common_genes": "n_global_common_genes",
    "mean_left_mean_abs_t": "left_mean_abs_t",
    "mean_right_mean_abs_t": "right_mean_abs_t",
    "mean_pair_mean_abs_t": "pair_mean_abs_t",
    "mean_left_mean_abs_t_global": "left_mean_abs_t_global",
    "mean_right_mean_abs_t_global": "right_mean_abs_t_global",
    "mean_pair_mean_abs_t_global": "pair_mean_abs_t_global",
    "mean_observed_spearman_logfc": "observed_spearman_logfc",
    "mean_observed_spearman_logfc_global": "observed_spearman_logfc_global",
    "mean_observed_spearman_t": "observed_spearman_t",
    "mean_observed_spearman_t_global": "observed_spearman_t_global",
    f"mean_observed_signed_overlap_t_top{TOP_K}": overlap_metric_column,
    f"mean_observed_signed_overlap_t_top{TOP_K}_global": f"{overlap_metric_column}_global",
    "mean_baseline_pair_spearman_logfc": "baseline_pair_mean_spearman_logfc",
    "mean_baseline_pair_spearman_logfc_global": "baseline_pair_mean_spearman_logfc_global",
    "mean_baseline_pair_spearman_t": "baseline_pair_mean_spearman_t",
    "mean_baseline_pair_spearman_t_global": "baseline_pair_mean_spearman_t_global",
    f"mean_baseline_pair_signed_overlap_t_top{TOP_K}": baseline_overlap_column,
    f"mean_baseline_pair_signed_overlap_t_top{TOP_K}_global": f"{baseline_overlap_column}_global",
    "mean_left_baseline_spearman_logfc": "left_baseline_spearman_logfc",
    "mean_left_baseline_spearman_logfc_global": "left_baseline_spearman_logfc_global",
    "mean_left_baseline_spearman_t": "left_baseline_spearman_t",
    "mean_left_baseline_spearman_t_global": "left_baseline_spearman_t_global",
    f"mean_left_baseline_signed_overlap_t_top{TOP_K}": left_baseline_overlap_column,
    f"mean_left_baseline_signed_overlap_t_top{TOP_K}_global": f"{left_baseline_overlap_column}_global",
    "mean_right_baseline_spearman_logfc": "right_baseline_spearman_logfc",
    "mean_right_baseline_spearman_logfc_global": "right_baseline_spearman_logfc_global",
    "mean_right_baseline_spearman_t": "right_baseline_spearman_t",
    "mean_right_baseline_spearman_t_global": "right_baseline_spearman_t_global",
    f"mean_right_baseline_signed_overlap_t_top{TOP_K}": right_baseline_overlap_column,
    f"mean_right_baseline_signed_overlap_t_top{TOP_K}_global": f"{right_baseline_overlap_column}_global",
    "mean_left_baseline_peer_count": "left_baseline_peer_count",
    "mean_right_baseline_peer_count": "right_baseline_peer_count",
}

drug_line_time_agg = {
    "n_matched_sample_pairs": ("left_obs_id", "size"),
    "n_matching_conditions": ("matched_condition_key", "nunique"),
}
for target_column, source_column in metric_mean_columns.items():
    drug_line_time_agg[target_column] = (source_column, "mean")
drug_line_time_agg["n_pair_baselines_available"] = (
    "baseline_pair_mean_spearman_logfc",
    lambda values: int(values.notna().sum()),
)
drug_line_time_agg["n_pair_baselines_available_global"] = (
    "baseline_pair_mean_spearman_logfc_global",
    lambda values: int(values.notna().sum()),
)

drug_line_time_metric_summary = (
    matched_pair_metrics.groupby(drug_line_time_group_columns, as_index=False)
    .agg(**drug_line_time_agg)
    .sort_values(drug_line_time_group_columns)
    .reset_index(drop=True)
)
drug_line_time_metric_summary_path = OUTPUT_DIR / "matched_drug_line_time_metric_summary.tsv"
drug_line_time_metric_summary.to_csv(drug_line_time_metric_summary_path, sep="	", index=False)
print(f"Saved drug-line-time metric summary to {drug_line_time_metric_summary_path}")

summary_mean_columns = [
    column_name for column_name in drug_line_time_metric_summary.columns if column_name.startswith("mean_")
]

pair_agg = {
    "n_matched_sample_pairs": ("n_matched_sample_pairs", "sum"),
    "n_matching_lines": ("cell_type", "nunique"),
    "n_matching_drugs": ("pubchem_cid", "nunique"),
    "n_matching_conditions": ("n_matching_conditions", "sum"),
    "n_matching_drug_line_times": ("pubchem_cid", "size"),
}
for column_name in summary_mean_columns:
    pair_agg[column_name] = (column_name, "mean")
pair_agg["n_pair_baselines_available"] = (
    "mean_baseline_pair_spearman_logfc",
    lambda values: int(values.notna().sum()),
)
pair_agg["n_pair_baselines_available_global"] = (
    "mean_baseline_pair_spearman_logfc_global",
    lambda values: int(values.notna().sum()),
)

pair_metric_summary = (
    drug_line_time_metric_summary.groupby(["dataset_a", "dataset_b"], as_index=False)
    .agg(**pair_agg)
    .sort_values(["dataset_a", "dataset_b"])
    .reset_index(drop=True)
)

line_agg = {
    "n_matched_sample_pairs": ("n_matched_sample_pairs", "sum"),
    "n_matching_drugs": ("pubchem_cid", "nunique"),
    "n_matching_conditions": ("n_matching_conditions", "sum"),
    "n_matching_drug_line_times": ("pubchem_cid", "size"),
}
for column_name in summary_mean_columns:
    line_agg[column_name] = (column_name, "mean")
line_agg["n_pair_baselines_available"] = (
    "mean_baseline_pair_spearman_logfc",
    lambda values: int(values.notna().sum()),
)
line_agg["n_pair_baselines_available_global"] = (
    "mean_baseline_pair_spearman_logfc_global",
    lambda values: int(values.notna().sum()),
)

line_metric_summary = (
    drug_line_time_metric_summary.groupby(["dataset_a", "dataset_b", "cell_type"], as_index=False)
    .agg(**line_agg)
    .sort_values(["dataset_a", "dataset_b", "cell_type"])
    .reset_index(drop=True)
)

pair_metric_summary_path = OUTPUT_DIR / "dataset_pair_metric_summary.tsv"
line_metric_summary_path = OUTPUT_DIR / "dataset_pair_line_metric_summary.tsv"
pair_metric_summary.to_csv(pair_metric_summary_path, sep="	", index=False)
line_metric_summary.to_csv(line_metric_summary_path, sep="	", index=False)
print(f"Saved dataset-pair summary to {pair_metric_summary_path}")
print(f"Saved dataset-pair-line summary to {line_metric_summary_path}")

pair_metric_summary_display = pair_metric_summary.copy()
pair_metric_summary_display["dataset_a"] = pair_metric_summary_display["dataset_a"].map(pretty_label)
pair_metric_summary_display["dataset_b"] = pair_metric_summary_display["dataset_b"].map(pretty_label)
display(pair_metric_summary_display)

line_metric_summary_display = line_metric_summary.copy()
line_metric_summary_display["dataset_a"] = line_metric_summary_display["dataset_a"].map(pretty_label)
line_metric_summary_display["dataset_b"] = line_metric_summary_display["dataset_b"].map(pretty_label)
display(line_metric_summary_display)
# Out:
# Saved drug-line-time metric summary to /home/cirro/Chem-PerturBridge_analysis/results/production_runs/overlap_signature_similarity_group_rep/full_production/matched_drug_line_time_metric_summary.tsv
# Saved dataset-pair summary to /home/cirro/Chem-PerturBridge_analysis/results/production_runs/overlap_signature_similarity_group_rep/full_production/dataset_pair_metric_summary.tsv
# Saved dataset-pair-line summary to /home/cirro/Chem-PerturBridge_analysis/results/production_runs/overlap_signature_similarity_group_rep/full_production/dataset_pair_line_metric_summary.tsv
#         dataset_a       dataset_b  n_matched_sample_pairs  n_matching_lines  \
# 0        CIGS-MCE        CIGS-TCM                   15964                 2
# 1   L1000 Phase I        CIGS-MCE                    1401                 2
# 2   L1000 Phase I  L1000 Phase II                   50695                15
# 3   L1000 Phase I        sci-Plex                    2653                 2
# 4   L1000 Phase I      Tahoe-100M                     610                 3
# 5  L1000 Phase II        CIGS-MCE                     508                 1
# 6  L1000 Phase II        sci-Plex                    3133                 2
# 7  L1000 Phase II      Tahoe-100M                    1473                 2
# 8      Tahoe-100M        sci-Plex                     170                 1
#
#    n_matching_drugs  n_matching_conditions  n_matching_drug_line_times  \
# 0               974                   1910                        1910
# 1               124                    127                         127
# 2               257                   2836                        1060
# 3                90                    285                         162
# 4                86                    152                         114
# 5                68                     68                          68
# 6                83                    375                         127
# 7               110                    402                         134
# 8                23                     69                          23
#
#    mean_common_genes  mean_global_common_genes  mean_left_mean_abs_t  ...  \
# 0        1821.904712                740.423037              0.892019  ...
# 1         857.511811                748.685039              1.284738  ...
# 2         978.000000                884.999057              1.263072  ...
# 3         776.790123                769.024691              1.376499  ...
# 4         940.903509                691.903509              1.112814  ...
# 5         852.000000                751.000000              1.959858  ...
# 6         809.448819                803.559055              1.198436  ...
# 7         941.000000                879.746269              0.937878  ...
# 8        6742.000000                599.000000              1.301665  ...
#
#    mean_right_baseline_spearman_logfc  \
# 0                            0.101761
# 1                            0.311305
# 2                            0.270612
# 3                            0.242426
# 4                            0.378645
# 5                            0.329177
# 6                            0.230082
# 7                            0.417183
# 8                            0.220218
#
#    mean_right_baseline_spearman_logfc_global  mean_right_baseline_spearman_t  \
# 0                                   0.098890                        0.114501
# 1                                   0.308836                        0.313621
# 2                                   0.270465                        0.283488
# 3                                   0.242382                        0.245101
# 4                                   0.398448                        0.399722
# 5                                   0.322873                        0.317990
# 6                                   0.230075                        0.233876
# 7                                   0.422610                        0.442152
# 8                                   0.230437                        0.219530
#
#    mean_right_baseline_spearman_t_global  \
# 0                               0.114335
# 1                               0.312186
# 2                               0.283430
# 3                               0.245165
# 4                               0.411569
# 5                               0.313309
# 6                               0.233869
# 7                               0.445580
# 8                               0.224634
#
#    mean_right_baseline_signed_overlap_t_top50  \
# 0                                    0.082026
# 1                                    0.220472
# 2                                    0.225603
# 3                                    0.177142
# 4                                    0.219842
# 5                                    0.231324
# 6                                    0.163084
# 7                                    0.245722
# 8                                    0.047065
#
#    mean_right_baseline_signed_overlap_t_top50_global  \
# 0                                           0.128466
# 1                                           0.226850
# 2                                           0.233581
# 3                                           0.178183
# 4                                           0.259364
# 5                                           0.234853
# 6                                           0.164374
# 7                                           0.255126
# 8                                           0.171159
#
#    mean_left_baseline_peer_count  mean_right_baseline_peer_count  \
# 0                   11469.318848                     2125.535079
# 1                     162.330709                    11427.637795
# 2                    2313.117741                      689.235045
# 3                    4272.128825                      180.745964
# 4                    3189.242168                      377.705044
# 5                     130.808824                    11415.941176
# 6                     911.512599                      182.581014
# 7                    1266.545136                      376.639239
# 8                     376.416667                      180.463768
#
#    n_pair_baselines_available  n_pair_baselines_available_global
# 0                        1910                               1910
# 1                         127                                127
# 2                        1060                               1060
# 3                         162                                162
# 4                         114                                114
# 5                          68                                 68
# 6                         127                                127
# 7                         134                                134
# 8                          23                                 23
#
# [9 rows x 43 columns]
#          dataset_a       dataset_b  cell_type  n_matched_sample_pairs  \
# 0         CIGS-MCE        CIGS-TCM  CVCL_0062                    7842
# 1         CIGS-MCE        CIGS-TCM  CVCL_0063                    8122
# 2    L1000 Phase I        CIGS-MCE  CVCL_0062                    1047
# 3    L1000 Phase I        CIGS-MCE  CVCL_0063                     354
# 4    L1000 Phase I  L1000 Phase II  CVCL_0023                    8049
# 5    L1000 Phase I  L1000 Phase II  CVCL_0031                   11741
# 6    L1000 Phase I  L1000 Phase II  CVCL_0033                    3143
# 7    L1000 Phase I  L1000 Phase II  CVCL_0035                    6722
# 8    L1000 Phase I  L1000 Phase II  CVCL_0062                    3739
# 9    L1000 Phase I  L1000 Phase II  CVCL_0132                    3121
# 10   L1000 Phase I  L1000 Phase II  CVCL_0178                    2670
# 11   L1000 Phase I  L1000 Phase II  CVCL_0320                    1824
# 12   L1000 Phase I  L1000 Phase II  CVCL_0332                    2220
# 13   L1000 Phase I  L1000 Phase II  CVCL_0598                    2348
# 14   L1000 Phase I  L1000 Phase II  CVCL_5136                    1014
# 15   L1000 Phase I  L1000 Phase II  CVCL_U602                     763
# 16   L1000 Phase I  L1000 Phase II  CVCL_VU89                    1696
# 17   L1000 Phase I  L1000 Phase II        NEU                     617
# 18   L1000 Phase I  L1000 Phase II        NPC                    1028
# 19   L1000 Phase I        sci-Plex  CVCL_0023                     892
# 20   L1000 Phase I        sci-Plex  CVCL_0031                    1761
# 21   L1000 Phase I      Tahoe-100M  CVCL_0023                     402
# 22   L1000 Phase I      Tahoe-100M  CVCL_0320                      96
# 23   L1000 Phase I      Tahoe-100M  CVCL_0332                     112
# 24  L1000 Phase II        CIGS-MCE  CVCL_0062                     508
# 25  L1000 Phase II        sci-Plex  CVCL_0023                    1356
# 26  L1000 Phase II        sci-Plex  CVCL_0031                    1777
# 27  L1000 Phase II      Tahoe-100M  CVCL_0023                     389
# 28  L1000 Phase II      Tahoe-100M  CVCL_0320                    1084
# 29      Tahoe-100M        sci-Plex  CVCL_0023                     170
#
#     n_matching_drugs  n_matching_conditions  n_matching_drug_line_times  \
# 0                948                    948                         948
# 1                962                    962                         962
# 2                113                    113                         113
# 3                 14                     14                          14
# 4                152                    237                         163
# 5                179                    615                         179
# 6                 63                    247                          63
# 7                118                    190                         118
# 8                 94                    370                          94
# 9                 43                    114                          48
# 10                63                    251                          63
# 11                34                     68                          34
# 12                63                    251                          63
# 13                63                    250                          63
# 14                31                     61                          31
# 15                34                     34                          34
# 16                39                     74                          39
# 17                33                     36                          33
# 18                35                     38                          35
# 19                74                    111                          74
# 20                88                    174                          88
# 21                83                     95                          83
# 22                20                     24                          20
# 23                11                     33                          11
# 24                68                     68                          68
# 25                44                    128                          44
# 26                83                    247                          83
# 27                24                     72                          24
# 28               110                    330                         110
# 29                23                     69                          23
#
#     mean_common_genes  mean_global_common_genes  mean_left_mean_abs_t  ...  \
# 0              1835.0                     751.0              0.933403  ...
# 1              1809.0                     730.0              0.851236  ...
# 2               852.0                     751.0              1.254855  ...
# 3               902.0                     730.0              1.525929  ...
# 4               978.0                     599.0              1.408337  ...
# 5               978.0                     912.0              1.327026  ...
# 6               978.0                     978.0              1.124445  ...
# 7               978.0                     978.0              1.429081  ...
# 8               978.0                     751.0              1.061750  ...
# 9               978.0                     978.0              1.654690  ...
# 10              978.0                     978.0              1.073211  ...
# 11              978.0                     941.0              1.427466  ...
# 12              978.0                     940.0              0.995701  ...
# 13              978.0                     978.0              1.066221  ...
# 14              978.0                     978.0              1.285483  ...
# 15              978.0                     978.0              1.172477  ...
# 16              978.0                     978.0              1.365667  ...
# 17              978.0                     978.0              0.919215  ...
# 18              978.0                     978.0              1.248631  ...
# 19              616.0                     599.0              1.314957  ...
# 20              912.0                     912.0              1.428250  ...
# 21              941.0                     599.0              1.111431  ...
# 22              941.0                     941.0              1.162661  ...
# 23              940.0                     940.0              1.032621  ...
# 24              852.0                     751.0              1.959858  ...
# 25              616.0                     599.0              1.165221  ...
# 26              912.0                     912.0              1.216043  ...
# 27              941.0                     599.0              1.127679  ...
# 28              941.0                     941.0              0.896467  ...
# 29             6742.0                     599.0              1.301665  ...
#
#     mean_right_baseline_spearman_logfc  \
# 0                             0.099040
# 1                             0.104442
# 2                             0.337820
# 3                             0.097288
# 4                             0.364488
# 5                             0.206479
# 6                             0.241826
# 7                             0.174755
# 8                             0.334215
# 9                             0.357825
# 10                            0.243578
# 11                            0.217163
# 12                            0.330316
# 13                            0.406931
# 14                            0.267668
# 15                            0.220116
# 16                            0.223309
# 17                            0.171193
# 18                            0.193375
# 19                            0.249503
# 20                            0.236475
# 21                            0.374457
# 22                            0.372820
# 23                            0.420836
# 24                            0.329177
# 25                            0.225331
# 26                            0.232602
# 27                            0.424872
# 28                            0.415506
# 29                            0.220218
#
#     mean_right_baseline_spearman_logfc_global  mean_right_baseline_spearman_t  \
# 0                                    0.099509                        0.108725
# 1                                    0.098280                        0.120193
# 2                                    0.334799                        0.340145
# 3                                    0.099276                        0.099536
# 4                                    0.360175                        0.378248
# 5                                    0.208407                        0.214202
# 6                                    0.241826                        0.250907
# 7                                    0.174755                        0.190778
# 8                                    0.336342                        0.351789
# 9                                    0.357825                        0.366917
# 10                                   0.243578                        0.255531
# 11                                   0.217812                        0.233676
# 12                                   0.330049                        0.340176
# 13                                   0.406931                        0.421580
# 14                                   0.267668                        0.287118
# 15                                   0.220116                        0.227223
# 16                                   0.223309                        0.230759
# 17                                   0.171193                        0.186245
# 18                                   0.193375                        0.220889
# 19                                   0.249407                        0.244304
# 20                                   0.236475                        0.245771
# 21                                   0.401657                        0.396202
# 22                                   0.372820                        0.395457
# 23                                   0.420836                        0.434037
# 24                                   0.322873                        0.317990
# 25                                   0.225309                        0.221556
# 26                                   0.232602                        0.240406
# 27                                   0.455171                        0.444681
# 28                                   0.415506                        0.441600
# 29                                   0.230437                        0.219530
#
#     mean_right_baseline_spearman_t_global  \
# 0                                0.110631
# 1                                0.117984
# 2                                0.337882
# 3                                0.104789
# 4                                0.373357
# 5                                0.217102
# 6                                0.250907
# 7                                0.190778
# 8                                0.354218
# 9                                0.366917
# 10                               0.255531
# 11                               0.233950
# 12                               0.339901
# 13                               0.421580
# 14                               0.287118
# 15                               0.227223
# 16                               0.230759
# 17                               0.186245
# 18                               0.220889
# 19                               0.244444
# 20                               0.245771
# 21                               0.412473
# 22                               0.395457
# 23                               0.434037
# 24                               0.313309
# 25                               0.221538
# 26                               0.240406
# 27                               0.463824
# 28                               0.441600
# 29                               0.224634
#
#     mean_right_baseline_signed_overlap_t_top50  \
# 0                                     0.082669
# 1                                     0.081393
# 2                                     0.237699
# 3                                     0.081429
# 4                                     0.279092
# 5                                     0.192707
# 6                                     0.205083
# 7                                     0.196347
# 8                                     0.255094
# 9                                     0.272888
# 10                                    0.182576
# 11                                    0.214674
# 12                                    0.226986
# 13                                    0.311199
# 14                                    0.250294
# 15                                    0.162941
# 16                                    0.205726
# 17                                    0.154288
# 18                                    0.197860
# 19                                    0.185595
# 20                                    0.170035
# 21                                    0.215192
# 22                                    0.233188
# 23                                    0.230658
# 24                                    0.231324
# 25                                    0.164765
# 26                                    0.162194
# 27                                    0.239100
# 28                                    0.247167
# 29                                    0.047065
#
#     mean_right_baseline_signed_overlap_t_top50_global  \
# 0                                            0.127247
# 1                                            0.129667
# 2                                            0.243805
# 3                                            0.090000
# 4                                            0.314775
# 5                                            0.197176
# 6                                            0.205083
# 7                                            0.196347
# 8                                            0.271010
# 9                                            0.272888
# 10                                           0.182576
# 11                                           0.215044
# 12                                           0.231568
# 13                                           0.311199
# 14                                           0.250294
# 15                                           0.162941
# 16                                           0.205726
# 17                                           0.154288
# 18                                           0.197860
# 19                                           0.187872
# 20                                           0.170035
# 21                                           0.269476
# 22                                           0.233188
# 23                                           0.230658
# 24                                           0.234853
# 25                                           0.168488
# 26                                           0.162194
# 27                                           0.291604
# 28                                           0.247167
# 29                                           0.171159
#
#     mean_left_baseline_peer_count  mean_right_baseline_peer_count  \
# 0                    11415.955696                     2126.506329
# 1                    11521.905405                     2124.577963
# 2                      178.973451                    11415.955752
# 3                       28.000000                    11521.928571
# 4                     3941.918881                      280.824366
# 5                     3692.950055                     1295.424585
# 6                      255.482303                      132.584103
# 7                     5167.563092                     1703.439025
# 8                      180.285186                      133.108215
# 9                     1585.930526                     1140.163856
# 10                     181.452750                      121.857143
# 11                     656.112496                     1562.037162
# 12                     211.124497                      131.090546
# 13                     197.052913                      133.039492
# 14                    1179.267315                      383.090952
# 15                    2722.941176                      266.411765
# 16                    1833.677156                     1551.639422
# 17                    2044.761376                      265.334503
# 18                    2908.923404                      248.710942
# 19                    3934.608742                      178.602584
# 20                    4555.952531                      182.548352
# 21                    4167.534997                      377.875215
# 22                     767.266667                      377.858333
# 23                     211.169913                      376.142316
# 24                     130.808824                    11415.941176
# 25                     327.939215                      180.706831
# 26                    1220.876803                      183.574557
# 27                     328.134447                      376.306185
# 28                    1471.289286                      376.711905
# 29                     376.416667                      180.463768
#
#     n_pair_baselines_available  n_pair_baselines_available_global
# 0                          948                                948
# 1                          962                                962
# 2                          113                                113
# 3                           14                                 14
# 4                          163                                163
# 5                          179                                179
# 6                           63                                 63
# 7                          118                                118
# 8                           94                                 94
# 9                           48                                 48
# 10                          63                                 63
# 11                          34                                 34
# 12                          63                                 63
# 13                          63                                 63
# 14                          31                                 31
# 15                          34                                 34
# 16                          39                                 39
# 17                          33                                 33
# 18                          35                                 35
# 19                          74                                 74
# 20                          88                                 88
# 21                          83                                 83
# 22                          20                                 20
# 23                          11                                 11
# 24                          68                                 68
# 25                          44                                 44
# 26                          83                                 83
# 27                          24                                 24
# 28                         110                                110
# 29                          23                                 23
#
# [30 rows x 43 columns]

# %%
display(pair_metric_summary.pivot(index="dataset_a", columns="dataset_b", values="mean_observed_spearman_logfc"))
display(pair_metric_summary.pivot(index="dataset_a", columns="dataset_b", values="mean_observed_spearman_logfc_global"))
# Out:
# dataset_b     cigs_mce  cigs_tcm  l1000_phase2   sciplex     tahoe
# dataset_a
# cigs_mce           NaN  0.028504           NaN       NaN       NaN
# l1000_phase1  0.129478       NaN      0.239247  0.094697  0.037681
# l1000_phase2  0.237153       NaN           NaN  0.102026  0.027033
# tahoe              NaN       NaN           NaN  0.052575       NaN
# dataset_b     cigs_mce  cigs_tcm  l1000_phase2   sciplex     tahoe
# dataset_a
# cigs_mce           NaN  0.025698           NaN       NaN       NaN
# l1000_phase1  0.132632       NaN      0.241742  0.095744  0.044732
# l1000_phase2  0.240140       NaN           NaN  0.102162  0.028212
# tahoe              NaN       NaN           NaN  0.044298       NaN

# %%
display(pair_metric_summary.pivot(index="dataset_a", columns="dataset_b", values="mean_observed_spearman_t"))
display(pair_metric_summary.pivot(index="dataset_a", columns="dataset_b", values="mean_observed_spearman_t_global"))
# Out:
# dataset_b     cigs_mce  cigs_tcm  l1000_phase2   sciplex     tahoe
# dataset_a
# cigs_mce           NaN  0.033923           NaN       NaN       NaN
# l1000_phase1  0.134985       NaN      0.252047  0.097796  0.038882
# l1000_phase2  0.251276       NaN           NaN  0.107800  0.030230
# tahoe              NaN       NaN           NaN  0.053621       NaN
# dataset_b     cigs_mce  cigs_tcm  l1000_phase2   sciplex     tahoe
# dataset_a
# cigs_mce           NaN  0.031358           NaN       NaN       NaN
# l1000_phase1  0.138506       NaN      0.254431  0.098748  0.044413
# l1000_phase2  0.254098       NaN           NaN  0.107875  0.030858
# tahoe              NaN       NaN           NaN  0.046449       NaN

# %%
display(pair_metric_summary.pivot(index="dataset_a", columns="dataset_b", values=f"mean_observed_signed_overlap_t_top{TOP_K}"))
display(pair_metric_summary.pivot(index="dataset_a", columns="dataset_b", values=f"mean_observed_signed_overlap_t_top{TOP_K}_global"))
# Out:
# dataset_b     cigs_mce  cigs_tcm  l1000_phase2   sciplex     tahoe
# dataset_a
# cigs_mce           NaN  0.053455           NaN       NaN       NaN
# l1000_phase1  0.131811       NaN      0.211803  0.115424  0.069840
# l1000_phase2  0.185588       NaN           NaN  0.115262  0.069446
# tahoe              NaN       NaN           NaN  0.025254       NaN
# dataset_b     cigs_mce  cigs_tcm  l1000_phase2   sciplex     tahoe
# dataset_a
# cigs_mce           NaN  0.092963           NaN       NaN       NaN
# l1000_phase1  0.140079       NaN      0.219074  0.116428  0.093461
# l1000_phase2  0.195000       NaN           NaN  0.116121  0.074681
# tahoe              NaN       NaN           NaN  0.110242       NaN

# %% [markdown]
# Baseline-adjusted final scores:
#
# For each matched sample pair, these scores subtract the within-dataset same-line / same-time / same-dose other-compound baseline from the observed cross-dataset score. The subtraction is done separately for dataset A and dataset B on the same shared-gene subset used for the observed cross-dataset score, then averaged across the two sides.

# %%
drug_line_time_group_columns = ["dataset_a", "dataset_b", "cell_type", "time_key", "pubchem_cid"]
baseline_adjusted_metrics = matched_pair_metrics.copy()

metric_names = [
    "spearman_logfc",
    "spearman_t",
    f"signed_overlap_t_top{TOP_K}",
    "spearman_logfc_global",
    "spearman_t_global",
    f"signed_overlap_t_top{TOP_K}_global",
]

for metric_name in metric_names:
    observed_col = f"observed_{metric_name}"
    left_baseline_col = f"left_baseline_{metric_name}"
    right_baseline_col = f"right_baseline_{metric_name}"

    left_delta_col = f"delta_vs_left_baseline_{metric_name}"
    right_delta_col = f"delta_vs_right_baseline_{metric_name}"
    pair_mean_delta_col = f"delta_pair_mean_{metric_name}"

    baseline_adjusted_metrics[left_delta_col] = (
        baseline_adjusted_metrics[observed_col] - baseline_adjusted_metrics[left_baseline_col]
    )
    baseline_adjusted_metrics[right_delta_col] = (
        baseline_adjusted_metrics[observed_col] - baseline_adjusted_metrics[right_baseline_col]
    )
    baseline_adjusted_metrics[pair_mean_delta_col] = baseline_adjusted_metrics[
        [left_delta_col, right_delta_col]
    ].mean(axis=1)

baseline_adjusted_metrics_path = OUTPUT_DIR / "matched_sample_pair_metrics_baseline_adjusted.tsv"
baseline_adjusted_metrics.to_csv(baseline_adjusted_metrics_path, sep="	", index=False)
print(f"Saved baseline-adjusted matched-pair metrics to {baseline_adjusted_metrics_path}")

mean_delta_columns = {
    "mean_delta_pair_mean_spearman_logfc": "delta_pair_mean_spearman_logfc",
    "mean_delta_pair_mean_spearman_t": "delta_pair_mean_spearman_t",
    f"mean_delta_pair_mean_signed_overlap_t_top{TOP_K}": f"delta_pair_mean_signed_overlap_t_top{TOP_K}",
    "mean_delta_pair_mean_spearman_logfc_global": "delta_pair_mean_spearman_logfc_global",
    "mean_delta_pair_mean_spearman_t_global": "delta_pair_mean_spearman_t_global",
    f"mean_delta_pair_mean_signed_overlap_t_top{TOP_K}_global": f"delta_pair_mean_signed_overlap_t_top{TOP_K}_global",
    "mean_delta_vs_left_baseline_spearman_logfc": "delta_vs_left_baseline_spearman_logfc",
    "mean_delta_vs_left_baseline_spearman_t": "delta_vs_left_baseline_spearman_t",
    f"mean_delta_vs_left_baseline_signed_overlap_t_top{TOP_K}": f"delta_vs_left_baseline_signed_overlap_t_top{TOP_K}",
    "mean_delta_vs_left_baseline_spearman_logfc_global": "delta_vs_left_baseline_spearman_logfc_global",
    "mean_delta_vs_left_baseline_spearman_t_global": "delta_vs_left_baseline_spearman_t_global",
    f"mean_delta_vs_left_baseline_signed_overlap_t_top{TOP_K}_global": f"delta_vs_left_baseline_signed_overlap_t_top{TOP_K}_global",
    "mean_delta_vs_right_baseline_spearman_logfc": "delta_vs_right_baseline_spearman_logfc",
    "mean_delta_vs_right_baseline_spearman_t": "delta_vs_right_baseline_spearman_t",
    f"mean_delta_vs_right_baseline_signed_overlap_t_top{TOP_K}": f"delta_vs_right_baseline_signed_overlap_t_top{TOP_K}",
    "mean_delta_vs_right_baseline_spearman_logfc_global": "delta_vs_right_baseline_spearman_logfc_global",
    "mean_delta_vs_right_baseline_spearman_t_global": "delta_vs_right_baseline_spearman_t_global",
    f"mean_delta_vs_right_baseline_signed_overlap_t_top{TOP_K}_global": f"delta_vs_right_baseline_signed_overlap_t_top{TOP_K}_global",
}

drug_line_time_delta_agg = {
    "n_matched_sample_pairs": ("left_obs_id", "size"),
    "n_matching_conditions": ("matched_condition_key", "nunique"),
}
for target_column, source_column in mean_delta_columns.items():
    drug_line_time_delta_agg[target_column] = (source_column, "mean")
drug_line_time_delta_agg["n_pair_mean_deltas_available"] = (
    "delta_pair_mean_spearman_logfc",
    lambda values: int(values.notna().sum()),
)
drug_line_time_delta_agg["n_pair_mean_deltas_available_global"] = (
    "delta_pair_mean_spearman_logfc_global",
    lambda values: int(values.notna().sum()),
)

drug_line_time_metric_baseline_adjusted_summary = (
    baseline_adjusted_metrics.groupby(drug_line_time_group_columns, as_index=False)
    .agg(**drug_line_time_delta_agg)
    .sort_values(drug_line_time_group_columns)
    .reset_index(drop=True)
)
drug_line_time_metric_baseline_adjusted_summary_path = OUTPUT_DIR / "matched_drug_line_time_metric_baseline_adjusted_summary.tsv"
drug_line_time_metric_baseline_adjusted_summary.to_csv(drug_line_time_metric_baseline_adjusted_summary_path, sep="	", index=False)
print(f"Saved drug-line-time baseline-adjusted summary to {drug_line_time_metric_baseline_adjusted_summary_path}")

summary_mean_delta_columns = [
    column_name
    for column_name in drug_line_time_metric_baseline_adjusted_summary.columns
    if column_name.startswith("mean_delta_")
]

pair_delta_agg = {
    "n_matched_sample_pairs": ("n_matched_sample_pairs", "sum"),
    "n_matching_lines": ("cell_type", "nunique"),
    "n_matching_drugs": ("pubchem_cid", "nunique"),
    "n_matching_conditions": ("n_matching_conditions", "sum"),
    "n_matching_drug_line_times": ("pubchem_cid", "size"),
}
for column_name in summary_mean_delta_columns:
    pair_delta_agg[column_name] = (column_name, "mean")
pair_delta_agg["n_pair_mean_deltas_available"] = (
    "mean_delta_pair_mean_spearman_logfc",
    lambda values: int(values.notna().sum()),
)
pair_delta_agg["n_pair_mean_deltas_available_global"] = (
    "mean_delta_pair_mean_spearman_logfc_global",
    lambda values: int(values.notna().sum()),
)

pair_metric_baseline_adjusted_summary = (
    drug_line_time_metric_baseline_adjusted_summary.groupby(["dataset_a", "dataset_b"], as_index=False)
    .agg(**pair_delta_agg)
    .sort_values(["dataset_a", "dataset_b"])
    .reset_index(drop=True)
)

line_delta_agg = {
    "n_matched_sample_pairs": ("n_matched_sample_pairs", "sum"),
    "n_matching_drugs": ("pubchem_cid", "nunique"),
    "n_matching_conditions": ("n_matching_conditions", "sum"),
    "n_matching_drug_line_times": ("pubchem_cid", "size"),
}
for column_name in summary_mean_delta_columns:
    line_delta_agg[column_name] = (column_name, "mean")
line_delta_agg["n_pair_mean_deltas_available"] = (
    "mean_delta_pair_mean_spearman_logfc",
    lambda values: int(values.notna().sum()),
)
line_delta_agg["n_pair_mean_deltas_available_global"] = (
    "mean_delta_pair_mean_spearman_logfc_global",
    lambda values: int(values.notna().sum()),
)

line_metric_baseline_adjusted_summary = (
    drug_line_time_metric_baseline_adjusted_summary.groupby(["dataset_a", "dataset_b", "cell_type"], as_index=False)
    .agg(**line_delta_agg)
    .sort_values(["dataset_a", "dataset_b", "cell_type"])
    .reset_index(drop=True)
)

pair_metric_baseline_adjusted_summary_path = OUTPUT_DIR / "dataset_pair_metric_baseline_adjusted_summary.tsv"
line_metric_baseline_adjusted_summary_path = OUTPUT_DIR / "dataset_pair_line_metric_baseline_adjusted_summary.tsv"
pair_metric_baseline_adjusted_summary.to_csv(pair_metric_baseline_adjusted_summary_path, sep="	", index=False)
line_metric_baseline_adjusted_summary.to_csv(line_metric_baseline_adjusted_summary_path, sep="	", index=False)
print(f"Saved baseline-adjusted dataset-pair summary to {pair_metric_baseline_adjusted_summary_path}")
print(f"Saved baseline-adjusted dataset-pair-line summary to {line_metric_baseline_adjusted_summary_path}")

pair_metric_baseline_adjusted_summary_display = pair_metric_baseline_adjusted_summary.copy()
pair_metric_baseline_adjusted_summary_display["dataset_a"] = pair_metric_baseline_adjusted_summary_display["dataset_a"].map(pretty_label)
pair_metric_baseline_adjusted_summary_display["dataset_b"] = pair_metric_baseline_adjusted_summary_display["dataset_b"].map(pretty_label)
display(pair_metric_baseline_adjusted_summary_display)

line_metric_baseline_adjusted_summary_display = line_metric_baseline_adjusted_summary.copy()
line_metric_baseline_adjusted_summary_display["dataset_a"] = line_metric_baseline_adjusted_summary_display["dataset_a"].map(pretty_label)
line_metric_baseline_adjusted_summary_display["dataset_b"] = line_metric_baseline_adjusted_summary_display["dataset_b"].map(pretty_label)
display(line_metric_baseline_adjusted_summary_display)
# Out:
# Saved baseline-adjusted matched-pair metrics to /home/cirro/Chem-PerturBridge_analysis/results/production_runs/overlap_signature_similarity_group_rep/full_production/matched_sample_pair_metrics_baseline_adjusted.tsv
# Saved drug-line-time baseline-adjusted summary to /home/cirro/Chem-PerturBridge_analysis/results/production_runs/overlap_signature_similarity_group_rep/full_production/matched_drug_line_time_metric_baseline_adjusted_summary.tsv
# Saved baseline-adjusted dataset-pair summary to /home/cirro/Chem-PerturBridge_analysis/results/production_runs/overlap_signature_similarity_group_rep/full_production/dataset_pair_metric_baseline_adjusted_summary.tsv
# Saved baseline-adjusted dataset-pair-line summary to /home/cirro/Chem-PerturBridge_analysis/results/production_runs/overlap_signature_similarity_group_rep/full_production/dataset_pair_line_metric_baseline_adjusted_summary.tsv
#         dataset_a       dataset_b  n_matched_sample_pairs  n_matching_lines  \
# 0        CIGS-MCE        CIGS-TCM                   15964                 2
# 1   L1000 Phase I        CIGS-MCE                    1401                 2
# 2   L1000 Phase I  L1000 Phase II                   50695                15
# 3   L1000 Phase I        sci-Plex                    2653                 2
# 4   L1000 Phase I      Tahoe-100M                     610                 3
# 5  L1000 Phase II        CIGS-MCE                     508                 1
# 6  L1000 Phase II        sci-Plex                    3133                 2
# 7  L1000 Phase II      Tahoe-100M                    1473                 2
# 8      Tahoe-100M        sci-Plex                     170                 1
#
#    n_matching_drugs  n_matching_conditions  n_matching_drug_line_times  \
# 0               974                   1910                        1910
# 1               124                    127                         127
# 2               257                   2836                        1060
# 3                90                    285                         162
# 4                86                    152                         114
# 5                68                     68                          68
# 6                83                    375                         127
# 7               110                    402                         134
# 8                23                     69                          23
#
#    mean_delta_pair_mean_spearman_logfc  mean_delta_pair_mean_spearman_t  \
# 0                            -0.112237                        -0.119686
# 1                            -0.229987                        -0.230676
# 2                            -0.048442                        -0.047084
# 3                            -0.169095                        -0.172284
# 4                            -0.236574                        -0.255859
# 5                            -0.171026                        -0.159631
# 6                            -0.102361                        -0.103945
# 7                            -0.249328                        -0.261580
# 8                            -0.285875                        -0.291656
#
#    mean_delta_pair_mean_signed_overlap_t_top50  ...  \
# 0                                    -0.038217  ...
# 1                                    -0.117323  ...
# 2                                    -0.002126  ...
# 3                                    -0.081913  ...
# 4                                    -0.121689  ...
# 5                                    -0.116838  ...
# 6                                    -0.059501  ...
# 7                                    -0.117596  ...
# 8                                    -0.060236  ...
#
#    mean_delta_vs_left_baseline_spearman_t_global  \
# 0                                      -0.152098
# 1                                      -0.278519
# 2                                      -0.060803
# 3                                      -0.196705
# 4                                      -0.142486
# 5                                      -0.249284
# 6                                      -0.082337
# 7                                      -0.108433
# 8                                      -0.421355
#
#    mean_delta_vs_left_baseline_signed_overlap_t_top50_global  \
# 0                                          -0.061958
# 1                                          -0.146378
# 2                                           0.007186
# 3                                          -0.102922
# 4                                          -0.095958
# 5                                          -0.183529
# 6                                          -0.071968
# 7                                          -0.059943
# 8                                          -0.177959
#
#    mean_delta_vs_right_baseline_spearman_logfc  \
# 0                                    -0.073257
# 1                                    -0.181827
# 2                                    -0.030978
# 3                                    -0.147729
# 4                                    -0.340964
# 5                                    -0.092024
# 6                                    -0.128057
# 7                                    -0.390150
# 8                                    -0.167643
#
#    mean_delta_vs_right_baseline_spearman_t  \
# 0                                -0.080578
# 1                                -0.178636
# 2                                -0.031065
# 3                                -0.147305
# 4                                -0.360840
# 5                                -0.066713
# 6                                -0.126076
# 7                                -0.411922
# 8                                -0.165910
#
#    mean_delta_vs_right_baseline_signed_overlap_t_top50  \
# 0                                          -0.028571
# 1                                          -0.088661
# 2                                          -0.013714
# 3                                          -0.061718
# 4                                          -0.150001
# 5                                          -0.045735
# 6                                          -0.047822
# 7                                          -0.176276
# 8                                          -0.021812
#
#    mean_delta_vs_right_baseline_spearman_logfc_global  \
# 0                                          -0.073192
# 1                                          -0.176204
# 2                                          -0.028313
# 3                                          -0.146638
# 4                                          -0.353716
# 5                                          -0.082734
# 6                                          -0.127913
# 7                                          -0.394398
# 8                                          -0.186139
#
#    mean_delta_vs_right_baseline_spearman_t_global  \
# 0                                       -0.082976
# 1                                       -0.173680
# 2                                       -0.028602
# 3                                       -0.146416
# 4                                       -0.367155
# 5                                       -0.059211
# 6                                       -0.125994
# 7                                       -0.414722
# 8                                       -0.178186
#
#    mean_delta_vs_right_baseline_signed_overlap_t_top50_global  \
# 0                                          -0.035503
# 1                                          -0.086772
# 2                                          -0.014399
# 3                                          -0.061754
# 4                                          -0.165903
# 5                                          -0.039853
# 6                                          -0.048254
# 7                                          -0.180444
# 8                                          -0.060918
#
#    n_pair_mean_deltas_available  n_pair_mean_deltas_available_global
# 0                          1910                                 1910
# 1                           127                                  127
# 2                          1060                                 1060
# 3                           162                                  162
# 4                           114                                  114
# 5                            68                                   68
# 6                           127                                  127
# 7                           134                                  134
# 8                            23                                   23
#
# [9 rows x 27 columns]
#          dataset_a       dataset_b  cell_type  n_matched_sample_pairs  \
# 0         CIGS-MCE        CIGS-TCM  CVCL_0062                    7842
# 1         CIGS-MCE        CIGS-TCM  CVCL_0063                    8122
# 2    L1000 Phase I        CIGS-MCE  CVCL_0062                    1047
# 3    L1000 Phase I        CIGS-MCE  CVCL_0063                     354
# 4    L1000 Phase I  L1000 Phase II  CVCL_0023                    8049
# 5    L1000 Phase I  L1000 Phase II  CVCL_0031                   11741
# 6    L1000 Phase I  L1000 Phase II  CVCL_0033                    3143
# 7    L1000 Phase I  L1000 Phase II  CVCL_0035                    6722
# 8    L1000 Phase I  L1000 Phase II  CVCL_0062                    3739
# 9    L1000 Phase I  L1000 Phase II  CVCL_0132                    3121
# 10   L1000 Phase I  L1000 Phase II  CVCL_0178                    2670
# 11   L1000 Phase I  L1000 Phase II  CVCL_0320                    1824
# 12   L1000 Phase I  L1000 Phase II  CVCL_0332                    2220
# 13   L1000 Phase I  L1000 Phase II  CVCL_0598                    2348
# 14   L1000 Phase I  L1000 Phase II  CVCL_5136                    1014
# 15   L1000 Phase I  L1000 Phase II  CVCL_U602                     763
# 16   L1000 Phase I  L1000 Phase II  CVCL_VU89                    1696
# 17   L1000 Phase I  L1000 Phase II        NEU                     617
# 18   L1000 Phase I  L1000 Phase II        NPC                    1028
# 19   L1000 Phase I        sci-Plex  CVCL_0023                     892
# 20   L1000 Phase I        sci-Plex  CVCL_0031                    1761
# 21   L1000 Phase I      Tahoe-100M  CVCL_0023                     402
# 22   L1000 Phase I      Tahoe-100M  CVCL_0320                      96
# 23   L1000 Phase I      Tahoe-100M  CVCL_0332                     112
# 24  L1000 Phase II        CIGS-MCE  CVCL_0062                     508
# 25  L1000 Phase II        sci-Plex  CVCL_0023                    1356
# 26  L1000 Phase II        sci-Plex  CVCL_0031                    1777
# 27  L1000 Phase II      Tahoe-100M  CVCL_0023                     389
# 28  L1000 Phase II      Tahoe-100M  CVCL_0320                    1084
# 29      Tahoe-100M        sci-Plex  CVCL_0023                     170
#
#     n_matching_drugs  n_matching_conditions  n_matching_drug_line_times  \
# 0                948                    948                         948
# 1                962                    962                         962
# 2                113                    113                         113
# 3                 14                     14                          14
# 4                152                    237                         163
# 5                179                    615                         179
# 6                 63                    247                          63
# 7                118                    190                         118
# 8                 94                    370                          94
# 9                 43                    114                          48
# 10                63                    251                          63
# 11                34                     68                          34
# 12                63                    251                          63
# 13                63                    250                          63
# 14                31                     61                          31
# 15                34                     34                          34
# 16                39                     74                          39
# 17                33                     36                          33
# 18                35                     38                          35
# 19                74                    111                          74
# 20                88                    174                          88
# 21                83                     95                          83
# 22                20                     24                          20
# 23                11                     33                          11
# 24                68                     68                          68
# 25                44                    128                          44
# 26                83                    247                          83
# 27                24                     72                          24
# 28               110                    330                         110
# 29                23                     69                          23
#
#     mean_delta_pair_mean_spearman_logfc  mean_delta_pair_mean_spearman_t  \
# 0                             -0.148987                        -0.158347
# 1                             -0.076021                        -0.081587
# 2                             -0.222543                        -0.221882
# 3                             -0.290072                        -0.301660
# 4                             -0.041845                        -0.031082
# 5                             -0.067527                        -0.063241
# 6                             -0.095450                        -0.096252
# 7                              0.008260                         0.012776
# 8                             -0.061352                        -0.064525
# 9                             -0.003917                        -0.010161
# 10                            -0.073109                        -0.078647
# 11                             0.035284                         0.032217
# 12                            -0.055255                        -0.048529
# 13                            -0.074241                        -0.087625
# 14                             0.091346                         0.093188
# 15                            -0.133033                        -0.126809
# 16                             0.045712                         0.048882
# 17                            -0.206639                        -0.210829
# 18                            -0.090130                        -0.100062
# 19                            -0.152330                        -0.151082
# 20                            -0.183193                        -0.190113
# 21                            -0.228394                        -0.250113
# 22                            -0.244222                        -0.256938
# 23                            -0.284386                        -0.297258
# 24                            -0.171026                        -0.159631
# 25                            -0.122688                        -0.124151
# 26                            -0.091586                        -0.093234
# 27                            -0.280436                        -0.293332
# 28                            -0.242541                        -0.254652
# 29                            -0.285875                        -0.291656
#
#     mean_delta_pair_mean_signed_overlap_t_top50  ...  \
# 0                                     -0.054884  ...
# 1                                     -0.021793  ...
# 2                                     -0.110531  ...
# 3                                     -0.172143  ...
# 4                                      0.006622  ...
# 5                                     -0.010845  ...
# 6                                     -0.022323  ...
# 7                                      0.020078  ...
# 8                                     -0.027433  ...
# 9                                      0.023405  ...
# 10                                    -0.011840  ...
# 11                                     0.051343  ...
# 12                                     0.002686  ...
# 13                                    -0.050902  ...
# 14                                     0.069144  ...
# 15                                    -0.016176  ...
# 16                                     0.052132  ...
# 17                                    -0.051909  ...
# 18                                    -0.022157  ...
# 19                                    -0.073097  ...
# 20                                    -0.089326  ...
# 21                                    -0.116675  ...
# 22                                    -0.138198  ...
# 23                                    -0.129502  ...
# 24                                    -0.116838  ...
# 25                                    -0.058827  ...
# 26                                    -0.059859  ...
# 27                                    -0.131637  ...
# 28                                    -0.114532  ...
# 29                                    -0.060236  ...
#
#     mean_delta_vs_left_baseline_spearman_t_global  \
# 0                                       -0.226050
# 1                                       -0.079223
# 2                                       -0.245571
# 3                                       -0.544457
# 4                                        0.039457
# 5                                       -0.132149
# 6                                       -0.112805
# 7                                       -0.046375
# 8                                       -0.045676
# 9                                       -0.050322
# 10                                      -0.102192
# 11                                      -0.048122
# 12                                      -0.011481
# 13                                      -0.037628
# 14                                       0.098038
# 15                                      -0.123634
# 16                                      -0.023150
# 17                                      -0.289199
# 18                                      -0.141004
# 19                                      -0.139000
# 20                                      -0.245230
# 21                                      -0.118670
# 22                                      -0.219614
# 23                                      -0.193817
# 24                                      -0.249284
# 25                                      -0.123859
# 26                                      -0.060325
# 27                                      -0.172110
# 28                                      -0.094540
# 29                                      -0.421355
#
#     mean_delta_vs_left_baseline_signed_overlap_t_top50_global  \
# 0                                           -0.098175
# 1                                           -0.026268
# 2                                           -0.122389
# 3                                           -0.340000
# 4                                            0.039362
# 5                                           -0.025078
# 6                                           -0.000989
# 7                                            0.013037
# 8                                            0.001231
# 9                                            0.004029
# 10                                          -0.018816
# 11                                           0.022663
# 12                                           0.020173
# 13                                           0.008734
# 14                                           0.081476
# 15                                           0.001471
# 16                                           0.032836
# 17                                          -0.040667
# 18                                           0.002267
# 19                                          -0.086080
# 20                                          -0.117085
# 21                                          -0.085867
# 22                                          -0.138681
# 23                                          -0.101275
# 24                                          -0.183529
# 25                                          -0.081224
# 26                                          -0.067061
# 27                                          -0.103526
# 28                                          -0.050434
# 29                                          -0.177959
#
#     mean_delta_vs_right_baseline_spearman_logfc  \
# 0                                     -0.069860
# 1                                     -0.076604
# 2                                     -0.198121
# 3                                     -0.050310
# 4                                     -0.095639
# 5                                      0.010171
# 6                                     -0.084513
# 7                                      0.070402
# 8                                     -0.070672
# 9                                      0.022993
# 10                                    -0.051776
# 11                                     0.103264
# 12                                    -0.092419
# 13                                    -0.123386
# 14                                     0.087650
# 15                                    -0.131979
# 16                                     0.111323
# 17                                    -0.120154
# 18                                    -0.037855
# 19                                    -0.170401
# 20                                    -0.128664
# 21                                    -0.346774
# 22                                    -0.291794
# 23                                    -0.386530
# 24                                    -0.092024
# 25                                    -0.134807
# 26                                    -0.124479
# 27                                    -0.382752
# 28                                    -0.391765
# 29                                    -0.167643
#
#     mean_delta_vs_right_baseline_spearman_t  \
# 0                                 -0.074026
# 1                                 -0.087035
# 2                                 -0.194416
# 3                                 -0.051269
# 4                                 -0.090234
# 5                                  0.014861
# 6                                 -0.079699
# 7                                  0.073057
# 8                                 -0.078612
# 9                                  0.020599
# 10                                -0.055103
# 11                                 0.099176
# 12                                -0.084052
# 13                                -0.137622
# 14                                 0.088338
# 15                                -0.129985
# 16                                 0.116896
# 17                                -0.132458
# 18                                -0.059121
# 19                                -0.161943
# 20                                -0.134995
# 21                                -0.367986
# 22                                -0.309262
# 23                                -0.400698
# 24                                -0.066713
# 25                                -0.125948
# 26                                -0.126143
# 27                                -0.398890
# 28                                -0.414765
# 29                                -0.165910
#
#     mean_delta_vs_right_baseline_signed_overlap_t_top50  \
# 0                                           -0.026983
# 1                                           -0.030135
# 2                                           -0.099469
# 3                                           -0.001429
# 4                                           -0.030646
# 5                                           -0.000343
# 6                                           -0.043656
# 7                                            0.027522
# 8                                           -0.059049
# 9                                            0.039411
# 10                                          -0.004864
# 11                                           0.075807
# 12                                          -0.015880
# 13                                          -0.110537
# 14                                           0.056811
# 15                                          -0.033824
# 16                                           0.071202
# 17                                          -0.063150
# 18                                          -0.046581
# 19                                          -0.061896
# 20                                          -0.061568
# 21                                          -0.149680
# 22                                          -0.147083
# 23                                          -0.157729
# 24                                          -0.045735
# 25                                          -0.038702
# 26                                          -0.052657
# 27                                          -0.165482
# 28                                          -0.178631
# 29                                          -0.021812
#
#     mean_delta_vs_right_baseline_spearman_logfc_global  \
# 0                                           -0.072921
# 1                                           -0.073460
# 2                                           -0.192218
# 3                                           -0.046950
# 4                                           -0.085153
# 5                                            0.014002
# 6                                           -0.084513
# 7                                            0.070402
# 8                                           -0.066935
# 9                                            0.022993
# 10                                          -0.051776
# 11                                           0.103154
# 12                                          -0.091308
# 13                                          -0.123386
# 14                                           0.087650
# 15                                          -0.131979
# 16                                           0.111323
# 17                                          -0.120154
# 18                                          -0.037855
# 19                                          -0.168012
# 20                                          -0.128664
# 21                                          -0.364289
# 22                                          -0.291794
# 23                                          -0.386530
# 24                                          -0.082734
# 25                                          -0.134393
# 26                                          -0.124479
# 27                                          -0.406469
# 28                                          -0.391765
# 29                                          -0.186139
#
#     mean_delta_vs_right_baseline_spearman_t_global  \
# 0                                        -0.078786
# 1                                        -0.087106
# 2                                        -0.189145
# 3                                        -0.048862
# 4                                        -0.078429
# 5                                         0.017307
# 6                                        -0.079699
# 7                                         0.073057
# 8                                        -0.077198
# 9                                         0.020599
# 10                                       -0.055103
# 11                                        0.099578
# 12                                       -0.082617
# 13                                       -0.137622
# 14                                        0.088338
# 15                                       -0.129985
# 16                                        0.116896
# 17                                       -0.132458
# 18                                       -0.059121
# 19                                       -0.159998
# 20                                       -0.134995
# 21                                       -0.376660
# 22                                       -0.309262
# 23                                       -0.400698
# 24                                       -0.059211
# 25                                       -0.125712
# 26                                       -0.126143
# 27                                       -0.414528
# 28                                       -0.414765
# 29                                       -0.178186
#
#     mean_delta_vs_right_baseline_signed_overlap_t_top50_global  \
# 0                                           -0.031287
# 1                                           -0.039657
# 2                                           -0.097965
# 3                                            0.003571
# 4                                           -0.036273
# 5                                            0.001303
# 6                                           -0.043656
# 7                                            0.027522
# 8                                           -0.059183
# 9                                            0.039411
# 10                                          -0.004864
# 11                                           0.079854
# 12                                          -0.019415
# 13                                          -0.110537
# 14                                           0.056811
# 15                                          -0.033824
# 16                                           0.071202
# 17                                          -0.063150
# 18                                          -0.046581
# 19                                          -0.061975
# 20                                          -0.061568
# 21                                          -0.171522
# 22                                          -0.147083
# 23                                          -0.157729
# 24                                          -0.039853
# 25                                          -0.039948
# 26                                          -0.052657
# 27                                          -0.188757
# 28                                          -0.178631
# 29                                          -0.060918
#
#     n_pair_mean_deltas_available  n_pair_mean_deltas_available_global
# 0                            948                                  948
# 1                            962                                  962
# 2                            113                                  113
# 3                             14                                   14
# 4                            163                                  163
# 5                            179                                  179
# 6                             63                                   63
# 7                            118                                  118
# 8                             94                                   94
# 9                             48                                   48
# 10                            63                                   63
# 11                            34                                   34
# 12                            63                                   63
# 13                            63                                   63
# 14                            31                                   31
# 15                            34                                   34
# 16                            39                                   39
# 17                            33                                   33
# 18                            35                                   35
# 19                            74                                   74
# 20                            88                                   88
# 21                            83                                   83
# 22                            20                                   20
# 23                            11                                   11
# 24                            68                                   68
# 25                            44                                   44
# 26                            83                                   83
# 27                            24                                   24
# 28                           110                                  110
# 29                            23                                   23
#
# [30 rows x 27 columns]

# %%
import sys

if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

from scripts.cluster_bootstrap_ci import cluster_bca_nested_mean_ci_table, summarize_ci_half_width_ranges

BOOTSTRAP_ITERATIONS = 2000
BOOTSTRAP_RANDOM_SEED = 20260505

signature_ci_metrics = {
    "observed_spearman_logfc": "mean_observed_spearman_logfc",
    "baseline_pair_spearman_logfc": "mean_baseline_pair_spearman_logfc",
}
signature_delta_ci_metrics = {
    "delta_pair_mean_spearman_logfc": "mean_delta_pair_mean_spearman_logfc",
}
SIGNATURE_CI_FINGERPRINT = cross_source_core.ci_fingerprint(
    version="signature-ci-v2-shared-core",
    upstream_fingerprint=SIGNATURE_METRICS_FINGERPRINT,
    n_boot=BOOTSTRAP_ITERATIONS,
    seed=BOOTSTRAP_RANDOM_SEED,
    metric_columns=[*signature_ci_metrics, *signature_delta_ci_metrics],
    group_columns=["dataset_a", "dataset_b", "cell_type", "pubchem_cid"],
)

def build_signature_ci() -> pd.DataFrame:
    overlap_signature_cluster_bca_ci = pd.concat(
        [
            cluster_bca_nested_mean_ci_table(
                drug_line_time_metric_summary,
                group_cols=["dataset_a", "dataset_b"],
                metric_cols=signature_ci_metrics,
                cluster_col="pubchem_cid",
                n_boot=BOOTSTRAP_ITERATIONS,
                seed=BOOTSTRAP_RANDOM_SEED,
                summary_level="dataset_pair",
            ),
            cluster_bca_nested_mean_ci_table(
                drug_line_time_metric_summary,
                group_cols=["dataset_a", "dataset_b", "cell_type"],
                metric_cols=signature_ci_metrics,
                cluster_col="pubchem_cid",
                n_boot=BOOTSTRAP_ITERATIONS,
                seed=BOOTSTRAP_RANDOM_SEED,
                summary_level="dataset_pair_line",
            ),
            cluster_bca_nested_mean_ci_table(
                drug_line_time_metric_baseline_adjusted_summary,
                group_cols=["dataset_a", "dataset_b"],
                metric_cols=signature_delta_ci_metrics,
                cluster_col="pubchem_cid",
                n_boot=BOOTSTRAP_ITERATIONS,
                seed=BOOTSTRAP_RANDOM_SEED,
                summary_level="dataset_pair_baseline_adjusted",
            ),
            cluster_bca_nested_mean_ci_table(
                drug_line_time_metric_baseline_adjusted_summary,
                group_cols=["dataset_a", "dataset_b", "cell_type"],
                metric_cols=signature_delta_ci_metrics,
                cluster_col="pubchem_cid",
                n_boot=BOOTSTRAP_ITERATIONS,
                seed=BOOTSTRAP_RANDOM_SEED,
                summary_level="dataset_pair_line_baseline_adjusted",
            ),
        ],
        ignore_index=True,
    )
    return overlap_signature_cluster_bca_ci


overlap_signature_cluster_bca_ci_path = OUTPUT_DIR / "signature_similarity_cluster_bca_ci.tsv"
overlap_signature_cluster_bca_ci = cached_frame(
    "signature_ci",
    overlap_signature_cluster_bca_ci_path,
    build_signature_ci,
    fingerprint=SIGNATURE_CI_FINGERPRINT,
)

overlap_signature_cluster_bca_ci_ranges = summarize_ci_half_width_ranges(overlap_signature_cluster_bca_ci)
overlap_signature_cluster_bca_ci_ranges_path = OUTPUT_DIR / "signature_similarity_cluster_bca_ci_ranges.tsv"
overlap_signature_cluster_bca_ci_ranges.to_csv(overlap_signature_cluster_bca_ci_ranges_path, sep="\t", index=False)
print(f"Saved overlap signature CI half-width ranges to {overlap_signature_cluster_bca_ci_ranges_path}")
display(overlap_signature_cluster_bca_ci)
display(overlap_signature_cluster_bca_ci_ranges)
# Out:
# [signature_ci] computed and saved 117 rows to signature_similarity_cluster_bca_ci.tsv
# Saved overlap signature CI half-width ranges to /home/cirro/Chem-PerturBridge_analysis/results/production_runs/overlap_signature_similarity_group_rep/full_production/signature_similarity_cluster_bca_ci_ranges.tsv
#         dataset_a     dataset_b                        summary_level  \
# 0        cigs_mce      cigs_tcm                         dataset_pair
# 1        cigs_mce      cigs_tcm                         dataset_pair
# 2    l1000_phase1      cigs_mce                         dataset_pair
# 3    l1000_phase1      cigs_mce                         dataset_pair
# 4    l1000_phase1  l1000_phase2                         dataset_pair
# ..            ...           ...                                  ...
# 112  l1000_phase2       sciplex  dataset_pair_line_baseline_adjusted
# 113  l1000_phase2       sciplex  dataset_pair_line_baseline_adjusted
# 114  l1000_phase2         tahoe  dataset_pair_line_baseline_adjusted
# 115  l1000_phase2         tahoe  dataset_pair_line_baseline_adjusted
# 116         tahoe       sciplex  dataset_pair_line_baseline_adjusted
#
#                              metric                            value_col  \
# 0           observed_spearman_logfc         mean_observed_spearman_logfc
# 1      baseline_pair_spearman_logfc    mean_baseline_pair_spearman_logfc
# 2           observed_spearman_logfc         mean_observed_spearman_logfc
# 3      baseline_pair_spearman_logfc    mean_baseline_pair_spearman_logfc
# 4           observed_spearman_logfc         mean_observed_spearman_logfc
# ..                              ...                                  ...
# 112  delta_pair_mean_spearman_logfc  mean_delta_pair_mean_spearman_logfc
# 113  delta_pair_mean_spearman_logfc  mean_delta_pair_mean_spearman_logfc
# 114  delta_pair_mean_spearman_logfc  mean_delta_pair_mean_spearman_logfc
# 115  delta_pair_mean_spearman_logfc  mean_delta_pair_mean_spearman_logfc
# 116  delta_pair_mean_spearman_logfc  mean_delta_pair_mean_spearman_logfc
#
#          mean    ci_low   ci_high  ci_half_width ci_method  ...  \
# 0    0.028504  0.023523  0.034736       0.005607       bca  ...
# 1    0.140741  0.136424  0.145137       0.004356       bca  ...
# 2    0.129478  0.101898  0.158312       0.028207       bca  ...
# 3    0.359465  0.332949  0.383956       0.025504       bca  ...
# 4    0.239247  0.213119  0.270910       0.028895       bca  ...
# ..        ...       ...       ...            ...       ...  ...
# 112 -0.122688 -0.149173 -0.091321       0.028926       bca  ...
# 113 -0.091586 -0.109770 -0.070073       0.019848       bca  ...
# 114 -0.280436 -0.312875 -0.234265       0.039305       bca  ...
# 115 -0.242541 -0.259777 -0.225709       0.017034       bca  ...
# 116 -0.285875 -0.317451 -0.223871       0.046790       bca  ...
#
#     n_bootstrap_iterations  n_bootstrap_valid  n_rows  n_finite_rows  \
# 0                     2000               2000    1910           1910
# 1                     2000               2000    1910           1910
# 2                     2000               2000     127            127
# 3                     2000               2000     127            127
# 4                     2000               2000    1060           1060
# ..                     ...                ...     ...            ...
# 112                   2000               2000      44             44
# 113                   2000               2000      83             83
# 114                   2000               2000      24             24
# 115                   2000               2000     110            110
# 116                   2000               2000      23             23
#
#      n_compounds  cluster_col  inner_strata outer_strata  \
# 0            974  pubchem_cid
# 1            974  pubchem_cid
# 2            124  pubchem_cid
# 3            124  pubchem_cid
# 4            257  pubchem_cid
# ..           ...          ...           ...          ...
# 112           44  pubchem_cid
# 113           83  pubchem_cid
# 114           24  pubchem_cid
# 115          110  pubchem_cid
# 116           23  pubchem_cid
#
#                                      uncertainty_scope  cell_type
# 0    95% BCa bootstrap CI clustered by PubChem comp...        NaN
# 1    95% BCa bootstrap CI clustered by PubChem comp...        NaN
# 2    95% BCa bootstrap CI clustered by PubChem comp...        NaN
# 3    95% BCa bootstrap CI clustered by PubChem comp...        NaN
# 4    95% BCa bootstrap CI clustered by PubChem comp...        NaN
# ..                                                 ...        ...
# 112  95% BCa bootstrap CI clustered by PubChem comp...  CVCL_0023
# 113  95% BCa bootstrap CI clustered by PubChem comp...  CVCL_0031
# 114  95% BCa bootstrap CI clustered by PubChem comp...  CVCL_0023
# 115  95% BCa bootstrap CI clustered by PubChem comp...  CVCL_0320
# 116  95% BCa bootstrap CI clustered by PubChem comp...  CVCL_0023
#
# [117 rows x 22 columns]
#                          summary_level                          metric  \
# 0                         dataset_pair    baseline_pair_spearman_logfc
# 1                         dataset_pair         observed_spearman_logfc
# 2       dataset_pair_baseline_adjusted  delta_pair_mean_spearman_logfc
# 3                    dataset_pair_line    baseline_pair_spearman_logfc
# 4                    dataset_pair_line         observed_spearman_logfc
# 5  dataset_pair_line_baseline_adjusted  delta_pair_mean_spearman_logfc
#
#    n_intervals  min_ci_half_width  median_ci_half_width  max_ci_half_width  \
# 0            9           0.004356              0.022723           0.035972
# 1            9           0.005607              0.028207           0.045706
# 2            9           0.005652              0.021065           0.043483
# 3           30           0.005828              0.035136           0.076586
# 4           30           0.005894              0.040204           0.106095
# 5           30           0.006870              0.037912           0.141327
#
#    min_n_compounds  max_n_compounds ci_methods ci_statuses
# 0               23              974        bca          ok
# 1               23              974        bca          ok
# 2               23              974        bca          ok
# 3               11              962        bca          ok
# 4               11              962        bca          ok
# 5               11              962        bca          ok

# %%
display(pair_metric_baseline_adjusted_summary.pivot(index="dataset_a", columns="dataset_b", values="mean_delta_pair_mean_spearman_logfc"))
display(pair_metric_baseline_adjusted_summary.pivot(index="dataset_a", columns="dataset_b", values="mean_delta_pair_mean_spearman_logfc_global"))
# Out:
# dataset_b     cigs_mce  cigs_tcm  l1000_phase2   sciplex     tahoe
# dataset_a
# cigs_mce           NaN -0.112237           NaN       NaN       NaN
# l1000_phase1 -0.229987       NaN     -0.048442 -0.169095 -0.236574
# l1000_phase2 -0.171026       NaN           NaN -0.102361 -0.249328
# tahoe              NaN       NaN           NaN -0.285875       NaN
# dataset_b     cigs_mce  cigs_tcm  l1000_phase2   sciplex     tahoe
# dataset_a
# cigs_mce           NaN -0.108043           NaN       NaN       NaN
# l1000_phase1 -0.225266       NaN     -0.045289 -0.168012 -0.236931
# l1000_phase2 -0.165048       NaN           NaN -0.102356 -0.249872
# tahoe              NaN       NaN           NaN -0.299839       NaN

# %%
display(pair_metric_baseline_adjusted_summary.pivot(index="dataset_a", columns="dataset_b", values="mean_delta_pair_mean_spearman_t"))
display(pair_metric_baseline_adjusted_summary.pivot(index="dataset_a", columns="dataset_b", values="mean_delta_pair_mean_spearman_t_global"))
# Out:
# dataset_b     cigs_mce  cigs_tcm  l1000_phase2   sciplex     tahoe
# dataset_a
# cigs_mce           NaN -0.119686           NaN       NaN       NaN
# l1000_phase1 -0.230676       NaN     -0.047084 -0.172284 -0.255859
# l1000_phase2 -0.159631       NaN           NaN -0.103945 -0.261580
# tahoe              NaN       NaN           NaN -0.291656       NaN
# dataset_b     cigs_mce  cigs_tcm  l1000_phase2   sciplex     tahoe
# dataset_a
# cigs_mce           NaN -0.117537           NaN       NaN       NaN
# l1000_phase1 -0.226100       NaN     -0.044183 -0.171561 -0.254287
# l1000_phase2 -0.154248       NaN           NaN -0.104165 -0.261578
# tahoe              NaN       NaN           NaN -0.299771       NaN

# %%
display(pair_metric_baseline_adjusted_summary.pivot(index="dataset_a", columns="dataset_b", values=f"mean_delta_pair_mean_signed_overlap_t_top{TOP_K}"))
display(pair_metric_baseline_adjusted_summary.pivot(index="dataset_a", columns="dataset_b", values=f"mean_delta_pair_mean_signed_overlap_t_top{TOP_K}_global"))
# Out:
# dataset_b     cigs_mce  cigs_tcm  l1000_phase2   sciplex     tahoe
# dataset_a
# cigs_mce           NaN -0.038217           NaN       NaN       NaN
# l1000_phase1 -0.117323       NaN     -0.002126 -0.081913 -0.121689
# l1000_phase2 -0.116838       NaN           NaN -0.059501 -0.117596
# tahoe              NaN       NaN           NaN -0.060236       NaN
# dataset_b     cigs_mce  cigs_tcm  l1000_phase2   sciplex     tahoe
# dataset_a
# cigs_mce           NaN  -0.04873           NaN       NaN       NaN
# l1000_phase1 -0.116575       NaN     -0.003477 -0.082338 -0.130589
# l1000_phase2 -0.111691       NaN           NaN -0.060111 -0.120194
# tahoe              NaN       NaN           NaN -0.119438       NaN

# %% [markdown]
# Baseline score summaries:
#
# These tables show the within-dataset baseline scores themselves, using the pair-mean baseline already defined above as the mean of the dataset A and dataset B same-line / same-time / same-dose other-compound baselines.

# %%
pair_metric_baseline_summary = pair_metric_summary[
    [
        "dataset_a",
        "dataset_b",
        "n_matched_sample_pairs",
        "n_matching_lines",
        "n_matching_drugs",
        "n_matching_conditions",
        "n_matching_drug_line_times",
        "mean_baseline_pair_spearman_logfc",
        "mean_baseline_pair_spearman_logfc_global",
        "mean_baseline_pair_spearman_t",
        "mean_baseline_pair_spearman_t_global",
        f"mean_baseline_pair_signed_overlap_t_top{TOP_K}",
        f"mean_baseline_pair_signed_overlap_t_top{TOP_K}_global",
        "mean_left_baseline_spearman_logfc",
        "mean_left_baseline_spearman_logfc_global",
        "mean_left_baseline_spearman_t",
        "mean_left_baseline_spearman_t_global",
        f"mean_left_baseline_signed_overlap_t_top{TOP_K}",
        f"mean_left_baseline_signed_overlap_t_top{TOP_K}_global",
        "mean_right_baseline_spearman_logfc",
        "mean_right_baseline_spearman_logfc_global",
        "mean_right_baseline_spearman_t",
        "mean_right_baseline_spearman_t_global",
        f"mean_right_baseline_signed_overlap_t_top{TOP_K}",
        f"mean_right_baseline_signed_overlap_t_top{TOP_K}_global",
        "n_pair_baselines_available",
        "n_pair_baselines_available_global",
    ]
].copy()

line_metric_baseline_summary = line_metric_summary[
    [
        "dataset_a",
        "dataset_b",
        "cell_type",
        "n_matched_sample_pairs",
        "n_matching_drugs",
        "n_matching_conditions",
        "n_matching_drug_line_times",
        "mean_baseline_pair_spearman_logfc",
        "mean_baseline_pair_spearman_logfc_global",
        "mean_baseline_pair_spearman_t",
        "mean_baseline_pair_spearman_t_global",
        f"mean_baseline_pair_signed_overlap_t_top{TOP_K}",
        f"mean_baseline_pair_signed_overlap_t_top{TOP_K}_global",
        "n_pair_baselines_available",
        "n_pair_baselines_available_global",
    ]
].copy()

pair_metric_baseline_summary_display = pair_metric_baseline_summary.copy()
pair_metric_baseline_summary_display["dataset_a"] = pair_metric_baseline_summary_display["dataset_a"].map(pretty_label)
pair_metric_baseline_summary_display["dataset_b"] = pair_metric_baseline_summary_display["dataset_b"].map(pretty_label)
display(pair_metric_baseline_summary_display)

line_metric_baseline_summary_display = line_metric_baseline_summary.copy()
line_metric_baseline_summary_display["dataset_a"] = line_metric_baseline_summary_display["dataset_a"].map(pretty_label)
line_metric_baseline_summary_display["dataset_b"] = line_metric_baseline_summary_display["dataset_b"].map(pretty_label)
display(line_metric_baseline_summary_display)
# Out:
#         dataset_a       dataset_b  n_matched_sample_pairs  n_matching_lines  \
# 0        CIGS-MCE        CIGS-TCM                   15964                 2
# 1   L1000 Phase I        CIGS-MCE                    1401                 2
# 2   L1000 Phase I  L1000 Phase II                   50695                15
# 3   L1000 Phase I        sci-Plex                    2653                 2
# 4   L1000 Phase I      Tahoe-100M                     610                 3
# 5  L1000 Phase II        CIGS-MCE                     508                 1
# 6  L1000 Phase II        sci-Plex                    3133                 2
# 7  L1000 Phase II      Tahoe-100M                    1473                 2
# 8      Tahoe-100M        sci-Plex                     170                 1
#
#    n_matching_drugs  n_matching_conditions  n_matching_drug_line_times  \
# 0               974                   1910                        1910
# 1               124                    127                         127
# 2               257                   2836                        1060
# 3                90                    285                         162
# 4                86                    152                         114
# 5                68                     68                          68
# 6                83                    375                         127
# 7               110                    402                         134
# 8                23                     69                          23
#
#    mean_baseline_pair_spearman_logfc  \
# 0                           0.140741
# 1                           0.359465
# 2                           0.287689
# 3                           0.263792
# 4                           0.274254
# 5                           0.408179
# 6                           0.204387
# 7                           0.276361
# 8                           0.338449
#
#    mean_baseline_pair_spearman_logfc_global  mean_baseline_pair_spearman_t  \
# 0                                  0.133740                       0.153609
# 1                                  0.357898                       0.365661
# 2                                  0.287030                       0.299131
# 3                                  0.263756                       0.270080
# 4                                  0.281663                       0.294741
# 5                                  0.405188                       0.410907
# 6                                  0.204518                       0.211745
# 7                                  0.278084                       0.291810
# 8                                  0.344136                       0.345277
#
#    ...  mean_left_baseline_signed_overlap_t_top50  \
# 0  ...                                   0.101319
# 1  ...                                   0.277795
# 2  ...                                   0.202829
# 3  ...                                   0.217532
# 4  ...                                   0.161502
# 5  ...                                   0.373529
# 6  ...                                   0.186443
# 7  ...                                   0.128362
# 8  ...                                   0.123913
#
#    mean_left_baseline_signed_overlap_t_top50_global  \
# 0                                          0.154921
# 1                                          0.286457
# 2                                          0.211992
# 3                                          0.219350
# 4                                          0.187260
# 5                                          0.378529
# 6                                          0.188089
# 7                                          0.134624
# 8                                          0.288200
#
#    mean_right_baseline_spearman_logfc  \
# 0                            0.101761
# 1                            0.311305
# 2                            0.270612
# 3                            0.242426
# 4                            0.378645
# 5                            0.329177
# 6                            0.230082
# 7                            0.417183
# 8                            0.220218
#
#    mean_right_baseline_spearman_logfc_global  mean_right_baseline_spearman_t  \
# 0                                   0.098890                        0.114501
# 1                                   0.308836                        0.313621
# 2                                   0.270465                        0.283488
# 3                                   0.242382                        0.245101
# 4                                   0.398448                        0.399722
# 5                                   0.322873                        0.317990
# 6                                   0.230075                        0.233876
# 7                                   0.422610                        0.442152
# 8                                   0.230437                        0.219530
#
#    mean_right_baseline_spearman_t_global  \
# 0                               0.114335
# 1                               0.312186
# 2                               0.283430
# 3                               0.245165
# 4                               0.411569
# 5                               0.313309
# 6                               0.233869
# 7                               0.445580
# 8                               0.224634
#
#    mean_right_baseline_signed_overlap_t_top50  \
# 0                                    0.082026
# 1                                    0.220472
# 2                                    0.225603
# 3                                    0.177142
# 4                                    0.219842
# 5                                    0.231324
# 6                                    0.163084
# 7                                    0.245722
# 8                                    0.047065
#
#    mean_right_baseline_signed_overlap_t_top50_global  \
# 0                                           0.128466
# 1                                           0.226850
# 2                                           0.233581
# 3                                           0.178183
# 4                                           0.259364
# 5                                           0.234853
# 6                                           0.164374
# 7                                           0.255126
# 8                                           0.171159
#
#    n_pair_baselines_available  n_pair_baselines_available_global
# 0                        1910                               1910
# 1                         127                                127
# 2                        1060                               1060
# 3                         162                                162
# 4                         114                                114
# 5                          68                                 68
# 6                         127                                127
# 7                         134                                134
# 8                          23                                 23
#
# [9 rows x 27 columns]
#          dataset_a       dataset_b  cell_type  n_matched_sample_pairs  \
# 0         CIGS-MCE        CIGS-TCM  CVCL_0062                    7842
# 1         CIGS-MCE        CIGS-TCM  CVCL_0063                    8122
# 2    L1000 Phase I        CIGS-MCE  CVCL_0062                    1047
# 3    L1000 Phase I        CIGS-MCE  CVCL_0063                     354
# 4    L1000 Phase I  L1000 Phase II  CVCL_0023                    8049
# 5    L1000 Phase I  L1000 Phase II  CVCL_0031                   11741
# 6    L1000 Phase I  L1000 Phase II  CVCL_0033                    3143
# 7    L1000 Phase I  L1000 Phase II  CVCL_0035                    6722
# 8    L1000 Phase I  L1000 Phase II  CVCL_0062                    3739
# 9    L1000 Phase I  L1000 Phase II  CVCL_0132                    3121
# 10   L1000 Phase I  L1000 Phase II  CVCL_0178                    2670
# 11   L1000 Phase I  L1000 Phase II  CVCL_0320                    1824
# 12   L1000 Phase I  L1000 Phase II  CVCL_0332                    2220
# 13   L1000 Phase I  L1000 Phase II  CVCL_0598                    2348
# 14   L1000 Phase I  L1000 Phase II  CVCL_5136                    1014
# 15   L1000 Phase I  L1000 Phase II  CVCL_U602                     763
# 16   L1000 Phase I  L1000 Phase II  CVCL_VU89                    1696
# 17   L1000 Phase I  L1000 Phase II        NEU                     617
# 18   L1000 Phase I  L1000 Phase II        NPC                    1028
# 19   L1000 Phase I        sci-Plex  CVCL_0023                     892
# 20   L1000 Phase I        sci-Plex  CVCL_0031                    1761
# 21   L1000 Phase I      Tahoe-100M  CVCL_0023                     402
# 22   L1000 Phase I      Tahoe-100M  CVCL_0320                      96
# 23   L1000 Phase I      Tahoe-100M  CVCL_0332                     112
# 24  L1000 Phase II        CIGS-MCE  CVCL_0062                     508
# 25  L1000 Phase II        sci-Plex  CVCL_0023                    1356
# 26  L1000 Phase II        sci-Plex  CVCL_0031                    1777
# 27  L1000 Phase II      Tahoe-100M  CVCL_0023                     389
# 28  L1000 Phase II      Tahoe-100M  CVCL_0320                    1084
# 29      Tahoe-100M        sci-Plex  CVCL_0023                     170
#
#     n_matching_drugs  n_matching_conditions  n_matching_drug_line_times  \
# 0                948                    948                         948
# 1                962                    962                         962
# 2                113                    113                         113
# 3                 14                     14                          14
# 4                152                    237                         163
# 5                179                    615                         179
# 6                 63                    247                          63
# 7                118                    190                         118
# 8                 94                    370                          94
# 9                 43                    114                          48
# 10                63                    251                          63
# 11                34                     68                          34
# 12                63                    251                          63
# 13                63                    250                          63
# 14                31                     61                          31
# 15                34                     34                          34
# 16                39                     74                          39
# 17                33                     36                          33
# 18                35                     38                          35
# 19                74                    111                          74
# 20                88                    174                          88
# 21                83                     95                          83
# 22                20                     24                          20
# 23                11                     33                          11
# 24                68                     68                          68
# 25                44                    128                          44
# 26                83                    247                          83
# 27                24                     72                          24
# 28               110                    330                         110
# 29                23                     69                          23
#
#     mean_baseline_pair_spearman_logfc  \
# 0                            0.178167
# 1                            0.103859
# 2                            0.362242
# 3                            0.337051
# 4                            0.310695
# 5                            0.283007
# 6                            0.252763
# 7                            0.234969
# 8                            0.324894
# 9                            0.381416
# 10                           0.264912
# 11                           0.285143
# 12                           0.293152
# 13                           0.357786
# 14                           0.263972
# 15                           0.221170
# 16                           0.280852
# 17                           0.257677
# 18                           0.245650
# 19                           0.231432
# 20                           0.291004
# 21                           0.256077
# 22                           0.325248
# 23                           0.318692
# 24                           0.408179
# 25                           0.213212
# 26                           0.199709
# 27                           0.322556
# 28                           0.266282
# 29                           0.338449
#
#     mean_baseline_pair_spearman_logfc_global  mean_baseline_pair_spearman_t  \
# 0                                   0.168510                       0.193046
# 1                                   0.099476                       0.114745
# 2                                   0.360252                       0.367610
# 3                                   0.338900                       0.349927
# 4                                   0.307107                       0.319096
# 5                                   0.282060                       0.290978
# 6                                   0.252763                       0.267461
# 7                                   0.234969                       0.248968
# 8                                   0.325863                       0.337702
# 9                                   0.381416                       0.395966
# 10                                  0.264912                       0.279075
# 11                                  0.285299                       0.300635
# 12                                  0.292512                       0.304653
# 13                                  0.357786                       0.371583
# 14                                  0.263972                       0.282268
# 15                                  0.221170                       0.224048
# 16                                  0.280852                       0.290557
# 17                                  0.257677                       0.264615
# 18                                  0.245650                       0.261830
# 19                                  0.231354                       0.233442
# 20                                  0.291004                       0.300889
# 21                                  0.266253                       0.278329
# 22                                  0.325248                       0.343133
# 23                                  0.318692                       0.330596
# 24                                  0.405188                       0.410907
# 25                                  0.213589                       0.219759
# 26                                  0.199709                       0.207497
# 27                                  0.332173                       0.339124
# 28                                  0.266282                       0.281487
# 29                                  0.344136                       0.345277
#
#     mean_baseline_pair_spearman_t_global  \
# 0                               0.184263
# 1                               0.114043
# 2                               0.366095
# 3                               0.352587
# 4                               0.315849
# 5                               0.290664
# 6                               0.267461
# 7                               0.248968
# 8                               0.338456
# 9                               0.395966
# 10                              0.279075
# 11                              0.300245
# 12                              0.304333
# 13                              0.371583
# 14                              0.282268
# 15                              0.224048
# 16                              0.290557
# 17                              0.264615
# 18                              0.261830
# 19                              0.233945
# 20                              0.300889
# 21                              0.283766
# 22                              0.343133
# 23                              0.330596
# 24                              0.408345
# 25                              0.220612
# 26                              0.207497
# 27                              0.342615
# 28                              0.281487
# 29                              0.346219
#
#     mean_baseline_pair_signed_overlap_t_top50  \
# 0                                    0.110570
# 1                                    0.073051
# 2                                    0.248761
# 3                                    0.252143
# 4                                    0.241824
# 5                                    0.202358
# 6                                    0.183749
# 7                                    0.202487
# 8                                    0.223478
# 9                                    0.289376
# 10                                   0.189552
# 11                                   0.239139
# 12                                   0.208419
# 13                                   0.251564
# 14                                   0.237961
# 15                                   0.145294
# 16                                   0.220516
# 17                                   0.143047
# 18                                   0.173436
# 19                                   0.196795
# 20                                   0.197793
# 21                                   0.182187
# 22                                   0.224302
# 23                                   0.202431
# 24                                   0.302426
# 25                                   0.184889
# 26                                   0.169396
# 27                                   0.205255
# 28                                   0.183068
# 29                                   0.085489
#
#     mean_baseline_pair_signed_overlap_t_top50_global  \
# 0                                           0.160691
# 1                                           0.122973
# 2                                           0.256018
# 3                                           0.261786
# 4                                           0.277812
# 5                                           0.209857
# 6                                           0.183749
# 7                                           0.202487
# 8                                           0.240803
# 9                                           0.289376
# 10                                          0.189552
# 11                                          0.241806
# 12                                          0.211774
# 13                                          0.251564
# 14                                          0.237961
# 15                                          0.145294
# 16                                          0.220516
# 17                                          0.143047
# 18                                          0.173436
# 19                                          0.199924
# 20                                          0.197793
# 21                                          0.226855
# 22                                          0.224302
# 23                                          0.202431
# 24                                          0.306691
# 25                                          0.189126
# 26                                          0.169396
# 27                                          0.248988
# 28                                          0.183068
# 29                                          0.229680
#
#     n_pair_baselines_available  n_pair_baselines_available_global
# 0                          948                                948
# 1                          962                                962
# 2                          113                                113
# 3                           14                                 14
# 4                          163                                163
# 5                          179                                179
# 6                           63                                 63
# 7                          118                                118
# 8                           94                                 94
# 9                           48                                 48
# 10                          63                                 63
# 11                          34                                 34
# 12                          63                                 63
# 13                          63                                 63
# 14                          31                                 31
# 15                          34                                 34
# 16                          39                                 39
# 17                          33                                 33
# 18                          35                                 35
# 19                          74                                 74
# 20                          88                                 88
# 21                          83                                 83
# 22                          20                                 20
# 23                          11                                 11
# 24                          68                                 68
# 25                          44                                 44
# 26                          83                                 83
# 27                          24                                 24
# 28                         110                                110
# 29                          23                                 23

# %%
display(pair_metric_baseline_summary.pivot(index="dataset_a", columns="dataset_b", values="mean_baseline_pair_spearman_logfc"))
display(pair_metric_baseline_summary.pivot(index="dataset_a", columns="dataset_b", values="mean_baseline_pair_spearman_logfc_global"))
# Out:
# dataset_b     cigs_mce  cigs_tcm  l1000_phase2   sciplex     tahoe
# dataset_a
# cigs_mce           NaN  0.140741           NaN       NaN       NaN
# l1000_phase1  0.359465       NaN      0.287689  0.263792  0.274254
# l1000_phase2  0.408179       NaN           NaN  0.204387  0.276361
# tahoe              NaN       NaN           NaN  0.338449       NaN
# dataset_b     cigs_mce  cigs_tcm  l1000_phase2   sciplex     tahoe
# dataset_a
# cigs_mce           NaN   0.13374           NaN       NaN       NaN
# l1000_phase1  0.357898       NaN       0.28703  0.263756  0.281663
# l1000_phase2  0.405188       NaN           NaN  0.204518  0.278084
# tahoe              NaN       NaN           NaN  0.344136       NaN

# %%
display(pair_metric_baseline_summary.pivot(index="dataset_a", columns="dataset_b", values="mean_baseline_pair_spearman_t"))
display(pair_metric_baseline_summary.pivot(index="dataset_a", columns="dataset_b", values="mean_baseline_pair_spearman_t_global"))
# Out:
# dataset_b     cigs_mce  cigs_tcm  l1000_phase2   sciplex     tahoe
# dataset_a
# cigs_mce           NaN  0.153609           NaN       NaN       NaN
# l1000_phase1  0.365661       NaN      0.299131  0.270080  0.294741
# l1000_phase2  0.410907       NaN           NaN  0.211745  0.291810
# tahoe              NaN       NaN           NaN  0.345277       NaN
# dataset_b     cigs_mce  cigs_tcm  l1000_phase2   sciplex     tahoe
# dataset_a
# cigs_mce           NaN  0.148896           NaN       NaN       NaN
# l1000_phase1  0.364606       NaN      0.298614  0.270309  0.298700
# l1000_phase2  0.408345       NaN           NaN  0.212041  0.292436
# tahoe              NaN       NaN           NaN  0.346219       NaN

# %%
display(pair_metric_baseline_summary.pivot(index="dataset_a", columns="dataset_b", values=f"mean_baseline_pair_signed_overlap_t_top{TOP_K}"))
display(pair_metric_baseline_summary.pivot(index="dataset_a", columns="dataset_b", values=f"mean_baseline_pair_signed_overlap_t_top{TOP_K}_global"))
# Out:
# dataset_b     cigs_mce  cigs_tcm  l1000_phase2   sciplex     tahoe
# dataset_a
# cigs_mce           NaN  0.091673           NaN       NaN       NaN
# l1000_phase1  0.249134       NaN      0.213929  0.197337  0.191529
# l1000_phase2  0.302426       NaN           NaN  0.174764  0.187042
# tahoe              NaN       NaN           NaN  0.085489       NaN
# dataset_b     cigs_mce  cigs_tcm  l1000_phase2   sciplex     tahoe
# dataset_a
# cigs_mce           NaN  0.141694           NaN       NaN       NaN
# l1000_phase1  0.256654       NaN      0.222551  0.198766  0.224050
# l1000_phase2  0.306691       NaN           NaN  0.176232  0.194875
# tahoe              NaN       NaN           NaN  0.229680       NaN

# %% [markdown]
# **T Strength vs Correlation**
#
# This section asks whether matched samples with larger moderated `t` magnitude also show higher cross-dataset similarity.
#
# For each matched sample pair, it computes:
# - `left_mean_abs_t`: mean absolute moderated `t` for the left sample on the same pairwise shared-gene set used for the observed cross-dataset score
# - `right_mean_abs_t`: same for the right sample
# - `pair_mean_abs_t`: average of the left and right values
#
# The summary tables still report dataset-pair-level Spearman relationships. The scatter plots, however, now use one point per exact matched condition, i.e.
# `pubchem_cid + cell_type + time_key + left_dose_key + right_dose_key`,
# so multiple matched dose pairs for the same drug-line-time appear as separate points.
#
# The same analysis is repeated on the line-specific global shared-gene set using the `*_global` columns.
#
# In the scatter plots, the x-axis uses `log10(mean absolute moderated t)` to reduce domination by extreme-`|t|` outliers.

# %%
def safe_column_spearman(frame: pd.DataFrame, x_col: str, y_col: str) -> float:
    subset = frame[[x_col, y_col]].replace([np.inf, -np.inf], np.nan).dropna()
    if len(subset) < 2 or subset[x_col].nunique() < 2 or subset[y_col].nunique() < 2:
        return float("nan")
    return float(subset[x_col].corr(subset[y_col], method="spearman"))


t_strength_pair_relationship_summary = pd.DataFrame(
    [
        {
            "dataset_a": dataset_a,
            "dataset_b": dataset_b,
            "n_matched_sample_pairs": int(len(group)),
            "spearman_pair_mean_abs_t_vs_observed_logfc": safe_column_spearman(group, "pair_mean_abs_t", "observed_spearman_logfc"),
            "spearman_pair_mean_abs_t_vs_observed_t": safe_column_spearman(group, "pair_mean_abs_t", "observed_spearman_t"),
            f"spearman_pair_mean_abs_t_vs_observed_signed_overlap_t_top{TOP_K}": safe_column_spearman(group, "pair_mean_abs_t", f"observed_signed_overlap_t_top{TOP_K}"),
            "spearman_pair_mean_abs_t_global_vs_observed_logfc_global": safe_column_spearman(group, "pair_mean_abs_t_global", "observed_spearman_logfc_global"),
            "spearman_pair_mean_abs_t_global_vs_observed_t_global": safe_column_spearman(group, "pair_mean_abs_t_global", "observed_spearman_t_global"),
            f"spearman_pair_mean_abs_t_global_vs_observed_signed_overlap_t_top{TOP_K}_global": safe_column_spearman(group, "pair_mean_abs_t_global", f"observed_signed_overlap_t_top{TOP_K}_global"),
        }
        for (dataset_a, dataset_b), group in matched_pair_metrics.groupby(["dataset_a", "dataset_b"], sort=False)
    ]
).sort_values(["dataset_a", "dataset_b"]).reset_index(drop=True)

matched_condition_group_columns = [
    "dataset_a",
    "dataset_b",
    "cell_type",
    "time_key",
    "pubchem_cid",
    "left_dose_key",
    "right_dose_key",
    "matched_condition_key",
]

matched_condition_t_strength_summary = (
    matched_pair_metrics.groupby(matched_condition_group_columns, as_index=False)
    .agg(
        n_matched_sample_pairs=("left_obs_id", "size"),
        mean_pair_mean_abs_t=("pair_mean_abs_t", "mean"),
        mean_pair_mean_abs_t_global=("pair_mean_abs_t_global", "mean"),
        mean_observed_spearman_logfc=("observed_spearman_logfc", "mean"),
        mean_observed_spearman_t=("observed_spearman_t", "mean"),
        **{f"mean_observed_signed_overlap_t_top{TOP_K}": (f"observed_signed_overlap_t_top{TOP_K}", "mean")},
        mean_observed_spearman_logfc_global=("observed_spearman_logfc_global", "mean"),
        mean_observed_spearman_t_global=("observed_spearman_t_global", "mean"),
        **{f"mean_observed_signed_overlap_t_top{TOP_K}_global": (f"observed_signed_overlap_t_top{TOP_K}_global", "mean")},
    )
    .sort_values(matched_condition_group_columns)
    .reset_index(drop=True)
)


t_strength_matched_condition_relationship_summary = pd.DataFrame(
    [
        {
            "dataset_a": dataset_a,
            "dataset_b": dataset_b,
            "n_matching_condition_dose_pairs": int(len(group)),
            "spearman_mean_abs_t_vs_observed_logfc": safe_column_spearman(group, "mean_pair_mean_abs_t", "mean_observed_spearman_logfc"),
            "spearman_mean_abs_t_vs_observed_t": safe_column_spearman(group, "mean_pair_mean_abs_t", "mean_observed_spearman_t"),
            f"spearman_mean_abs_t_vs_observed_signed_overlap_t_top{TOP_K}": safe_column_spearman(group, "mean_pair_mean_abs_t", f"mean_observed_signed_overlap_t_top{TOP_K}"),
            "spearman_mean_abs_t_global_vs_observed_logfc_global": safe_column_spearman(group, "mean_pair_mean_abs_t_global", "mean_observed_spearman_logfc_global"),
            "spearman_mean_abs_t_global_vs_observed_t_global": safe_column_spearman(group, "mean_pair_mean_abs_t_global", "mean_observed_spearman_t_global"),
            f"spearman_mean_abs_t_global_vs_observed_signed_overlap_t_top{TOP_K}_global": safe_column_spearman(group, "mean_pair_mean_abs_t_global", f"mean_observed_signed_overlap_t_top{TOP_K}_global"),
        }
        for (dataset_a, dataset_b), group in matched_condition_t_strength_summary.groupby(["dataset_a", "dataset_b"], sort=False)
    ]
).sort_values(["dataset_a", "dataset_b"]).reset_index(drop=True)

for frame in [t_strength_pair_relationship_summary, t_strength_matched_condition_relationship_summary]:
    frame["dataset_a"] = frame["dataset_a"].map(pretty_label)
    frame["dataset_b"] = frame["dataset_b"].map(pretty_label)

display(t_strength_pair_relationship_summary)
display(t_strength_matched_condition_relationship_summary)
# Out:
#         dataset_a       dataset_b  n_matched_sample_pairs  \
# 0        CIGS-MCE        CIGS-TCM                   15964
# 1   L1000 Phase I        CIGS-MCE                    1401
# 2   L1000 Phase I  L1000 Phase II                   50695
# 3   L1000 Phase I        sci-Plex                    2653
# 4   L1000 Phase I      Tahoe-100M                     610
# 5  L1000 Phase II        CIGS-MCE                     508
# 6  L1000 Phase II        sci-Plex                    3133
# 7  L1000 Phase II      Tahoe-100M                    1473
# 8      Tahoe-100M        sci-Plex                     170
#
#    spearman_pair_mean_abs_t_vs_observed_logfc  \
# 0                                    0.211554
# 1                                    0.460201
# 2                                    0.836216
# 3                                    0.593714
# 4                                    0.463300
# 5                                    0.707012
# 6                                    0.737558
# 7                                    0.403832
# 8                                    0.703324
#
#    spearman_pair_mean_abs_t_vs_observed_t  \
# 0                                0.227496
# 1                                0.437037
# 2                                0.841913
# 3                                0.590739
# 4                                0.433898
# 5                                0.676524
# 6                                0.736759
# 7                                0.399014
# 8                                0.704555
#
#    spearman_pair_mean_abs_t_vs_observed_signed_overlap_t_top50  \
# 0                                           0.244594
# 1                                           0.508964
# 2                                           0.851671
# 3                                           0.621648
# 4                                           0.426427
# 5                                           0.525066
# 6                                           0.682961
# 7                                           0.298871
# 8                                           0.593000
#
#    spearman_pair_mean_abs_t_global_vs_observed_logfc_global  \
# 0                                           0.205080
# 1                                           0.431479
# 2                                           0.841868
# 3                                           0.593024
# 4                                           0.431334
# 5                                           0.699409
# 6                                           0.737362
# 7                                           0.434029
# 8                                           0.544832
#
#    spearman_pair_mean_abs_t_global_vs_observed_t_global  \
# 0                                           0.217092
# 1                                           0.424924
# 2                                           0.846755
# 3                                           0.591282
# 4                                           0.413285
# 5                                           0.675176
# 6                                           0.736596
# 7                                           0.413392
# 8                                           0.550734
#
#    spearman_pair_mean_abs_t_global_vs_observed_signed_overlap_t_top50_global
# 0                                           0.263781
# 1                                           0.495274
# 2                                           0.855005
# 3                                           0.626892
# 4                                           0.415786
# 5                                           0.547776
# 6                                           0.678675
# 7                                           0.388636
# 8                                           0.501291
#         dataset_a       dataset_b  n_matching_condition_dose_pairs  \
# 0        CIGS-MCE        CIGS-TCM                             1910
# 1   L1000 Phase I        CIGS-MCE                              127
# 2   L1000 Phase I  L1000 Phase II                             2836
# 3   L1000 Phase I        sci-Plex                              285
# 4   L1000 Phase I      Tahoe-100M                              152
# 5  L1000 Phase II        CIGS-MCE                               68
# 6  L1000 Phase II        sci-Plex                              375
# 7  L1000 Phase II      Tahoe-100M                              402
# 8      Tahoe-100M        sci-Plex                               69
#
#    spearman_mean_abs_t_vs_observed_logfc  spearman_mean_abs_t_vs_observed_t  \
# 0                               0.234890                           0.251098
# 1                               0.529750                           0.507745
# 2                               0.615169                           0.627575
# 3                               0.498998                           0.493558
# 4                               0.426452                           0.397016
# 5                               0.684162                           0.649540
# 6                               0.675128                           0.678680
# 7                               0.352974                           0.336413
# 8                               0.612751                           0.617501
#
#    spearman_mean_abs_t_vs_observed_signed_overlap_t_top50  \
# 0                                           0.258160
# 1                                           0.549037
# 2                                           0.649897
# 3                                           0.524922
# 4                                           0.444846
# 5                                           0.482176
# 6                                           0.614749
# 7                                           0.264001
# 8                                           0.521787
#
#    spearman_mean_abs_t_global_vs_observed_logfc_global  \
# 0                                           0.228231
# 1                                           0.507095
# 2                                           0.618909
# 3                                           0.498030
# 4                                           0.415196
# 5                                           0.679887
# 6                                           0.676111
# 7                                           0.352010
# 8                                           0.413555
#
#    spearman_mean_abs_t_global_vs_observed_t_global  \
# 0                                         0.238777
# 1                                         0.495559
# 2                                         0.630845
# 3                                         0.493899
# 4                                         0.394511
# 5                                         0.648662
# 6                                         0.678568
# 7                                         0.334426
# 8                                         0.415199
#
#    spearman_mean_abs_t_global_vs_observed_signed_overlap_t_top50_global
# 0                                           0.283557
# 1                                           0.545007
# 2                                           0.652582
# 3                                           0.528121
# 4                                           0.440286
# 5                                           0.511967
# 6                                           0.614184
# 7                                           0.295918
# 8                                           0.405077

# %%
plot_frame = matched_condition_t_strength_summary.copy()
plot_frame = plot_frame.loc[
    np.isfinite(plot_frame["mean_pair_mean_abs_t"].to_numpy(dtype=float))
    & (plot_frame["mean_pair_mean_abs_t"].to_numpy(dtype=float) > 0)
].copy()
plot_frame["log10_mean_pair_mean_abs_t"] = np.log10(plot_frame["mean_pair_mean_abs_t"].to_numpy(dtype=float))
plot_frame["dataset_pair"] = plot_frame["dataset_a"].map(pretty_label) + " vs " + plot_frame["dataset_b"].map(pretty_label)

fig, axes = plt.subplots(1, 2, figsize=(14, 5), constrained_layout=True)

sns.scatterplot(
    data=plot_frame,
    x="log10_mean_pair_mean_abs_t",
    y="mean_observed_spearman_logfc",
    hue="dataset_pair",
    alpha=0.7,
    s=18,
    ax=axes[0],
)
sns.regplot(
    data=plot_frame,
    x="log10_mean_pair_mean_abs_t",
    y="mean_observed_spearman_logfc",
    scatter=False,
    color="black",
    line_kws={"linewidth": 2.0, "linestyle": "--"},
    ax=axes[0],
)
logfc_rho = safe_column_spearman(plot_frame, "log10_mean_pair_mean_abs_t", "mean_observed_spearman_logfc")
logfc_subset = plot_frame[["log10_mean_pair_mean_abs_t", "mean_observed_spearman_logfc"]].replace([np.inf, -np.inf], np.nan).dropna()
axes[0].text(
    0.03,
    0.97,
    f"Spearman rho = {logfc_rho:.3f}\nn = {len(logfc_subset):,}",
    transform=axes[0].transAxes,
    ha="left",
    va="top",
    fontsize=10,
    bbox={"boxstyle": "round,pad=0.3", "facecolor": "white", "alpha": 0.85, "edgecolor": "0.8"},
)
axes[0].set_title("Matched condition-dose log mean |t| vs observed logFC correlation")
axes[0].set_xlabel("log10(mean absolute moderated t across datasets)")
axes[0].set_ylabel("Observed cross-dataset Spearman(logFC)")

sns.scatterplot(
    data=plot_frame,
    x="log10_mean_pair_mean_abs_t",
    y="mean_observed_spearman_t",
    hue="dataset_pair",
    alpha=0.7,
    s=18,
    ax=axes[1],
)
sns.regplot(
    data=plot_frame,
    x="log10_mean_pair_mean_abs_t",
    y="mean_observed_spearman_t",
    scatter=False,
    color="black",
    line_kws={"linewidth": 2.0, "linestyle": "--"},
    ax=axes[1],
)
t_rho = safe_column_spearman(plot_frame, "log10_mean_pair_mean_abs_t", "mean_observed_spearman_t")
t_subset = plot_frame[["log10_mean_pair_mean_abs_t", "mean_observed_spearman_t"]].replace([np.inf, -np.inf], np.nan).dropna()
axes[1].text(
    0.03,
    0.97,
    f"Spearman rho = {t_rho:.3f}\nn = {len(t_subset):,}",
    transform=axes[1].transAxes,
    ha="left",
    va="top",
    fontsize=10,
    bbox={"boxstyle": "round,pad=0.3", "facecolor": "white", "alpha": 0.85, "edgecolor": "0.8"},
)
axes[1].set_title("Matched condition-dose log mean |t| vs observed t correlation")
axes[1].set_xlabel("log10(mean absolute moderated t across datasets)")
axes[1].set_ylabel("Observed cross-dataset Spearman(t)")

handles, labels = axes[1].get_legend_handles_labels()
if axes[0].legend_ is not None:
    axes[0].legend_.remove()
axes[1].legend(handles=handles, labels=labels, title="Dataset pair", bbox_to_anchor=(1.02, 1), loc="upper left")

t_strength_scatter_path = OUTPUT_DIR / "matched_condition_log10_mean_abs_t_vs_observed_spearman_scatter.pdf"
fig.savefig(t_strength_scatter_path, bbox_inches="tight")
print(f"Saved plot to {t_strength_scatter_path}")

t_strength_scatter_description_path = OUTPUT_DIR / "matched_condition_log10_mean_abs_t_vs_observed_spearman_scatter_description.txt"
description_lines = [
    "Plot: matched-condition perturbation strength vs cross-dataset signature similarity.",
    "",
    f"Source table: {matched_pair_metrics_path}",
    f"Output plot: {t_strength_scatter_path}",
    f"Number of plotted matched condition-dose points: {len(plot_frame):,}",
    "",
    "Generation steps:",
    "1. Start from matched_sample_pair_metrics.tsv, which contains precomputed pairwise signature-similarity metrics for matched sample pairs across datasets.",
    "2. Aggregate sample-pair rows to matched condition-dose rows grouped by dataset_a, dataset_b, cell_type, time_key, pubchem_cid, left_dose_key, right_dose_key, and matched_condition_key.",
    "3. For each matched condition-dose row, average pair_mean_abs_t, observed_spearman_logfc, and observed_spearman_t over the available matched sample pairs.",
    "4. Keep rows with finite, positive mean_pair_mean_abs_t and plot log10(mean_pair_mean_abs_t) on the x-axis.",
    "5. Draw two scatter panels: observed cross-dataset Spearman(logFC) on the left and observed cross-dataset Spearman(moderated t) on the right.",
    "6. Color points by dataset pair and overlay a dashed black linear regression trend line for visual orientation.",
    "7. Report Spearman rho in each panel using the plotted matched condition-dose points, after dropping non-finite x/y values.",
    "",
    "What the plot shows:",
    f"- Left panel: association between log10 mean absolute moderated t and observed cross-dataset Spearman(logFC); Spearman rho = {logfc_rho:.3f}, n = {len(logfc_subset):,}.",
    f"- Right panel: association between log10 mean absolute moderated t and observed cross-dataset Spearman(moderated t); Spearman rho = {t_rho:.3f}, n = {len(t_subset):,}.",
    "- Higher mean absolute moderated t corresponds to stronger perturbation signal across the two datasets for a matched compound, cell type, time, and dose pair.",
    "- The positive Spearman correlations indicate that stronger perturbation signals tend to be more reproducible across datasets, but the scatter remains broad, so t-strength is only a partial explanation of cross-dataset similarity.",
    "- The figure is descriptive and uses already precomputed signature-similarity outputs; it does not recompute signatures or add uncertainty intervals.",
]
t_strength_scatter_description_path.write_text("\n".join(description_lines) + "\n")
print(f"Saved plot description to {t_strength_scatter_description_path}")
plt.show()
# Out:
# Saved plot to /home/cirro/Chem-PerturBridge_analysis/results/production_runs/overlap_signature_similarity_group_rep/full_production/matched_condition_log10_mean_abs_t_vs_observed_spearman_scatter.pdf
# Saved plot description to /home/cirro/Chem-PerturBridge_analysis/results/production_runs/overlap_signature_similarity_group_rep/full_production/matched_condition_log10_mean_abs_t_vs_observed_spearman_scatter_description.txt

# %% [markdown]
# Optional cleanup:
#
# ```python
# close_all_line_sources()
# ```

# %% [markdown]
# **Dataset-Pair Heatmaps**
#
# These heatmaps summarize the dataset-pair means for `Spearman(logFC)` at three levels:
# - observed cross-dataset score
# - pair baseline score
# - observed minus baseline pair score
#
# They use the same dataset labels and lower-triangular layout as [plot_overlap_heatmaps.ipynb](./plot_overlap_heatmaps.ipynb). The diagonal is masked because these are cross-dataset summaries only.

# %%
HEATMAP_OUTPUT_PATHS = {
    "mean_observed_spearman_logfc": OUTPUT_DIR / "dataset_pair_mean_observed_spearman_logfc_heatmap.pdf",
    "mean_baseline_pair_spearman_logfc": OUTPUT_DIR / "dataset_pair_mean_baseline_pair_spearman_logfc_heatmap.pdf",
    "mean_delta_pair_mean_spearman_logfc": OUTPUT_DIR / "dataset_pair_mean_delta_pair_mean_spearman_logfc_heatmap.pdf",
}


build_symmetric_pair_metric_matrix = cross_source_core.build_symmetric_pair_metric_matrix


heatmap_dataset_order = [dataset_name for dataset_name in DATASET_ORDER if dataset_name in active_datasets]

observed_baseline_values = pd.concat(
    [
        pair_metric_summary["mean_observed_spearman_logfc"],
        pair_metric_summary["mean_baseline_pair_spearman_logfc"],
    ],
    ignore_index=True,
).replace([np.inf, -np.inf], np.nan)
observed_baseline_values = observed_baseline_values.dropna()
if observed_baseline_values.empty:
    observed_baseline_vmin = None
    observed_baseline_vmax = None
else:
    observed_baseline_vmin = float(observed_baseline_values.min())
    observed_baseline_vmax = float(observed_baseline_values.max())


delta_values = (
    pair_metric_baseline_adjusted_summary["mean_delta_pair_mean_spearman_logfc"]
    .replace([np.inf, -np.inf], np.nan)
    .dropna()
)
if delta_values.empty:
    delta_abs_max = None
else:
    delta_abs_max = float(np.nanmax(np.abs(delta_values.to_numpy(dtype=float))))



def plot_pair_metric_heatmap(
    summary_frame: pd.DataFrame,
    value_col: str,
    title: str,
    cmap: str,
    output_path: Path,
    *,
    dataset_order: Optional[list[str]] = None,
    vmin: Optional[float] = None,
    vmax: Optional[float] = None,
    center: Optional[float] = None,
    cbar_label: Optional[str] = None,
):
    dataset_order = dataset_order or heatmap_dataset_order
    matrix = build_symmetric_pair_metric_matrix(summary_frame, value_col, dataset_order)
    display_matrix = matrix.rename(index=pretty_label, columns=pretty_label).iloc[1:, :-1]
    mask = np.triu(np.ones(display_matrix.shape, dtype=bool), k=1)

    fig_width = max(5.5, 1.35 * len(display_matrix.columns))
    fig_height = max(4.5, 1.15 * len(display_matrix.index))
    fig, ax = plt.subplots(figsize=(fig_width, fig_height), constrained_layout=True)
    sns.heatmap(
        display_matrix,
        mask=mask,
        annot=True,
        fmt=".3f",
        cmap=cmap,
        vmin=vmin,
        vmax=vmax,
        center=center,
        linewidths=0.5,
        linecolor="white",
        square=True,
        cbar_kws={"shrink": 0.85},
        ax=ax,
    )
    ax.set_title(title)
    ax.set_xlabel("")
    ax.set_ylabel("")
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    ax.set_yticklabels(ax.get_yticklabels(), rotation=0)
    ax.grid(False)
    output_path.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(output_path, bbox_inches="tight")
    plt.show()
    print(f"Saved heatmap to {output_path}")


print("Heatmap datasets:", ", ".join(pretty_label(dataset_name) for dataset_name in heatmap_dataset_order))
# Out:
# Heatmap datasets: L1000 Phase I, L1000 Phase II, Tahoe-100M, CIGS-MCE, CIGS-TCM, sci-Plex

# %%
plot_pair_metric_heatmap(
    pair_metric_summary,
    value_col="mean_observed_spearman_logfc",
    title="Cross-Dataset Spearman(logFC)",
    cmap="YlGnBu",
    output_path=HEATMAP_OUTPUT_PATHS["mean_observed_spearman_logfc"],
    dataset_order=heatmap_dataset_order,
    vmin=observed_baseline_vmin,
    vmax=observed_baseline_vmax,
    cbar_label="Mean observed Spearman(logFC)",
)
# Out:
# Saved heatmap to /home/cirro/Chem-PerturBridge_analysis/results/production_runs/overlap_signature_similarity_group_rep/full_production/dataset_pair_mean_observed_spearman_logfc_heatmap.pdf

# %%
plot_pair_metric_heatmap(
    pair_metric_summary,
    value_col="mean_baseline_pair_spearman_logfc",
    title="Baseline Pair Spearman(logFC)",
    cmap="YlOrBr",
    output_path=HEATMAP_OUTPUT_PATHS["mean_baseline_pair_spearman_logfc"],
    dataset_order=heatmap_dataset_order,
    vmin=observed_baseline_vmin,
    vmax=observed_baseline_vmax,
    cbar_label="Mean baseline pair Spearman(logFC)",
)
# Out:
# Saved heatmap to /home/cirro/Chem-PerturBridge_analysis/results/production_runs/overlap_signature_similarity_group_rep/full_production/dataset_pair_mean_baseline_pair_spearman_logfc_heatmap.pdf

# %%
plot_pair_metric_heatmap(
    pair_metric_baseline_adjusted_summary,
    value_col="mean_delta_pair_mean_spearman_logfc",
    title="Observed Minus Baseline Pair Spearman(logFC)",
    cmap="RdBu_r",
    output_path=HEATMAP_OUTPUT_PATHS["mean_delta_pair_mean_spearman_logfc"],
    dataset_order=heatmap_dataset_order,
    vmin=None if delta_abs_max is None else -delta_abs_max,
    vmax=None if delta_abs_max is None else delta_abs_max,
    center=0.0,
    cbar_label="Mean delta Spearman(logFC)",
)
# Out:
# Saved heatmap to /home/cirro/Chem-PerturBridge_analysis/results/production_runs/overlap_signature_similarity_group_rep/full_production/dataset_pair_mean_delta_pair_mean_spearman_logfc_heatmap.pdf

# %% [markdown]
# ## Per-peer and target-side baselines for all-gene logFC Spearman
#
# This section mirrors the peer-baseline analysis in
# [overlap_group_rep_deg_metrics_reviewer_additions.ipynb](./overlap_group_rep_deg_metrics_reviewer_additions.ipynb)
# for the all-gene `logFC` Spearman metric, which is the whole-signature counterpart of the
# DEG-restricted agreement tables.
#
# Everything above is unchanged. The same matched sample pairs are rescored against four
# baselines -- `source_centroid` (the published one, recomputed as a parity check),
# `target_centroid` (the same mean built from the other dataset's peers), `source_peer`
# (every own-dataset peer scored separately), and `target_peer` (every other-dataset peer
# scored separately) -- with the mean, standard deviation, fraction of peer scores below the
# observed score, and the add-one corrected percentile `(1 + #{m(i, x) < m(i, j)}) / (K + 1)`
# reported for the per-peer variants.

# %%
import importlib
import sys

if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

import scripts.notebook_cache as notebook_cache_module
import scripts.peer_baselines as peer_baselines_module

# Support resuming this section in a kernel that imported the pre-optimization helpers.
importlib.reload(notebook_cache_module)
importlib.reload(peer_baselines_module)
cached_frame = notebook_cache_module.cached_frame
cache_summary = notebook_cache_module.cache_summary
resumable_context_frame = notebook_cache_module.resumable_context_frame
stable_json_fingerprint = notebook_cache_module.stable_json_fingerprint
frame_identity_fingerprint = notebook_cache_module.frame_identity_fingerprint

from scripts.peer_baselines import (
    empty_peer_score_summary,
    prepare_spearman_rows,
    select_peer_indices,
    spearman_against_prepared_peers,
    summarize_peer_scores,
)

# Table 6 reports all-gene logFC Spearman on the pairwise shared gene set.
PEER_BASELINE_VARIANTS = (
    "source_centroid",
    "target_centroid",
    "source_peer",
    "target_peer",
)
MAX_BASELINE_PEERS: Optional[int] = 512
PEER_SAMPLING_SEED = 20260505


baseline_peer_stratum = cross_source_core.line_source_stratum_arrays


def baseline_peer_selection(
    source: LineSource,
    obs_id: str,
    *,
    pubchem_cid: str,
    dose_key: str,
    time_key: str,
) -> tuple[SignatureStratum, np.ndarray, int]:
    selection = cross_source_core.select_line_source_peers(
        source,
        obs_id,
        pubchem_cid=pubchem_cid,
        dose_key=dose_key,
        time_key=time_key,
        max_peers=MAX_BASELINE_PEERS,
        sampling_seed=PEER_SAMPLING_SEED,
    )
    return (
        selection.stratum,
        selection.row_indices,
        selection.total_count,
    )


def baseline_peer_logfc_matrix(
    source: LineSource,
    obs_id: str,
    *,
    pubchem_cid: str,
    dose_key: str,
    time_key: str,
) -> tuple[np.ndarray, int, int]:
    stratum, chosen, n_total = baseline_peer_selection(
        source,
        obs_id,
        pubchem_cid=pubchem_cid,
        dose_key=dose_key,
        time_key=time_key,
    )
    return stratum.values[chosen], n_total, int(chosen.size)


def compute_peer_baseline_record(match_row: pd.Series) -> dict[str, object]:
    """Score one matched sample pair's all-gene logFC Spearman against four baselines.

      source_centroid -- the published baseline: mean of the sample's own-dataset peers.
      target_centroid -- the same mean built in the other dataset.
      source_peer     -- every own-dataset peer scored separately.
      target_peer     -- every other-dataset peer scored separately.
    """
    dataset_a = str(match_row["dataset_a"])
    dataset_b = str(match_row["dataset_b"])
    cell_type = str(match_row["cell_type"])
    left_source = get_line_source(dataset_a, cell_type)
    right_source = get_line_source(dataset_b, cell_type)
    shared_genes, left_gene_pos, right_gene_pos = shared_gene_positions(left_source, right_source)
    if shared_genes.size < 2:
        raise ValueError(
            f"Fewer than two shared genes for {dataset_a} vs {dataset_b} / {cell_type}"
        )

    left_obs_id = str(match_row["left_obs_id"])
    right_obs_id = str(match_row["right_obs_id"])
    pubchem_cid = str(match_row["pubchem_cid"])
    time_key = str(match_row["time_key"])
    left_lookup = {
        "pubchem_cid": pubchem_cid,
        "dose_key": str(match_row["left_dose_key"]),
        "time_key": time_key,
    }
    right_lookup = {
        "pubchem_cid": pubchem_cid,
        "dose_key": str(match_row["right_dose_key"]),
        "time_key": time_key,
    }

    left_logfc = left_source.get_vector(left_obs_id, "logFC", **left_lookup)[left_gene_pos]
    right_logfc = right_source.get_vector(right_obs_id, "logFC", **right_lookup)[right_gene_pos]

    left_centroid_full = left_source.get_baseline_vector(left_obs_id, "logFC", **left_lookup)
    right_centroid_full = right_source.get_baseline_vector(right_obs_id, "logFC", **right_lookup)
    left_centroid = None if left_centroid_full is None else np.asarray(left_centroid_full, dtype=np.float32)[left_gene_pos]
    right_centroid = None if right_centroid_full is None else np.asarray(right_centroid_full, dtype=np.float32)[right_gene_pos]

    left_peer_stratum, left_peer_rows, left_n_total_peers = baseline_peer_selection(
        left_source,
        left_obs_id,
        **left_lookup,
    )
    right_peer_stratum, right_peer_rows, right_n_total_peers = baseline_peer_selection(
        right_source,
        right_obs_id,
        **right_lookup,
    )
    left_n_scored_peers = int(left_peer_rows.size)
    right_n_scored_peers = int(right_peer_rows.size)
    left_peers = left_peer_stratum.values[left_peer_rows][:, left_gene_pos]
    right_peers = right_peer_stratum.values[right_peer_rows][:, right_gene_pos]
    prepared_peer_matrices = {
        "left": (left_peer_stratum.prepared_spearman(left_gene_pos), left_peer_rows),
        "right": (right_peer_stratum.prepared_spearman(right_gene_pos), right_peer_rows),
    }

    # The peer set must be exactly the set the published centroid averaged. Comparing
    # counts checks that membership without recomputing the centroid mean per pair, and it
    # keeps working when MAX_BASELINE_PEERS caps how many peers are scored.
    for side, source, obs_id, lookup, n_total in (
        ("left", left_source, left_obs_id, left_lookup, left_n_total_peers),
        ("right", right_source, right_obs_id, right_lookup, right_n_total_peers),
    ):
        expected_peers = int(source.baseline_peer_count(obs_id, **lookup))
        if int(n_total) != expected_peers:
            raise AssertionError(
                f"Peer set does not match the published centroid for {side} side of "
                f"{dataset_a} vs {dataset_b} / {cell_type} / {pubchem_cid}: "
                f"{int(n_total)} peers vs {expected_peers} averaged by get_baseline_vector."
            )

    observed = signed_spearman(left_logfc, right_logfc)
    record: dict[str, object] = {
        **match_row.to_dict(),
        "n_common_genes": int(shared_genes.size),
        "left_peer_total_count": left_n_total_peers,
        "right_peer_total_count": right_n_total_peers,
        "left_peer_scored_count": left_n_scored_peers,
        "right_peer_scored_count": right_n_scored_peers,
        "peer_sampling_seed": PEER_SAMPLING_SEED,
        "max_baseline_peers": MAX_BASELINE_PEERS,
        "pb_observed_spearman_logfc": observed,
    }

    side_specs = {
        "left": {
            "sample_logfc": left_logfc,
            "source_centroid": left_centroid,
            "target_centroid": right_centroid,
            "source_peers": left_peers,
            "target_peers": right_peers,
        },
        "right": {
            "sample_logfc": right_logfc,
            "source_centroid": right_centroid,
            "target_centroid": left_centroid,
            "source_peers": right_peers,
            "target_peers": left_peers,
        },
    }

    for variant in PEER_BASELINE_VARIANTS:
        side_values: list[float] = []
        side_sds: list[float] = []
        side_fractions: list[float] = []
        side_percentiles: list[float] = []
        for side, spec in side_specs.items():
            column_stem = f"pb_{variant}_spearman_logfc_{side}"
            if variant.endswith("_centroid"):
                centroid = spec[variant]
                value = (
                    float("nan")
                    if centroid is None
                    else signed_spearman(spec["sample_logfc"], centroid)
                )
                record[column_stem] = value
                side_values.append(value)
                continue

            peer_matrix = spec["source_peers" if variant == "source_peer" else "target_peers"]
            if peer_matrix.shape[0] == 0:
                record.update(empty_peer_score_summary(column_stem))
                side_values.append(float("nan"))
                side_sds.append(float("nan"))
                side_fractions.append(float("nan"))
                side_percentiles.append(float("nan"))
                continue
            prepared_peers, prepared_peer_rows = prepared_peer_matrices[
                "left" if peer_matrix is left_peers else "right"
            ]
            peer_scores = spearman_against_prepared_peers(
                spec["sample_logfc"], prepared_peers, row_indices=prepared_peer_rows
            )
            summary = summarize_peer_scores(observed, peer_scores, column_stem)
            record.update(summary)
            side_values.append(summary[f"{column_stem}_mean_score"])
            side_sds.append(summary[f"{column_stem}_sd_score"])
            side_fractions.append(summary[f"{column_stem}_fraction_below_observed"])
            side_percentiles.append(summary[f"{column_stem}_corrected_percentile"])

        pair_stem = f"pb_{variant}_spearman_logfc_pair"
        pair_value = mean_available(side_values)
        record[pair_stem] = pair_value
        record[f"pb_delta_vs_{variant}_spearman_logfc"] = (
            float("nan")
            if (pd.isna(observed) or pd.isna(pair_value))
            else float(observed - pair_value)
        )
        if not variant.endswith("_centroid"):
            record[f"{pair_stem}_sd_score"] = mean_available(side_sds)
            record[f"{pair_stem}_fraction_below_observed"] = mean_available(side_fractions)
            record[f"{pair_stem}_corrected_percentile"] = mean_available(side_percentiles)

    return record


print(f"All-gene logFC per-peer baselines configured with max_peers={MAX_BASELINE_PEERS}")
# Out:
# All-gene logFC per-peer baselines configured with max_peers=512

# %%
peer_baseline_unresolved: list[dict[str, object]] = []

PEER_BASELINE_INPUT_FINGERPRINT = stable_json_fingerprint(
    {
        "version": "signature-peer-v5",
        "cap": MAX_BASELINE_PEERS,
        "seed": PEER_SAMPLING_SEED,
        "matched_metrics": frame_identity_fingerprint(
            matched_pair_metrics,
            context_join_columns + ["pubchem_cid", "left_obs_id", "right_obs_id"],
        ),
        "sources": sorted(
            (
                str(path.resolve()),
                int(path.stat().st_size),
                int(path.stat().st_mtime_ns),
            )
            for dataset_name, cell_type in matched_pairs[["dataset_a", "cell_type"]]
            .drop_duplicates()
            .itertuples(index=False, name=None)
            for path in [resolve_line_path(str(dataset_name), str(cell_type))]
        )
        + sorted(
            (
                str(path.resolve()),
                int(path.stat().st_size),
                int(path.stat().st_mtime_ns),
            )
            for dataset_name, cell_type in matched_pairs[["dataset_b", "cell_type"]]
            .drop_duplicates()
            .itertuples(index=False, name=None)
            for path in [resolve_line_path(str(dataset_name), str(cell_type))]
        ),
    }
)
peer_baseline_contexts = [
    (tuple(str(value) for value in context_key), group.copy())
    for context_key, group in matched_pairs.groupby(context_join_columns, sort=False)
]


def build_peer_baseline_context(context_item) -> pd.DataFrame:
    context_key, group = context_item
    dataset_a, dataset_b, cell_type, time_key, left_dose_key, right_dose_key = context_key
    print(
        f"Peer baselines for {pretty_label(dataset_a)} vs {pretty_label(dataset_b)} / {cell_type} / "
        f"time={time_key} / doses={left_dose_key} vs {right_dose_key}: {len(group)} matched sample pairs",
        flush=True,
    )
    records: list[dict[str, object]] = []
    row_progress = notebook_cache_module.ProgressReporter(
        total=len(group),
        label="peer_baseline_rows",
        every=100,
        min_interval_seconds=20.0,
    )
    for _, match_row in group.iterrows():
        try:
            records.append(compute_peer_baseline_record(match_row))
        except KeyError as exc:
            peer_baseline_unresolved.append({**match_row.to_dict(), "error": str(exc)})
        finally:
            row_progress.update(detail=f"{dataset_a} vs {dataset_b} / {cell_type}")
    return pd.DataFrame(records)


def build_peer_baselines() -> pd.DataFrame:
    return resumable_context_frame(
        "peer_baselines",
        OUTPUT_DIR / ".checkpoints" / "peer_baselines",
        peer_baseline_contexts,
        context_key=lambda item: item[0],
        build_context=build_peer_baseline_context,
        fingerprint=PEER_BASELINE_INPUT_FINGERPRINT,
        context_label=lambda item: " / ".join(item[0]),
    )


matched_pair_peer_baselines_path = OUTPUT_DIR / "matched_sample_pair_peer_baselines.tsv"
matched_pair_peer_baselines = cached_frame(
    "peer_baselines",
    matched_pair_peer_baselines_path,
    build_peer_baselines,
    fingerprint=PEER_BASELINE_INPUT_FINGERPRINT,
    required_columns=[
        "pb_observed_spearman_logfc",
        "pb_source_peer_spearman_logfc_pair",
        "pb_source_peer_spearman_logfc_pair_sd_score",
        "pb_target_peer_spearman_logfc_pair",
    ],
)
if matched_pair_peer_baselines.empty:
    raise ValueError("No matched sample pairs could be scored against the per-peer baselines.")

print(f"Scored {len(matched_pair_peer_baselines):,} matched sample pairs")

if peer_baseline_unresolved:
    peer_baseline_unresolved_frame = pd.DataFrame(peer_baseline_unresolved)
    peer_baseline_unresolved_path = OUTPUT_DIR / "unresolved_peer_baseline_pairs.tsv"
    peer_baseline_unresolved_frame.to_csv(peer_baseline_unresolved_path, sep="\t", index=False)
    print(
        f"Skipped {len(peer_baseline_unresolved_frame):,} matched sample pairs; "
        f"saved details to {peer_baseline_unresolved_path}"
    )

# Parity: the recomputed observed and source-centroid columns must reproduce the published
# ones, so any change in the reported deltas comes from the new baselines only.
peer_baseline_join_columns = [
    "dataset_a",
    "dataset_b",
    "cell_type",
    "time_key",
    "pubchem_cid",
    "left_obs_id",
    "right_obs_id",
    "left_dose_key",
    "right_dose_key",
]
parity_column_pairs = [
    ("pb_observed_spearman_logfc", "observed_spearman_logfc"),
    ("pb_source_centroid_spearman_logfc_left", "left_baseline_spearman_logfc"),
    ("pb_source_centroid_spearman_logfc_right", "right_baseline_spearman_logfc"),
    ("pb_source_centroid_spearman_logfc_pair", "baseline_pair_mean_spearman_logfc"),
]
parity_frame = matched_pair_peer_baselines.merge(
    matched_pair_metrics[peer_baseline_join_columns + [published for _, published in parity_column_pairs]],
    on=peer_baseline_join_columns,
    how="inner",
    validate="one_to_one",
)
if len(parity_frame) != len(matched_pair_peer_baselines):
    raise AssertionError(
        f"Parity join matched {len(parity_frame):,} of {len(matched_pair_peer_baselines):,} peer-baseline rows."
    )

parity_rows: list[dict[str, object]] = []
for recomputed_column, published_column in parity_column_pairs:
    recomputed = parity_frame[recomputed_column].to_numpy(dtype=np.float64)
    published = parity_frame[published_column].to_numpy(dtype=np.float64)
    both_finite = np.isfinite(recomputed) & np.isfinite(published)
    parity_rows.append(
        {
            "recomputed_column": recomputed_column,
            "published_column": published_column,
            "n_both_finite": int(both_finite.sum()),
            "n_finite_mismatch": int(np.sum(np.isfinite(recomputed) != np.isfinite(published))),
            "max_abs_diff": (
                float(np.max(np.abs(recomputed[both_finite] - published[both_finite])))
                if both_finite.any()
                else float("nan")
            ),
        }
    )
peer_baseline_parity = pd.DataFrame(parity_rows)
display(peer_baseline_parity)

if int(peer_baseline_parity["n_finite_mismatch"].sum()) > 0:
    raise AssertionError("Recomputed and published columns disagree on which rows are defined.")
worst_parity_diff = float(np.nanmax(peer_baseline_parity["max_abs_diff"].to_numpy(dtype=np.float64)))
if worst_parity_diff > 1e-6:
    raise AssertionError(
        f"Recomputed source-centroid parity check failed with max abs diff {worst_parity_diff:.3g}."
    )
print(f"Parity check passed; largest absolute difference {worst_parity_diff:.3g}.")
# Out:
# [peer_baselines] computing context 1/290: l1000_phase1 / l1000_phase2 / CVCL_0023 / 24 / 10 / 10
# Peer baselines for L1000 Phase I vs L1000 Phase II / CVCL_0023 / time=24 / doses=10 vs 10: 5788 matched sample pairs
# [peer_baseline_rows] 100/5,788 (1.7%) | elapsed 00:06 | 17.40/s | ETA 05:27 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 200/5,788 (3.5%) | elapsed 00:11 | 18.39/s | ETA 05:04 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 300/5,788 (5.2%) | elapsed 00:16 | 18.97/s | ETA 04:49 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 400/5,788 (6.9%) | elapsed 00:21 | 19.10/s | ETA 04:42 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 500/5,788 (8.6%) | elapsed 00:26 | 19.49/s | ETA 04:31 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 600/5,788 (10.4%) | elapsed 00:31 | 19.65/s | ETA 04:24 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 700/5,788 (12.1%) | elapsed 00:36 | 19.65/s | ETA 04:19 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 800/5,788 (13.8%) | elapsed 00:41 | 19.53/s | ETA 04:15 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 900/5,788 (15.5%) | elapsed 00:46 | 19.42/s | ETA 04:12 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 1,000/5,788 (17.3%) | elapsed 00:51 | 19.48/s | ETA 04:06 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 1,100/5,788 (19.0%) | elapsed 00:56 | 19.55/s | ETA 04:00 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 1,200/5,788 (20.7%) | elapsed 01:01 | 19.66/s | ETA 03:53 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 1,300/5,788 (22.5%) | elapsed 01:06 | 19.67/s | ETA 03:48 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 1,400/5,788 (24.2%) | elapsed 01:11 | 19.77/s | ETA 03:42 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 1,500/5,788 (25.9%) | elapsed 01:16 | 19.74/s | ETA 03:37 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 1,600/5,788 (27.6%) | elapsed 01:21 | 19.71/s | ETA 03:32 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 1,700/5,788 (29.4%) | elapsed 01:26 | 19.72/s | ETA 03:27 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 1,800/5,788 (31.1%) | elapsed 01:31 | 19.74/s | ETA 03:22 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 1,900/5,788 (32.8%) | elapsed 01:36 | 19.72/s | ETA 03:17 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 2,000/5,788 (34.6%) | elapsed 01:41 | 19.78/s | ETA 03:11 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 2,100/5,788 (36.3%) | elapsed 01:46 | 19.82/s | ETA 03:06 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 2,200/5,788 (38.0%) | elapsed 01:51 | 19.81/s | ETA 03:01 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 2,300/5,788 (39.7%) | elapsed 01:56 | 19.86/s | ETA 02:56 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 2,400/5,788 (41.5%) | elapsed 02:01 | 19.86/s | ETA 02:51 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 2,500/5,788 (43.2%) | elapsed 02:06 | 19.86/s | ETA 02:46 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 2,600/5,788 (44.9%) | elapsed 02:11 | 19.79/s | ETA 02:41 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 2,700/5,788 (46.6%) | elapsed 02:17 | 19.76/s | ETA 02:36 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 2,800/5,788 (48.4%) | elapsed 02:22 | 19.76/s | ETA 02:31 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 2,900/5,788 (50.1%) | elapsed 02:27 | 19.77/s | ETA 02:26 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 3,000/5,788 (51.8%) | elapsed 02:32 | 19.78/s | ETA 02:21 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 3,100/5,788 (53.6%) | elapsed 02:37 | 19.81/s | ETA 02:16 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 3,200/5,788 (55.3%) | elapsed 02:42 | 19.80/s | ETA 02:11 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 3,300/5,788 (57.0%) | elapsed 02:47 | 19.82/s | ETA 02:06 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 3,400/5,788 (58.7%) | elapsed 02:52 | 19.80/s | ETA 02:01 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 3,500/5,788 (60.5%) | elapsed 02:57 | 19.73/s | ETA 01:56 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 3,600/5,788 (62.2%) | elapsed 03:03 | 19.70/s | ETA 01:51 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 3,700/5,788 (63.9%) | elapsed 03:08 | 19.71/s | ETA 01:46 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 3,800/5,788 (65.7%) | elapsed 03:13 | 19.67/s | ETA 01:41 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 3,900/5,788 (67.4%) | elapsed 03:18 | 19.66/s | ETA 01:36 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 4,000/5,788 (69.1%) | elapsed 03:23 | 19.68/s | ETA 01:31 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 4,100/5,788 (70.8%) | elapsed 03:28 | 19.70/s | ETA 01:26 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 4,200/5,788 (72.6%) | elapsed 03:33 | 19.71/s | ETA 01:21 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 4,300/5,788 (74.3%) | elapsed 03:38 | 19.73/s | ETA 01:15 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 4,400/5,788 (76.0%) | elapsed 03:43 | 19.73/s | ETA 01:10 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 4,500/5,788 (77.7%) | elapsed 03:48 | 19.70/s | ETA 01:05 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 4,600/5,788 (79.5%) | elapsed 03:53 | 19.70/s | ETA 01:00 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 4,700/5,788 (81.2%) | elapsed 03:58 | 19.71/s | ETA 00:55 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 4,800/5,788 (82.9%) | elapsed 04:04 | 19.70/s | ETA 00:50 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 4,900/5,788 (84.7%) | elapsed 04:08 | 19.72/s | ETA 00:45 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 5,000/5,788 (86.4%) | elapsed 04:14 | 19.71/s | ETA 00:40 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 5,100/5,788 (88.1%) | elapsed 04:19 | 19.72/s | ETA 00:35 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 5,200/5,788 (89.8%) | elapsed 04:23 | 19.74/s | ETA 00:30 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 5,300/5,788 (91.6%) | elapsed 04:29 | 19.74/s | ETA 00:25 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 5,400/5,788 (93.3%) | elapsed 04:34 | 19.74/s | ETA 00:20 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 5,500/5,788 (95.0%) | elapsed 04:39 | 19.68/s | ETA 00:15 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 5,600/5,788 (96.8%) | elapsed 04:45 | 19.67/s | ETA 00:10 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 5,700/5,788 (98.5%) | elapsed 04:50 | 19.67/s | ETA 00:04 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baseline_rows] 5,788/5,788 (100.0%) | elapsed 04:54 | 19.67/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0023
# [peer_baselines] 1/290 (0.3%) | elapsed 04:55 | 0.00/s | ETA 23:40:44 | 0 reloaded, 1 computed
# [peer_baselines] computing context 2/290: l1000_phase1 / l1000_phase2 / CVCL_0031 / 24 / 10 / 10
# Peer baselines for L1000 Phase I vs L1000 Phase II / CVCL_0031 / time=24 / doses=10 vs 10: 7803 matched sample pairs
# [peer_baseline_rows] 100/7,803 (1.3%) | elapsed 00:11 | 9.08/s | ETA 14:08 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 200/7,803 (2.6%) | elapsed 00:20 | 9.78/s | ETA 12:58 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 300/7,803 (3.8%) | elapsed 00:30 | 9.90/s | ETA 12:38 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 400/7,803 (5.1%) | elapsed 00:41 | 9.86/s | ETA 12:31 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 500/7,803 (6.4%) | elapsed 00:50 | 10.00/s | ETA 12:10 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 600/7,803 (7.7%) | elapsed 01:00 | 10.06/s | ETA 11:56 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 700/7,803 (9.0%) | elapsed 01:09 | 10.09/s | ETA 11:44 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 800/7,803 (10.3%) | elapsed 01:19 | 10.07/s | ETA 11:35 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 900/7,803 (11.5%) | elapsed 01:29 | 10.12/s | ETA 11:22 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 1,000/7,803 (12.8%) | elapsed 01:39 | 10.08/s | ETA 11:15 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 1,100/7,803 (14.1%) | elapsed 01:49 | 10.12/s | ETA 11:02 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 1,200/7,803 (15.4%) | elapsed 01:58 | 10.16/s | ETA 10:50 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 1,300/7,803 (16.7%) | elapsed 02:08 | 10.17/s | ETA 10:39 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 1,400/7,803 (17.9%) | elapsed 02:17 | 10.20/s | ETA 10:28 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 1,500/7,803 (19.2%) | elapsed 02:28 | 10.17/s | ETA 10:20 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 1,600/7,803 (20.5%) | elapsed 02:37 | 10.17/s | ETA 10:10 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 1,700/7,803 (21.8%) | elapsed 02:48 | 10.12/s | ETA 10:03 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 1,800/7,803 (23.1%) | elapsed 02:57 | 10.15/s | ETA 09:52 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 1,900/7,803 (24.3%) | elapsed 03:07 | 10.14/s | ETA 09:42 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 2,000/7,803 (25.6%) | elapsed 03:18 | 10.11/s | ETA 09:34 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 2,100/7,803 (26.9%) | elapsed 03:28 | 10.09/s | ETA 09:25 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 2,200/7,803 (28.2%) | elapsed 03:38 | 10.08/s | ETA 09:16 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 2,300/7,803 (29.5%) | elapsed 03:49 | 10.05/s | ETA 09:07 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 2,400/7,803 (30.8%) | elapsed 03:58 | 10.07/s | ETA 08:57 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 2,500/7,803 (32.0%) | elapsed 04:08 | 10.07/s | ETA 08:47 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 2,600/7,803 (33.3%) | elapsed 04:18 | 10.06/s | ETA 08:37 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 2,700/7,803 (34.6%) | elapsed 04:28 | 10.06/s | ETA 08:27 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 2,800/7,803 (35.9%) | elapsed 04:38 | 10.08/s | ETA 08:16 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 2,900/7,803 (37.2%) | elapsed 04:48 | 10.07/s | ETA 08:07 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 3,000/7,803 (38.4%) | elapsed 04:58 | 10.05/s | ETA 07:58 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 3,100/7,803 (39.7%) | elapsed 05:08 | 10.06/s | ETA 07:48 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 3,200/7,803 (41.0%) | elapsed 05:18 | 10.05/s | ETA 07:38 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 3,300/7,803 (42.3%) | elapsed 05:28 | 10.06/s | ETA 07:28 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 3,400/7,803 (43.6%) | elapsed 05:38 | 10.07/s | ETA 07:17 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 3,500/7,803 (44.9%) | elapsed 05:47 | 10.08/s | ETA 07:07 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 3,600/7,803 (46.1%) | elapsed 05:57 | 10.09/s | ETA 06:57 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 3,700/7,803 (47.4%) | elapsed 06:06 | 10.11/s | ETA 06:46 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 3,800/7,803 (48.7%) | elapsed 06:16 | 10.12/s | ETA 06:36 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 3,900/7,803 (50.0%) | elapsed 06:25 | 10.12/s | ETA 06:26 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 4,000/7,803 (51.3%) | elapsed 06:35 | 10.12/s | ETA 06:16 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 4,100/7,803 (52.5%) | elapsed 06:45 | 10.11/s | ETA 06:06 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 4,200/7,803 (53.8%) | elapsed 06:55 | 10.12/s | ETA 05:56 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 4,300/7,803 (55.1%) | elapsed 07:04 | 10.13/s | ETA 05:46 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 4,400/7,803 (56.4%) | elapsed 07:14 | 10.14/s | ETA 05:35 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 4,500/7,803 (57.7%) | elapsed 07:23 | 10.15/s | ETA 05:25 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 4,600/7,803 (59.0%) | elapsed 07:33 | 10.16/s | ETA 05:15 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 4,700/7,803 (60.2%) | elapsed 07:43 | 10.15/s | ETA 05:06 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 4,800/7,803 (61.5%) | elapsed 07:54 | 10.13/s | ETA 04:56 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 4,900/7,803 (62.8%) | elapsed 08:04 | 10.13/s | ETA 04:47 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 5,000/7,803 (64.1%) | elapsed 08:13 | 10.14/s | ETA 04:36 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 5,100/7,803 (65.4%) | elapsed 08:23 | 10.13/s | ETA 04:27 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 5,200/7,803 (66.6%) | elapsed 08:33 | 10.13/s | ETA 04:17 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 5,300/7,803 (67.9%) | elapsed 08:44 | 10.11/s | ETA 04:08 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 5,400/7,803 (69.2%) | elapsed 08:55 | 10.10/s | ETA 03:58 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 5,500/7,803 (70.5%) | elapsed 09:05 | 10.09/s | ETA 03:48 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 5,600/7,803 (71.8%) | elapsed 09:16 | 10.07/s | ETA 03:39 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 5,700/7,803 (73.0%) | elapsed 09:26 | 10.07/s | ETA 03:29 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 5,800/7,803 (74.3%) | elapsed 09:36 | 10.06/s | ETA 03:19 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 5,900/7,803 (75.6%) | elapsed 09:46 | 10.07/s | ETA 03:09 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 6,000/7,803 (76.9%) | elapsed 09:56 | 10.07/s | ETA 02:59 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 6,100/7,803 (78.2%) | elapsed 10:05 | 10.08/s | ETA 02:49 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 6,200/7,803 (79.5%) | elapsed 10:14 | 10.09/s | ETA 02:39 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 6,300/7,803 (80.7%) | elapsed 10:25 | 10.09/s | ETA 02:29 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 6,400/7,803 (82.0%) | elapsed 10:36 | 10.06/s | ETA 02:19 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 6,500/7,803 (83.3%) | elapsed 10:47 | 10.05/s | ETA 02:10 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 6,600/7,803 (84.6%) | elapsed 10:58 | 10.03/s | ETA 02:00 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 6,700/7,803 (85.9%) | elapsed 11:08 | 10.04/s | ETA 01:50 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 6,800/7,803 (87.1%) | elapsed 11:18 | 10.03/s | ETA 01:40 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 6,900/7,803 (88.4%) | elapsed 11:28 | 10.03/s | ETA 01:30 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 7,000/7,803 (89.7%) | elapsed 11:38 | 10.03/s | ETA 01:20 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 7,100/7,803 (91.0%) | elapsed 11:47 | 10.04/s | ETA 01:10 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 7,200/7,803 (92.3%) | elapsed 11:56 | 10.05/s | ETA 01:00 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 7,300/7,803 (93.6%) | elapsed 12:06 | 10.05/s | ETA 00:50 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 7,400/7,803 (94.8%) | elapsed 12:16 | 10.06/s | ETA 00:40 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 7,500/7,803 (96.1%) | elapsed 12:25 | 10.06/s | ETA 00:30 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 7,600/7,803 (97.4%) | elapsed 12:35 | 10.07/s | ETA 00:20 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 7,700/7,803 (98.7%) | elapsed 12:44 | 10.07/s | ETA 00:10 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 7,800/7,803 (100.0%) | elapsed 12:54 | 10.08/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 7,803/7,803 (100.0%) | elapsed 12:54 | 10.08/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baselines] 2/290 (0.7%) | elapsed 17:50 | 0.00/s | ETA 42:48:00 | 0 reloaded, 2 computed
# [peer_baselines] computing context 3/290: l1000_phase1 / l1000_phase2 / CVCL_0031 / 24 / 2 / 3.33
# Peer baselines for L1000 Phase I vs L1000 Phase II / CVCL_0031 / time=24 / doses=2 vs 3.33: 746 matched sample pairs
# [peer_baseline_rows] 100/746 (13.4%) | elapsed 00:01 | 72.40/s | ETA 00:09 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 200/746 (26.8%) | elapsed 00:03 | 74.43/s | ETA 00:07 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 300/746 (40.2%) | elapsed 00:04 | 74.84/s | ETA 00:06 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 400/746 (53.6%) | elapsed 00:05 | 75.33/s | ETA 00:05 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 500/746 (67.0%) | elapsed 00:07 | 75.40/s | ETA 00:03 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 600/746 (80.4%) | elapsed 00:08 | 75.65/s | ETA 00:02 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 700/746 (93.8%) | elapsed 00:09 | 75.65/s | ETA 00:01 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 746/746 (100.0%) | elapsed 00:10 | 75.62/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baselines] computing context 4/290: l1000_phase1 / l1000_phase2 / CVCL_0031 / 24 / 0.4 / 0.37037
# Peer baselines for L1000 Phase I vs L1000 Phase II / CVCL_0031 / time=24 / doses=0.4 vs 0.37037: 278 matched sample pairs
# [peer_baseline_rows] 100/278 (36.0%) | elapsed 00:05 | 19.30/s | ETA 00:09 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 200/278 (71.9%) | elapsed 00:10 | 19.40/s | ETA 00:04 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 278/278 (100.0%) | elapsed 00:14 | 19.21/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baselines] computing context 5/290: l1000_phase1 / l1000_phase2 / CVCL_0031 / 24 / 0.08 / 0.12
# Peer baselines for L1000 Phase I vs L1000 Phase II / CVCL_0031 / time=24 / doses=0.08 vs 0.12: 807 matched sample pairs
# [peer_baseline_rows] 100/807 (12.4%) | elapsed 00:01 | 70.12/s | ETA 00:10 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 200/807 (24.8%) | elapsed 00:03 | 72.99/s | ETA 00:08 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 300/807 (37.2%) | elapsed 00:04 | 73.84/s | ETA 00:07 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 400/807 (49.6%) | elapsed 00:05 | 73.76/s | ETA 00:06 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 500/807 (62.0%) | elapsed 00:07 | 74.40/s | ETA 00:04 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 600/807 (74.3%) | elapsed 00:08 | 74.86/s | ETA 00:03 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 700/807 (86.7%) | elapsed 00:09 | 75.21/s | ETA 00:01 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 800/807 (99.1%) | elapsed 00:11 | 75.49/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 807/807 (100.0%) | elapsed 00:11 | 75.50/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baselines] 5/290 (1.7%) | elapsed 18:25 | 0.00/s | ETA 17:30:01 | 0 reloaded, 5 computed
# [peer_baselines] computing context 6/290: l1000_phase1 / l1000_phase2 / CVCL_0035 / 24 / 10 / 10
# Peer baselines for L1000 Phase I vs L1000 Phase II / CVCL_0035 / time=24 / doses=10 vs 10: 5660 matched sample pairs
# [peer_baseline_rows] 100/5,660 (1.8%) | elapsed 00:11 | 9.17/s | ETA 10:06 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 200/5,660 (3.5%) | elapsed 00:21 | 9.62/s | ETA 09:28 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 300/5,660 (5.3%) | elapsed 00:31 | 9.70/s | ETA 09:13 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 400/5,660 (7.1%) | elapsed 00:41 | 9.71/s | ETA 09:02 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 500/5,660 (8.8%) | elapsed 00:51 | 9.78/s | ETA 08:47 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 600/5,660 (10.6%) | elapsed 01:01 | 9.84/s | ETA 08:34 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 700/5,660 (12.4%) | elapsed 01:11 | 9.84/s | ETA 08:24 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 800/5,660 (14.1%) | elapsed 01:21 | 9.82/s | ETA 08:15 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 900/5,660 (15.9%) | elapsed 01:31 | 9.87/s | ETA 08:02 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 1,000/5,660 (17.7%) | elapsed 01:41 | 9.86/s | ETA 07:53 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 1,100/5,660 (19.4%) | elapsed 01:52 | 9.85/s | ETA 07:43 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 1,200/5,660 (21.2%) | elapsed 02:01 | 9.91/s | ETA 07:30 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 1,300/5,660 (23.0%) | elapsed 02:11 | 9.93/s | ETA 07:19 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 1,400/5,660 (24.7%) | elapsed 02:21 | 9.92/s | ETA 07:09 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 1,500/5,660 (26.5%) | elapsed 02:31 | 9.95/s | ETA 06:58 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 1,600/5,660 (28.3%) | elapsed 02:40 | 9.98/s | ETA 06:47 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 1,700/5,660 (30.0%) | elapsed 02:50 | 9.99/s | ETA 06:36 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 1,800/5,660 (31.8%) | elapsed 03:00 | 9.98/s | ETA 06:27 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 1,900/5,660 (33.6%) | elapsed 03:10 | 10.00/s | ETA 06:16 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 2,000/5,660 (35.3%) | elapsed 03:20 | 9.99/s | ETA 06:06 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 2,100/5,660 (37.1%) | elapsed 03:30 | 9.98/s | ETA 05:57 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 2,200/5,660 (38.9%) | elapsed 03:41 | 9.95/s | ETA 05:48 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 2,300/5,660 (40.6%) | elapsed 03:52 | 9.93/s | ETA 05:38 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 2,400/5,660 (42.4%) | elapsed 04:01 | 9.95/s | ETA 05:28 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 2,500/5,660 (44.2%) | elapsed 04:11 | 9.96/s | ETA 05:17 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 2,600/5,660 (45.9%) | elapsed 04:21 | 9.97/s | ETA 05:07 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 2,700/5,660 (47.7%) | elapsed 04:31 | 9.98/s | ETA 04:57 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 2,800/5,660 (49.5%) | elapsed 04:40 | 9.99/s | ETA 04:46 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 2,900/5,660 (51.2%) | elapsed 04:50 | 10.00/s | ETA 04:36 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 3,000/5,660 (53.0%) | elapsed 05:00 | 10.00/s | ETA 04:26 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 3,100/5,660 (54.8%) | elapsed 05:10 | 10.00/s | ETA 04:16 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 3,200/5,660 (56.5%) | elapsed 05:20 | 9.99/s | ETA 04:06 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 3,300/5,660 (58.3%) | elapsed 05:30 | 9.99/s | ETA 03:56 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 3,400/5,660 (60.1%) | elapsed 05:40 | 9.99/s | ETA 03:46 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 3,500/5,660 (61.8%) | elapsed 05:51 | 9.96/s | ETA 03:37 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 3,600/5,660 (63.6%) | elapsed 06:01 | 9.96/s | ETA 03:27 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 3,700/5,660 (65.4%) | elapsed 06:11 | 9.97/s | ETA 03:17 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 3,800/5,660 (67.1%) | elapsed 06:21 | 9.99/s | ETA 03:06 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 3,900/5,660 (68.9%) | elapsed 06:30 | 10.00/s | ETA 02:56 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 4,000/5,660 (70.7%) | elapsed 06:40 | 10.00/s | ETA 02:46 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 4,100/5,660 (72.4%) | elapsed 06:50 | 10.01/s | ETA 02:36 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 4,200/5,660 (74.2%) | elapsed 06:59 | 10.02/s | ETA 02:26 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 4,300/5,660 (76.0%) | elapsed 07:09 | 10.03/s | ETA 02:16 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 4,400/5,660 (77.7%) | elapsed 07:19 | 10.03/s | ETA 02:06 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 4,500/5,660 (79.5%) | elapsed 07:29 | 10.03/s | ETA 01:56 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 4,600/5,660 (81.3%) | elapsed 07:39 | 10.01/s | ETA 01:46 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 4,700/5,660 (83.0%) | elapsed 07:49 | 10.01/s | ETA 01:36 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 4,800/5,660 (84.8%) | elapsed 08:00 | 10.00/s | ETA 01:26 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 4,900/5,660 (86.6%) | elapsed 08:10 | 10.00/s | ETA 01:16 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 5,000/5,660 (88.3%) | elapsed 08:20 | 10.00/s | ETA 01:06 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 5,100/5,660 (90.1%) | elapsed 08:31 | 9.98/s | ETA 00:56 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 5,200/5,660 (91.9%) | elapsed 08:41 | 9.97/s | ETA 00:46 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 5,300/5,660 (93.6%) | elapsed 08:51 | 9.99/s | ETA 00:36 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 5,400/5,660 (95.4%) | elapsed 09:00 | 10.00/s | ETA 00:26 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 5,500/5,660 (97.2%) | elapsed 09:10 | 10.00/s | ETA 00:16 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 5,600/5,660 (98.9%) | elapsed 09:20 | 9.99/s | ETA 00:06 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baseline_rows] 5,660/5,660 (100.0%) | elapsed 09:27 | 9.98/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0035
# [peer_baselines] 6/290 (2.1%) | elapsed 27:53 | 0.00/s | ETA 21:59:54 | 0 reloaded, 6 computed
# [peer_baselines] computing context 7/290: l1000_phase1 / l1000_phase2 / CVCL_U602 / 24 / 10 / 10
# Peer baselines for L1000 Phase I vs L1000 Phase II / CVCL_U602 / time=24 / doses=10 vs 10: 763 matched sample pairs
# [peer_baseline_rows] 100/763 (13.1%) | elapsed 00:05 | 18.83/s | ETA 00:35 | l1000_phase1 vs l1000_phase2 / CVCL_U602
# [peer_baseline_rows] 200/763 (26.2%) | elapsed 00:10 | 19.14/s | ETA 00:29 | l1000_phase1 vs l1000_phase2 / CVCL_U602
# [peer_baseline_rows] 300/763 (39.3%) | elapsed 00:15 | 19.52/s | ETA 00:24 | l1000_phase1 vs l1000_phase2 / CVCL_U602
# [peer_baseline_rows] 400/763 (52.4%) | elapsed 00:20 | 19.67/s | ETA 00:18 | l1000_phase1 vs l1000_phase2 / CVCL_U602
# [peer_baseline_rows] 500/763 (65.5%) | elapsed 00:25 | 19.81/s | ETA 00:13 | l1000_phase1 vs l1000_phase2 / CVCL_U602
# [peer_baseline_rows] 600/763 (78.6%) | elapsed 00:30 | 19.87/s | ETA 00:08 | l1000_phase1 vs l1000_phase2 / CVCL_U602
# [peer_baseline_rows] 700/763 (91.7%) | elapsed 00:35 | 19.92/s | ETA 00:03 | l1000_phase1 vs l1000_phase2 / CVCL_U602
# [peer_baseline_rows] 763/763 (100.0%) | elapsed 00:38 | 20.03/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_U602
# [peer_baselines] 7/290 (2.4%) | elapsed 28:31 | 0.00/s | ETA 19:13:06 | 0 reloaded, 7 computed
# [peer_baselines] computing context 8/290: l1000_phase1 / l1000_phase2 / NEU / 24 / 10 / 10
# Peer baselines for L1000 Phase I vs L1000 Phase II / NEU / time=24 / doses=10 vs 10: 573 matched sample pairs
# [peer_baseline_rows] 100/573 (17.5%) | elapsed 00:05 | 19.62/s | ETA 00:24 | l1000_phase1 vs l1000_phase2 / NEU
# [peer_baseline_rows] 200/573 (34.9%) | elapsed 00:10 | 20.05/s | ETA 00:19 | l1000_phase1 vs l1000_phase2 / NEU
# [peer_baseline_rows] 300/573 (52.4%) | elapsed 00:15 | 20.06/s | ETA 00:14 | l1000_phase1 vs l1000_phase2 / NEU
# [peer_baseline_rows] 400/573 (69.8%) | elapsed 00:20 | 19.99/s | ETA 00:09 | l1000_phase1 vs l1000_phase2 / NEU
# [peer_baseline_rows] 500/573 (87.3%) | elapsed 00:25 | 20.07/s | ETA 00:04 | l1000_phase1 vs l1000_phase2 / NEU
# [peer_baseline_rows] 573/573 (100.0%) | elapsed 00:29 | 20.06/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / NEU
# [peer_baselines] computing context 9/290: l1000_phase1 / l1000_phase2 / NPC / 24 / 10 / 10
# Peer baselines for L1000 Phase I vs L1000 Phase II / NPC / time=24 / doses=10 vs 10: 971 matched sample pairs
# [peer_baseline_rows] 100/971 (10.3%) | elapsed 00:06 | 18.10/s | ETA 00:48 | l1000_phase1 vs l1000_phase2 / NPC
# [peer_baseline_rows] 200/971 (20.6%) | elapsed 00:10 | 19.06/s | ETA 00:40 | l1000_phase1 vs l1000_phase2 / NPC
# [peer_baseline_rows] 300/971 (30.9%) | elapsed 00:15 | 19.36/s | ETA 00:35 | l1000_phase1 vs l1000_phase2 / NPC
# [peer_baseline_rows] 400/971 (41.2%) | elapsed 00:21 | 19.18/s | ETA 00:30 | l1000_phase1 vs l1000_phase2 / NPC
# [peer_baseline_rows] 500/971 (51.5%) | elapsed 00:26 | 19.24/s | ETA 00:24 | l1000_phase1 vs l1000_phase2 / NPC
# [peer_baseline_rows] 600/971 (61.8%) | elapsed 00:31 | 19.33/s | ETA 00:19 | l1000_phase1 vs l1000_phase2 / NPC
# [peer_baseline_rows] 700/971 (72.1%) | elapsed 00:36 | 19.40/s | ETA 00:14 | l1000_phase1 vs l1000_phase2 / NPC
# [peer_baseline_rows] 800/971 (82.4%) | elapsed 00:41 | 19.41/s | ETA 00:09 | l1000_phase1 vs l1000_phase2 / NPC
# [peer_baseline_rows] 900/971 (92.7%) | elapsed 00:46 | 19.38/s | ETA 00:04 | l1000_phase1 vs l1000_phase2 / NPC
# [peer_baseline_rows] 971/971 (100.0%) | elapsed 00:50 | 19.45/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / NPC
# [peer_baselines] 9/290 (3.1%) | elapsed 29:50 | 0.01/s | ETA 15:31:31 | 0 reloaded, 9 computed
# [peer_baselines] computing context 10/290: l1000_phase1 / l1000_phase2 / CVCL_0031 / 24 / 0.4 / 0.37
# Peer baselines for L1000 Phase I vs L1000 Phase II / CVCL_0031 / time=24 / doses=0.4 vs 0.37: 367 matched sample pairs
# [peer_baseline_rows] 100/367 (27.2%) | elapsed 00:01 | 69.74/s | ETA 00:04 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 200/367 (54.5%) | elapsed 00:03 | 70.98/s | ETA 00:02 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 300/367 (81.7%) | elapsed 00:04 | 71.70/s | ETA 00:01 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baseline_rows] 367/367 (100.0%) | elapsed 00:05 | 71.91/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0031
# [peer_baselines] computing context 11/290: l1000_phase1 / l1000_phase2 / CVCL_0033 / 24 / 10 / 10
# Peer baselines for L1000 Phase I vs L1000 Phase II / CVCL_0033 / time=24 / doses=10 vs 10: 730 matched sample pairs
# [peer_baseline_rows] 100/730 (13.7%) | elapsed 00:01 | 80.48/s | ETA 00:08 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baseline_rows] 200/730 (27.4%) | elapsed 00:02 | 82.91/s | ETA 00:06 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baseline_rows] 300/730 (41.1%) | elapsed 00:04 | 83.32/s | ETA 00:05 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baseline_rows] 400/730 (54.8%) | elapsed 00:05 | 83.91/s | ETA 00:04 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baseline_rows] 500/730 (68.5%) | elapsed 00:06 | 84.08/s | ETA 00:03 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baseline_rows] 600/730 (82.2%) | elapsed 00:07 | 84.18/s | ETA 00:02 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baseline_rows] 700/730 (95.9%) | elapsed 00:08 | 84.29/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baseline_rows] 730/730 (100.0%) | elapsed 00:09 | 84.34/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baselines] computing context 12/290: l1000_phase1 / l1000_phase2 / CVCL_0033 / 24 / 2 / 1.11
# Peer baselines for L1000 Phase I vs L1000 Phase II / CVCL_0033 / time=24 / doses=2 vs 1.11: 5 matched sample pairs
# [peer_baseline_rows] 5/5 (100.0%) | elapsed 00:00 | 47.61/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baselines] computing context 13/290: l1000_phase1 / l1000_phase2 / CVCL_0033 / 24 / 0.4 / 0.37
# Peer baselines for L1000 Phase I vs L1000 Phase II / CVCL_0033 / time=24 / doses=0.4 vs 0.37: 811 matched sample pairs
# [peer_baseline_rows] 100/811 (12.3%) | elapsed 00:01 | 81.57/s | ETA 00:09 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baseline_rows] 200/811 (24.7%) | elapsed 00:02 | 82.28/s | ETA 00:07 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baseline_rows] 300/811 (37.0%) | elapsed 00:04 | 82.13/s | ETA 00:06 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baseline_rows] 400/811 (49.3%) | elapsed 00:05 | 82.29/s | ETA 00:05 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baseline_rows] 500/811 (61.7%) | elapsed 00:06 | 82.38/s | ETA 00:04 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baseline_rows] 600/811 (74.0%) | elapsed 00:07 | 82.54/s | ETA 00:03 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baseline_rows] 700/811 (86.3%) | elapsed 00:08 | 82.70/s | ETA 00:01 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baseline_rows] 800/811 (98.6%) | elapsed 00:10 | 82.75/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baseline_rows] 811/811 (100.0%) | elapsed 00:10 | 82.76/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baselines] computing context 14/290: l1000_phase1 / l1000_phase2 / CVCL_0033 / 24 / 0.08 / 0.12
# Peer baselines for L1000 Phase I vs L1000 Phase II / CVCL_0033 / time=24 / doses=0.08 vs 0.12: 825 matched sample pairs
# [peer_baseline_rows] 100/825 (12.1%) | elapsed 00:01 | 82.29/s | ETA 00:09 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baseline_rows] 200/825 (24.2%) | elapsed 00:02 | 83.59/s | ETA 00:07 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baseline_rows] 300/825 (36.4%) | elapsed 00:04 | 84.16/s | ETA 00:06 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baseline_rows] 400/825 (48.5%) | elapsed 00:05 | 84.51/s | ETA 00:05 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baseline_rows] 500/825 (60.6%) | elapsed 00:06 | 84.46/s | ETA 00:04 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baseline_rows] 600/825 (72.7%) | elapsed 00:07 | 84.73/s | ETA 00:03 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baseline_rows] 700/825 (84.8%) | elapsed 00:08 | 84.70/s | ETA 00:01 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baseline_rows] 800/825 (97.0%) | elapsed 00:09 | 84.78/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baseline_rows] 825/825 (100.0%) | elapsed 00:10 | 84.79/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0033
# [peer_baselines] 14/290 (4.8%) | elapsed 30:24 | 0.01/s | ETA 9:59:18 | 0 reloaded, 14 computed
# [peer_baselines] computing context 15/290: l1000_phase1 / l1000_phase2 / CVCL_0062 / 24 / 10 / 10
# Peer baselines for L1000 Phase I vs L1000 Phase II / CVCL_0062 / time=24 / doses=10 vs 10: 827 matched sample pairs
# [peer_baseline_rows] 100/827 (12.1%) | elapsed 00:01 | 88.45/s | ETA 00:08 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 200/827 (24.2%) | elapsed 00:02 | 91.62/s | ETA 00:07 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 300/827 (36.3%) | elapsed 00:03 | 92.36/s | ETA 00:06 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 400/827 (48.4%) | elapsed 00:04 | 92.67/s | ETA 00:05 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 500/827 (60.5%) | elapsed 00:05 | 93.04/s | ETA 00:04 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 600/827 (72.6%) | elapsed 00:06 | 92.33/s | ETA 00:02 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 700/827 (84.6%) | elapsed 00:08 | 92.68/s | ETA 00:01 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 800/827 (96.7%) | elapsed 00:09 | 92.83/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 827/827 (100.0%) | elapsed 00:09 | 92.82/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baselines] computing context 16/290: l1000_phase1 / l1000_phase2 / CVCL_0062 / 24 / 2 / 3.33
# Peer baselines for L1000 Phase I vs L1000 Phase II / CVCL_0062 / time=24 / doses=2 vs 3.33: 944 matched sample pairs
# [peer_baseline_rows] 100/944 (10.6%) | elapsed 00:01 | 87.61/s | ETA 00:10 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 200/944 (21.2%) | elapsed 00:02 | 88.22/s | ETA 00:08 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 300/944 (31.8%) | elapsed 00:03 | 87.92/s | ETA 00:07 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 400/944 (42.4%) | elapsed 00:05 | 88.25/s | ETA 00:06 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 500/944 (53.0%) | elapsed 00:06 | 88.54/s | ETA 00:05 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 600/944 (63.6%) | elapsed 00:07 | 88.88/s | ETA 00:04 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 700/944 (74.2%) | elapsed 00:08 | 88.89/s | ETA 00:03 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 800/944 (84.7%) | elapsed 00:09 | 89.06/s | ETA 00:02 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 900/944 (95.3%) | elapsed 00:10 | 89.07/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 944/944 (100.0%) | elapsed 00:11 | 89.08/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baselines] computing context 17/290: l1000_phase1 / l1000_phase2 / CVCL_0062 / 24 / 0.4 / 0.37
# Peer baselines for L1000 Phase I vs L1000 Phase II / CVCL_0062 / time=24 / doses=0.4 vs 0.37: 989 matched sample pairs
# [peer_baseline_rows] 100/989 (10.1%) | elapsed 00:01 | 87.96/s | ETA 00:10 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 200/989 (20.2%) | elapsed 00:02 | 85.68/s | ETA 00:09 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 300/989 (30.3%) | elapsed 00:03 | 87.12/s | ETA 00:08 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 400/989 (40.4%) | elapsed 00:05 | 87.60/s | ETA 00:07 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 500/989 (50.6%) | elapsed 00:06 | 87.87/s | ETA 00:06 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 600/989 (60.7%) | elapsed 00:07 | 88.06/s | ETA 00:04 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 700/989 (70.8%) | elapsed 00:08 | 88.22/s | ETA 00:03 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 800/989 (80.9%) | elapsed 00:09 | 88.49/s | ETA 00:02 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 900/989 (91.0%) | elapsed 00:10 | 88.51/s | ETA 00:01 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 989/989 (100.0%) | elapsed 00:11 | 88.71/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baselines] 17/290 (5.9%) | elapsed 30:55 | 0.01/s | ETA 8:16:29 | 0 reloaded, 17 computed
# [peer_baselines] computing context 18/290: l1000_phase1 / l1000_phase2 / CVCL_0062 / 24 / 0.08 / 0.12
# Peer baselines for L1000 Phase I vs L1000 Phase II / CVCL_0062 / time=24 / doses=0.08 vs 0.12: 979 matched sample pairs
# [peer_baseline_rows] 100/979 (10.2%) | elapsed 00:01 | 86.61/s | ETA 00:10 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 200/979 (20.4%) | elapsed 00:02 | 88.00/s | ETA 00:09 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 300/979 (30.6%) | elapsed 00:03 | 88.22/s | ETA 00:08 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 400/979 (40.9%) | elapsed 00:05 | 88.52/s | ETA 00:07 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 500/979 (51.1%) | elapsed 00:06 | 88.92/s | ETA 00:05 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 600/979 (61.3%) | elapsed 00:07 | 88.96/s | ETA 00:04 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 700/979 (71.5%) | elapsed 00:08 | 89.28/s | ETA 00:03 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 800/979 (81.7%) | elapsed 00:09 | 89.40/s | ETA 00:02 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 900/979 (91.9%) | elapsed 00:10 | 89.47/s | ETA 00:01 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baseline_rows] 979/979 (100.0%) | elapsed 00:11 | 89.63/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0062
# [peer_baselines] computing context 19/290: l1000_phase1 / l1000_phase2 / CVCL_0178 / 24 / 10 / 10
# Peer baselines for L1000 Phase I vs L1000 Phase II / CVCL_0178 / time=24 / doses=10 vs 10: 638 matched sample pairs
# [peer_baseline_rows] 100/638 (15.7%) | elapsed 00:01 | 85.52/s | ETA 00:06 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baseline_rows] 200/638 (31.3%) | elapsed 00:02 | 87.93/s | ETA 00:05 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baseline_rows] 300/638 (47.0%) | elapsed 00:03 | 88.29/s | ETA 00:04 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baseline_rows] 400/638 (62.7%) | elapsed 00:05 | 88.56/s | ETA 00:03 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baseline_rows] 500/638 (78.4%) | elapsed 00:06 | 88.81/s | ETA 00:02 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baseline_rows] 600/638 (94.0%) | elapsed 00:07 | 88.99/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baseline_rows] 638/638 (100.0%) | elapsed 00:07 | 89.08/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baselines] computing context 20/290: l1000_phase1 / l1000_phase2 / CVCL_0178 / 24 / 2 / 3.33
# Peer baselines for L1000 Phase I vs L1000 Phase II / CVCL_0178 / time=24 / doses=2 vs 3.33: 665 matched sample pairs
# [peer_baseline_rows] 100/665 (15.0%) | elapsed 00:01 | 85.83/s | ETA 00:07 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baseline_rows] 200/665 (30.1%) | elapsed 00:02 | 86.43/s | ETA 00:05 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baseline_rows] 300/665 (45.1%) | elapsed 00:03 | 87.38/s | ETA 00:04 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baseline_rows] 400/665 (60.2%) | elapsed 00:05 | 88.02/s | ETA 00:03 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baseline_rows] 500/665 (75.2%) | elapsed 00:06 | 88.58/s | ETA 00:02 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baseline_rows] 600/665 (90.2%) | elapsed 00:07 | 88.43/s | ETA 00:01 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baseline_rows] 665/665 (100.0%) | elapsed 00:08 | 88.60/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baselines] computing context 21/290: l1000_phase1 / l1000_phase2 / CVCL_0178 / 24 / 0.4 / 0.37
# Peer baselines for L1000 Phase I vs L1000 Phase II / CVCL_0178 / time=24 / doses=0.4 vs 0.37: 678 matched sample pairs
# [peer_baseline_rows] 100/678 (14.7%) | elapsed 00:01 | 85.10/s | ETA 00:07 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baseline_rows] 200/678 (29.5%) | elapsed 00:02 | 86.68/s | ETA 00:06 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baseline_rows] 300/678 (44.2%) | elapsed 00:03 | 87.64/s | ETA 00:04 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baseline_rows] 400/678 (59.0%) | elapsed 00:05 | 87.48/s | ETA 00:03 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baseline_rows] 500/678 (73.7%) | elapsed 00:06 | 88.06/s | ETA 00:02 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baseline_rows] 600/678 (88.5%) | elapsed 00:07 | 88.19/s | ETA 00:01 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baseline_rows] 678/678 (100.0%) | elapsed 00:08 | 88.39/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baselines] 21/290 (7.2%) | elapsed 31:29 | 0.01/s | ETA 6:43:13 | 0 reloaded, 21 computed
# [peer_baselines] computing context 22/290: l1000_phase1 / l1000_phase2 / CVCL_0178 / 24 / 0.08 / 0.12
# Peer baselines for L1000 Phase I vs L1000 Phase II / CVCL_0178 / time=24 / doses=0.08 vs 0.12: 689 matched sample pairs
# [peer_baseline_rows] 100/689 (14.5%) | elapsed 00:01 | 85.77/s | ETA 00:07 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baseline_rows] 200/689 (29.0%) | elapsed 00:02 | 87.18/s | ETA 00:06 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baseline_rows] 300/689 (43.5%) | elapsed 00:03 | 87.89/s | ETA 00:04 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baseline_rows] 400/689 (58.1%) | elapsed 00:05 | 87.54/s | ETA 00:03 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baseline_rows] 500/689 (72.6%) | elapsed 00:06 | 88.03/s | ETA 00:02 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baseline_rows] 600/689 (87.1%) | elapsed 00:07 | 88.30/s | ETA 00:01 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baseline_rows] 689/689 (100.0%) | elapsed 00:08 | 88.47/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0178
# [peer_baselines] computing context 23/290: l1000_phase1 / l1000_phase2 / CVCL_0332 / 24 / 10 / 10
# Peer baselines for L1000 Phase I vs L1000 Phase II / CVCL_0332 / time=24 / doses=10 vs 10: 511 matched sample pairs
# [peer_baseline_rows] 100/511 (19.6%) | elapsed 00:01 | 85.51/s | ETA 00:05 | l1000_phase1 vs l1000_phase2 / CVCL_0332
# [peer_baseline_rows] 200/511 (39.1%) | elapsed 00:02 | 87.23/s | ETA 00:04 | l1000_phase1 vs l1000_phase2 / CVCL_0332
# [peer_baseline_rows] 300/511 (58.7%) | elapsed 00:03 | 88.10/s | ETA 00:02 | l1000_phase1 vs l1000_phase2 / CVCL_0332
# [peer_baseline_rows] 400/511 (78.3%) | elapsed 00:05 | 87.73/s | ETA 00:01 | l1000_phase1 vs l1000_phase2 / CVCL_0332
# [peer_baseline_rows] 500/511 (97.8%) | elapsed 00:06 | 88.15/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0332
# [peer_baseline_rows] 511/511 (100.0%) | elapsed 00:06 | 88.17/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0332
# [peer_baselines] computing context 24/290: l1000_phase1 / l1000_phase2 / CVCL_0332 / 24 / 2 / 3.33
# Peer baselines for L1000 Phase I vs L1000 Phase II / CVCL_0332 / time=24 / doses=2 vs 3.33: 560 matched sample pairs
# [peer_baseline_rows] 100/560 (17.9%) | elapsed 00:01 | 87.17/s | ETA 00:05 | l1000_phase1 vs l1000_phase2 / CVCL_0332
# [peer_baseline_rows] 200/560 (35.7%) | elapsed 00:02 | 88.77/s | ETA 00:04 | l1000_phase1 vs l1000_phase2 / CVCL_0332
# [peer_baseline_rows] 300/560 (53.6%) | elapsed 00:03 | 89.21/s | ETA 00:03 | l1000_phase1 vs l1000_phase2 / CVCL_0332
# [peer_baseline_rows] 400/560 (71.4%) | elapsed 00:04 | 89.56/s | ETA 00:02 | l1000_phase1 vs l1000_phase2 / CVCL_0332
# [peer_baseline_rows] 500/560 (89.3%) | elapsed 00:06 | 89.85/s | ETA 00:01 | l1000_phase1 vs l1000_phase2 / CVCL_0332
# [peer_baseline_rows] 560/560 (100.0%) | elapsed 00:06 | 89.03/s | ETA 00:00 | l1000_phase1 vs l1000_phase2 / CVCL_0332
# [peer_baselines] computing context 25/290: l1000_phase1 / l1000_phase2 / CVCL_0332 / 24 / 0.4 / 0.37
# Peer baselines for L1000 Phase I vs L1000 Phase II / CVCL_0332 / time=24 / doses=0.4 vs 0.37: 564 matched sample pairs
# ...
# [peer_baseline_rows] 2,466/7,799 (31.6%) | elapsed 1:16:55 | 0.53/s | ETA 2:46:21 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,477/7,799 (31.8%) | elapsed 1:17:15 | 0.53/s | ETA 2:46:00 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,488/7,799 (31.9%) | elapsed 1:17:36 | 0.53/s | ETA 2:45:39 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,499/7,799 (32.0%) | elapsed 1:17:57 | 0.53/s | ETA 2:45:19 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,500/7,799 (32.1%) | elapsed 1:17:59 | 0.53/s | ETA 2:45:17 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,511/7,799 (32.2%) | elapsed 1:18:19 | 0.53/s | ETA 2:44:56 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,522/7,799 (32.3%) | elapsed 1:18:39 | 0.53/s | ETA 2:44:35 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,533/7,799 (32.5%) | elapsed 1:19:00 | 0.53/s | ETA 2:44:13 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,544/7,799 (32.6%) | elapsed 1:19:20 | 0.53/s | ETA 2:43:52 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,555/7,799 (32.8%) | elapsed 1:19:40 | 0.53/s | ETA 2:43:31 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,566/7,799 (32.9%) | elapsed 1:20:01 | 0.53/s | ETA 2:43:10 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,577/7,799 (33.0%) | elapsed 1:20:21 | 0.53/s | ETA 2:42:49 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,589/7,799 (33.2%) | elapsed 1:20:43 | 0.53/s | ETA 2:42:25 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,600/7,799 (33.3%) | elapsed 1:21:03 | 0.53/s | ETA 2:42:03 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,611/7,799 (33.5%) | elapsed 1:21:23 | 0.53/s | ETA 2:41:42 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,622/7,799 (33.6%) | elapsed 1:21:43 | 0.53/s | ETA 2:41:21 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,633/7,799 (33.8%) | elapsed 1:22:03 | 0.53/s | ETA 2:41:00 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,644/7,799 (33.9%) | elapsed 1:22:24 | 0.53/s | ETA 2:40:39 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,655/7,799 (34.0%) | elapsed 1:22:45 | 0.53/s | ETA 2:40:19 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,666/7,799 (34.2%) | elapsed 1:23:05 | 0.53/s | ETA 2:39:58 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,677/7,799 (34.3%) | elapsed 1:23:26 | 0.53/s | ETA 2:39:37 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,688/7,799 (34.5%) | elapsed 1:23:46 | 0.53/s | ETA 2:39:17 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,699/7,799 (34.6%) | elapsed 1:24:06 | 0.53/s | ETA 2:38:56 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,700/7,799 (34.6%) | elapsed 1:24:08 | 0.53/s | ETA 2:38:54 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,711/7,799 (34.8%) | elapsed 1:24:28 | 0.53/s | ETA 2:38:32 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,722/7,799 (34.9%) | elapsed 1:24:49 | 0.53/s | ETA 2:38:12 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,733/7,799 (35.0%) | elapsed 1:25:09 | 0.53/s | ETA 2:37:51 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,744/7,799 (35.2%) | elapsed 1:25:30 | 0.53/s | ETA 2:37:30 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,755/7,799 (35.3%) | elapsed 1:25:50 | 0.53/s | ETA 2:37:09 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,766/7,799 (35.5%) | elapsed 1:26:11 | 0.53/s | ETA 2:36:49 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,777/7,799 (35.6%) | elapsed 1:26:32 | 0.53/s | ETA 2:36:29 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,788/7,799 (35.7%) | elapsed 1:26:53 | 0.53/s | ETA 2:36:09 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,799/7,799 (35.9%) | elapsed 1:27:13 | 0.53/s | ETA 2:35:48 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,800/7,799 (35.9%) | elapsed 1:27:15 | 0.53/s | ETA 2:35:46 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,811/7,799 (36.0%) | elapsed 1:27:35 | 0.53/s | ETA 2:35:25 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,822/7,799 (36.2%) | elapsed 1:27:56 | 0.53/s | ETA 2:35:05 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,833/7,799 (36.3%) | elapsed 1:28:17 | 0.53/s | ETA 2:34:44 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,844/7,799 (36.5%) | elapsed 1:28:37 | 0.53/s | ETA 2:34:23 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,855/7,799 (36.6%) | elapsed 1:28:57 | 0.53/s | ETA 2:34:03 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,866/7,799 (36.7%) | elapsed 1:29:18 | 0.53/s | ETA 2:33:42 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,877/7,799 (36.9%) | elapsed 1:29:39 | 0.53/s | ETA 2:33:22 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,888/7,799 (37.0%) | elapsed 1:29:59 | 0.53/s | ETA 2:33:01 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,899/7,799 (37.2%) | elapsed 1:30:19 | 0.53/s | ETA 2:32:40 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,900/7,799 (37.2%) | elapsed 1:30:21 | 0.53/s | ETA 2:32:38 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,911/7,799 (37.3%) | elapsed 1:30:42 | 0.53/s | ETA 2:32:17 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,922/7,799 (37.5%) | elapsed 1:31:02 | 0.53/s | ETA 2:31:57 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,933/7,799 (37.6%) | elapsed 1:31:23 | 0.53/s | ETA 2:31:36 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,944/7,799 (37.7%) | elapsed 1:31:43 | 0.53/s | ETA 2:31:16 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,955/7,799 (37.9%) | elapsed 1:32:04 | 0.53/s | ETA 2:30:55 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,966/7,799 (38.0%) | elapsed 1:32:24 | 0.53/s | ETA 2:30:34 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,977/7,799 (38.2%) | elapsed 1:32:45 | 0.53/s | ETA 2:30:14 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,988/7,799 (38.3%) | elapsed 1:33:05 | 0.53/s | ETA 2:29:53 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 2,999/7,799 (38.5%) | elapsed 1:33:25 | 0.54/s | ETA 2:29:32 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,000/7,799 (38.5%) | elapsed 1:33:27 | 0.54/s | ETA 2:29:30 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,011/7,799 (38.6%) | elapsed 1:33:47 | 0.54/s | ETA 2:29:08 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,022/7,799 (38.7%) | elapsed 1:34:08 | 0.54/s | ETA 2:28:47 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,033/7,799 (38.9%) | elapsed 1:34:28 | 0.54/s | ETA 2:28:27 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,044/7,799 (39.0%) | elapsed 1:34:48 | 0.54/s | ETA 2:28:05 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,055/7,799 (39.2%) | elapsed 1:35:08 | 0.54/s | ETA 2:27:44 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,066/7,799 (39.3%) | elapsed 1:35:28 | 0.54/s | ETA 2:27:23 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,077/7,799 (39.5%) | elapsed 1:35:48 | 0.54/s | ETA 2:27:01 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,088/7,799 (39.6%) | elapsed 1:36:08 | 0.54/s | ETA 2:26:40 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,100/7,799 (39.7%) | elapsed 1:36:30 | 0.54/s | ETA 2:26:17 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,112/7,799 (39.9%) | elapsed 1:36:52 | 0.54/s | ETA 2:25:53 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,123/7,799 (40.0%) | elapsed 1:37:12 | 0.54/s | ETA 2:25:32 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,134/7,799 (40.2%) | elapsed 1:37:32 | 0.54/s | ETA 2:25:11 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,145/7,799 (40.3%) | elapsed 1:37:53 | 0.54/s | ETA 2:24:50 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,156/7,799 (40.5%) | elapsed 1:38:13 | 0.54/s | ETA 2:24:30 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,167/7,799 (40.6%) | elapsed 1:38:33 | 0.54/s | ETA 2:24:09 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,178/7,799 (40.7%) | elapsed 1:38:54 | 0.54/s | ETA 2:23:48 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,189/7,799 (40.9%) | elapsed 1:39:14 | 0.54/s | ETA 2:23:27 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,200/7,799 (41.0%) | elapsed 1:39:34 | 0.54/s | ETA 2:23:05 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,211/7,799 (41.2%) | elapsed 1:39:54 | 0.54/s | ETA 2:22:45 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,222/7,799 (41.3%) | elapsed 1:40:15 | 0.54/s | ETA 2:22:24 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,233/7,799 (41.5%) | elapsed 1:40:35 | 0.54/s | ETA 2:22:03 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,244/7,799 (41.6%) | elapsed 1:40:55 | 0.54/s | ETA 2:21:42 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,255/7,799 (41.7%) | elapsed 1:41:15 | 0.54/s | ETA 2:21:21 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,267/7,799 (41.9%) | elapsed 1:41:37 | 0.54/s | ETA 2:20:58 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,278/7,799 (42.0%) | elapsed 1:41:57 | 0.54/s | ETA 2:20:37 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,289/7,799 (42.2%) | elapsed 1:42:18 | 0.54/s | ETA 2:20:16 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,300/7,799 (42.3%) | elapsed 1:42:38 | 0.54/s | ETA 2:19:55 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,311/7,799 (42.5%) | elapsed 1:42:58 | 0.54/s | ETA 2:19:35 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,322/7,799 (42.6%) | elapsed 1:43:19 | 0.54/s | ETA 2:19:14 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,333/7,799 (42.7%) | elapsed 1:43:39 | 0.54/s | ETA 2:18:53 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,344/7,799 (42.9%) | elapsed 1:43:59 | 0.54/s | ETA 2:18:32 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,355/7,799 (43.0%) | elapsed 1:44:19 | 0.54/s | ETA 2:18:11 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,366/7,799 (43.2%) | elapsed 1:44:39 | 0.54/s | ETA 2:17:50 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,377/7,799 (43.3%) | elapsed 1:44:59 | 0.54/s | ETA 2:17:29 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,389/7,799 (43.5%) | elapsed 1:45:21 | 0.54/s | ETA 2:17:05 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,400/7,799 (43.6%) | elapsed 1:45:41 | 0.54/s | ETA 2:16:44 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,412/7,799 (43.7%) | elapsed 1:46:03 | 0.54/s | ETA 2:16:21 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,424/7,799 (43.9%) | elapsed 1:46:24 | 0.54/s | ETA 2:15:58 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,435/7,799 (44.0%) | elapsed 1:46:45 | 0.54/s | ETA 2:15:37 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,446/7,799 (44.2%) | elapsed 1:47:05 | 0.54/s | ETA 2:15:16 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,457/7,799 (44.3%) | elapsed 1:47:25 | 0.54/s | ETA 2:14:55 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,468/7,799 (44.5%) | elapsed 1:47:45 | 0.54/s | ETA 2:14:34 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,479/7,799 (44.6%) | elapsed 1:48:05 | 0.54/s | ETA 2:14:13 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,490/7,799 (44.7%) | elapsed 1:48:26 | 0.54/s | ETA 2:13:52 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,500/7,799 (44.9%) | elapsed 1:48:44 | 0.54/s | ETA 2:13:33 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,511/7,799 (45.0%) | elapsed 1:49:04 | 0.54/s | ETA 2:13:12 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,523/7,799 (45.2%) | elapsed 1:49:26 | 0.54/s | ETA 2:12:49 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,535/7,799 (45.3%) | elapsed 1:49:47 | 0.54/s | ETA 2:12:26 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,547/7,799 (45.5%) | elapsed 1:50:09 | 0.54/s | ETA 2:12:03 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,558/7,799 (45.6%) | elapsed 1:50:29 | 0.54/s | ETA 2:11:42 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,570/7,799 (45.8%) | elapsed 1:50:51 | 0.54/s | ETA 2:11:19 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,581/7,799 (45.9%) | elapsed 1:51:11 | 0.54/s | ETA 2:10:58 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,593/7,799 (46.1%) | elapsed 1:51:33 | 0.54/s | ETA 2:10:34 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,600/7,799 (46.2%) | elapsed 1:51:45 | 0.54/s | ETA 2:10:21 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,612/7,799 (46.3%) | elapsed 1:52:07 | 0.54/s | ETA 2:09:57 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,624/7,799 (46.5%) | elapsed 1:52:28 | 0.54/s | ETA 2:09:34 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,635/7,799 (46.6%) | elapsed 1:52:49 | 0.54/s | ETA 2:09:14 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,646/7,799 (46.7%) | elapsed 1:53:09 | 0.54/s | ETA 2:08:53 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,657/7,799 (46.9%) | elapsed 1:53:29 | 0.54/s | ETA 2:08:33 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,668/7,799 (47.0%) | elapsed 1:53:49 | 0.54/s | ETA 2:08:12 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,680/7,799 (47.2%) | elapsed 1:54:11 | 0.54/s | ETA 2:07:48 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,691/7,799 (47.3%) | elapsed 1:54:31 | 0.54/s | ETA 2:07:27 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,700/7,799 (47.4%) | elapsed 1:54:47 | 0.54/s | ETA 2:07:10 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,711/7,799 (47.6%) | elapsed 1:55:07 | 0.54/s | ETA 2:06:49 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,723/7,799 (47.7%) | elapsed 1:55:29 | 0.54/s | ETA 2:06:26 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,735/7,799 (47.9%) | elapsed 1:55:51 | 0.54/s | ETA 2:06:03 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,747/7,799 (48.0%) | elapsed 1:56:13 | 0.54/s | ETA 2:05:40 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,758/7,799 (48.2%) | elapsed 1:56:33 | 0.54/s | ETA 2:05:19 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,769/7,799 (48.3%) | elapsed 1:56:53 | 0.54/s | ETA 2:04:59 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,780/7,799 (48.5%) | elapsed 1:57:13 | 0.54/s | ETA 2:04:38 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,791/7,799 (48.6%) | elapsed 1:57:33 | 0.54/s | ETA 2:04:17 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,800/7,799 (48.7%) | elapsed 1:57:50 | 0.54/s | ETA 2:04:00 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,811/7,799 (48.9%) | elapsed 1:58:10 | 0.54/s | ETA 2:03:40 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,822/7,799 (49.0%) | elapsed 1:58:31 | 0.54/s | ETA 2:03:19 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,833/7,799 (49.1%) | elapsed 1:58:51 | 0.54/s | ETA 2:02:58 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,844/7,799 (49.3%) | elapsed 1:59:11 | 0.54/s | ETA 2:02:38 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,855/7,799 (49.4%) | elapsed 1:59:31 | 0.54/s | ETA 2:02:17 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,866/7,799 (49.6%) | elapsed 1:59:52 | 0.54/s | ETA 2:01:56 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,877/7,799 (49.7%) | elapsed 2:00:12 | 0.54/s | ETA 2:01:35 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,888/7,799 (49.9%) | elapsed 2:00:32 | 0.54/s | ETA 2:01:15 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,899/7,799 (50.0%) | elapsed 2:00:53 | 0.54/s | ETA 2:00:54 | cigs_mce vs cigs_tcm / CVCL_0062
# [peer_baseline_rows] 3,900/7,799 (50.0%) | elapsed 2:00:54 | 0.54/s | ETA 2:00:53 | cigs_mce vs cigs_tcm / CVCL_0062

# %%
peer_baseline_value_columns = [
    column_name
    for column_name in matched_pair_peer_baselines.columns
    if column_name.startswith("pb_")
    or column_name.endswith("_peer_total_count")
    or column_name.endswith("_peer_scored_count")
    or column_name == "n_common_genes"
]

peer_drug_line_time_agg: dict[str, tuple[str, object]] = {
    "n_matched_sample_pairs": ("left_obs_id", "size"),
    "n_matching_conditions": ("matched_condition_key", "nunique"),
}
for column_name in peer_baseline_value_columns:
    peer_drug_line_time_agg[f"mean_{column_name}"] = (column_name, "mean")

peer_drug_line_time_summary = (
    matched_pair_peer_baselines.groupby(drug_line_time_group_columns, as_index=False)
    .agg(**peer_drug_line_time_agg)
    .sort_values(drug_line_time_group_columns)
    .reset_index(drop=True)
)

peer_summary_mean_columns = [
    column_name
    for column_name in peer_drug_line_time_summary.columns
    if column_name.startswith("mean_")
]

peer_pair_agg: dict[str, tuple[str, object]] = {
    "n_matched_sample_pairs": ("n_matched_sample_pairs", "sum"),
    "n_matching_lines": ("cell_type", "nunique"),
    "n_matching_drugs": ("pubchem_cid", "nunique"),
    "n_matching_conditions": ("n_matching_conditions", "sum"),
    "n_matching_drug_line_times": ("pubchem_cid", "size"),
}
for column_name in peer_summary_mean_columns:
    peer_pair_agg[column_name] = (column_name, "mean")

peer_pair_summary = (
    peer_drug_line_time_summary.groupby(["dataset_a", "dataset_b"], as_index=False)
    .agg(**peer_pair_agg)
    .sort_values(["dataset_a", "dataset_b"])
    .reset_index(drop=True)
)

peer_line_agg: dict[str, tuple[str, object]] = {
    "n_matched_sample_pairs": ("n_matched_sample_pairs", "sum"),
    "n_matching_drugs": ("pubchem_cid", "nunique"),
    "n_matching_conditions": ("n_matching_conditions", "sum"),
    "n_matching_drug_line_times": ("pubchem_cid", "size"),
}
for column_name in peer_summary_mean_columns:
    peer_line_agg[column_name] = (column_name, "mean")

peer_line_summary = (
    peer_drug_line_time_summary.groupby(["dataset_a", "dataset_b", "cell_type"], as_index=False)
    .agg(**peer_line_agg)
    .sort_values(["dataset_a", "dataset_b", "cell_type"])
    .reset_index(drop=True)
)

for filename, frame in {
    "matched_drug_line_time_peer_baseline_summary.tsv": peer_drug_line_time_summary,
    "dataset_pair_peer_baseline_summary.tsv": peer_pair_summary,
    "dataset_pair_line_peer_baseline_summary.tsv": peer_line_summary,
}.items():
    output_path = OUTPUT_DIR / filename
    frame.to_csv(output_path, sep="\t", index=False)
    print(f"Saved peer-baseline summary to {output_path}")

peer_baseline_ci_stems = ["pb_observed_spearman_logfc"]
for variant in PEER_BASELINE_VARIANTS:
    peer_baseline_ci_stems.append(f"pb_{variant}_spearman_logfc_pair")
    peer_baseline_ci_stems.append(f"pb_delta_vs_{variant}_spearman_logfc")
    if not variant.endswith("_centroid"):
        peer_baseline_ci_stems.append(f"pb_{variant}_spearman_logfc_pair_sd_score")
        peer_baseline_ci_stems.append(f"pb_{variant}_spearman_logfc_pair_fraction_below_observed")
        peer_baseline_ci_stems.append(f"pb_{variant}_spearman_logfc_pair_corrected_percentile")

peer_baseline_ci_metrics = {stem: f"mean_{stem}" for stem in peer_baseline_ci_stems}
missing_ci_columns = sorted(
    set(peer_baseline_ci_metrics.values()) - set(peer_drug_line_time_summary.columns)
)
if missing_ci_columns:
    raise KeyError(f"Missing peer-baseline CI columns: {missing_ci_columns}")

def build_peer_ci() -> pd.DataFrame:
    peer_baseline_cluster_bca_ci = pd.concat(
        [
            cluster_bca_nested_mean_ci_table(
                peer_drug_line_time_summary,
                group_cols=["dataset_a", "dataset_b"],
                metric_cols=peer_baseline_ci_metrics,
                cluster_col="pubchem_cid",
                n_boot=BOOTSTRAP_ITERATIONS,
                seed=BOOTSTRAP_RANDOM_SEED,
                summary_level="peer_baseline_dataset_pair",
            ),
            cluster_bca_nested_mean_ci_table(
                peer_drug_line_time_summary,
                group_cols=["dataset_a", "dataset_b", "cell_type"],
                metric_cols=peer_baseline_ci_metrics,
                cluster_col="pubchem_cid",
                n_boot=BOOTSTRAP_ITERATIONS,
                seed=BOOTSTRAP_RANDOM_SEED,
                summary_level="peer_baseline_dataset_pair_line",
            ),
        ],
        ignore_index=True,
    )
    return peer_baseline_cluster_bca_ci


peer_baseline_cluster_bca_ci_path = OUTPUT_DIR / "peer_baseline_cluster_bca_ci.tsv"
peer_baseline_cluster_bca_ci = cached_frame(
    "peer_ci",
    peer_baseline_cluster_bca_ci_path,
    build_peer_ci,
    fingerprint=(
        f"signature-peer-ci-v2|source={PEER_BASELINE_INPUT_FINGERPRINT}"
        f"|boot={BOOTSTRAP_ITERATIONS}|seed={BOOTSTRAP_RANDOM_SEED}"
    ),
)

peer_baseline_ci_ranges = summarize_ci_half_width_ranges(peer_baseline_cluster_bca_ci)
peer_baseline_ci_ranges_path = OUTPUT_DIR / "peer_baseline_cluster_bca_ci_ranges.tsv"
peer_baseline_ci_ranges.to_csv(peer_baseline_ci_ranges_path, sep="\t", index=False)
print(f"Saved peer-baseline CI half-width ranges to {peer_baseline_ci_ranges_path}")


format_ci_cell = cross_source_core.format_ci_cell


pair_level_ci = peer_baseline_cluster_bca_ci.loc[
    peer_baseline_cluster_bca_ci["summary_level"] == "peer_baseline_dataset_pair"
].copy()
pair_level_ci["cell"] = pair_level_ci.apply(format_ci_cell, axis=1)
ci_lookup = {
    (str(row["dataset_a"]), str(row["dataset_b"]), str(row["metric"])): str(row["cell"])
    for _, row in pair_level_ci.iterrows()
}

rebuttal_rows: list[dict[str, object]] = []
for _, pair_row in peer_pair_summary.iterrows():
    dataset_a = str(pair_row["dataset_a"])
    dataset_b = str(pair_row["dataset_b"])
    record: dict[str, object] = {
        "dataset_a": pretty_label(dataset_a),
        "dataset_b": pretty_label(dataset_b),
        "metric": "all_gene_spearman_logfc",
        "n_compounds": int(pair_row["n_matching_drugs"]),
        "n_drug_line_times": int(pair_row["n_matching_drug_line_times"]),
        "observed": ci_lookup.get((dataset_a, dataset_b, "pb_observed_spearman_logfc"), ""),
    }
    for variant in PEER_BASELINE_VARIANTS:
        record[variant] = ci_lookup.get(
            (dataset_a, dataset_b, f"pb_{variant}_spearman_logfc_pair"), ""
        )
        record[f"delta_vs_{variant}"] = ci_lookup.get(
            (dataset_a, dataset_b, f"pb_delta_vs_{variant}_spearman_logfc"), ""
        )
    for variant in ("source_peer", "target_peer"):
        record[f"{variant}_fraction_below_observed"] = ci_lookup.get(
            (dataset_a, dataset_b, f"pb_{variant}_spearman_logfc_pair_fraction_below_observed"), ""
        )
        record[f"{variant}_corrected_percentile"] = ci_lookup.get(
            (dataset_a, dataset_b, f"pb_{variant}_spearman_logfc_pair_corrected_percentile"), ""
        )
    record["mean_peers_source"] = float(
        np.nanmean(
            [
                pair_row.get("mean_left_peer_scored_count", np.nan),
                pair_row.get("mean_right_peer_scored_count", np.nan),
            ]
        )
    )
    rebuttal_rows.append(record)

peer_baseline_rebuttal_table = pd.DataFrame(rebuttal_rows)
peer_baseline_rebuttal_table_path = OUTPUT_DIR / "peer_baseline_rebuttal_table.tsv"
peer_baseline_rebuttal_table.to_csv(peer_baseline_rebuttal_table_path, sep="\t", index=False)
print(f"Saved rebuttal-ready peer-baseline table to {peer_baseline_rebuttal_table_path}")
display(peer_baseline_rebuttal_table)

display(cache_summary())

# %% [markdown]
# ## W4: per-gene population standardization at two scopes
#
# This additive sensitivity analysis keeps every raw-logFC result above unchanged. For each
# dataset, it fits gene-wise population statistics both within each cellular context and
# across all eligible cell types (`ddof=0`), then reports both transforms before computing
# Table 6 all-gene logFC Spearman.
#
# The same matched pairs, shared-gene sets, peer membership, peer cap, aggregation, and
# compound-clustered BCa procedure are reused. Source/target centroids and individual peers
# are all transformed with their own source-context statistics. This is a condition-level
# analogue of the gene-wise population axis in L1000 Level 4, not a reconstruction of its
# plate-level raw-expression pipeline.

# %%
import hashlib
import importlib
import json

import scripts.peer_baselines as peer_baselines_module
importlib.reload(peer_baselines_module)

from scripts.peer_baselines import (
    empty_peer_score_summary,
    finite_column_totals,
    prepare_spearman_rows,
    select_peer_indices,
    spearman_against_prepared_peers,
    summarize_peer_scores,
)
import scripts.population_zscore as population_zscore_module
importlib.reload(population_zscore_module)

from scripts.population_zscore import (
    ENGINE_VERSION as W4_ENGINE_VERSION,
    POPULATION_SCALE_VARIANTS,
    PopulationStatsCatalog,
    stats_qc_record,
)

W4_SCALE_VARIANTS = POPULATION_SCALE_VARIANTS
ACTIVE_W4_SCALE_VARIANT = W4_SCALE_VARIANTS[0]
W4_SMOKE_COMPARISON_POPULATION = os.environ.get(
    "CPB_W4_SMOKE_COMPARISON_POPULATION", ""
).strip().lower() in {"1", "true", "yes"}
W4_PRECOMPUTE_MODE = os.environ.get(
    "CPB_W4_PRECOMPUTE_MODE", "wait"
).strip().lower()
if W4_PRECOMPUTE_MODE not in {"stop", "wait", "lazy"}:
    raise ValueError("CPB_W4_PRECOMPUTE_MODE must be stop, wait, or lazy")
W4_PRECOMPUTE_POLL_SECONDS = float(
    os.environ.get("CPB_W4_PRECOMPUTE_POLL_SECONDS", "30")
)
W4_PRECOMPUTE_TIMEOUT_SECONDS = 60.0 * float(
    os.environ.get("CPB_W4_PRECOMPUTE_TIMEOUT_MINUTES", "720")
)
if W4_SMOKE_COMPARISON_POPULATION and TEST_DATASET_SUBSET is None:
    raise ValueError(
        "CPB_W4_SMOKE_COMPARISON_POPULATION is smoke-only and requires "
        "CPB_DATASET_SUBSET."
    )
W4_STATS_CACHE_ROOT = (
    OUTPUT_DIR / "w4_population_zscore_stats_smoke"
    if W4_SMOKE_COMPARISON_POPULATION
    else REPO_ROOT / "results" / "w4_population_zscore_stats"
)

W4_STATS_CATALOG = PopulationStatsCatalog(
    source_dataset_dirs=SOURCE_DATASET_DIRS,
    matched_lines=matched_lines,
    matched_dataset_names=matched_active_datasets,
    resolve_line_path=resolve_line_path,
    cache_root=W4_STATS_CACHE_ROOT,
    smoke_comparison_population=W4_SMOKE_COMPARISON_POPULATION,
    precompute_mode=W4_PRECOMPUTE_MODE,
    poll_seconds=W4_PRECOMPUTE_POLL_SECONDS,
    timeout_seconds=W4_PRECOMPUTE_TIMEOUT_SECONDS,
)
W4_POPULATION_POLICY = W4_STATS_CATALOG.population_policy
W4_STATS_BY_SOURCE = W4_STATS_CATALOG.stats_by_source
W4_POOLED_STATS_BY_DATASET = W4_STATS_CATALOG.pooled_stats_by_dataset
w4_dataset_population_source_paths = (
    W4_STATS_CATALOG.dataset_population_source_paths
)
get_w4_population_stats = lambda source: W4_STATS_CATALOG.get_stats(
    source,
    scale_variant=ACTIVE_W4_SCALE_VARIANT,
)

def w4_standardize_selected_vector(
    source: LineSource,
    values: np.ndarray,
    gene_positions: np.ndarray,
) -> np.ndarray:
    positions = np.asarray(gene_positions, dtype=np.int64)
    selected = np.asarray(values, dtype=np.float64).reshape(-1)[positions]
    return W4_STATS_CATALOG.standardize_aligned_vector(
        source,
        selected,
        positions,
        scale_variant=ACTIVE_W4_SCALE_VARIANT,
    )


def w4_standardize_selected_matrix(
    source: LineSource,
    values: np.ndarray,
    gene_positions: np.ndarray,
) -> np.ndarray:
    positions = np.asarray(gene_positions, dtype=np.int64)
    selected = np.atleast_2d(np.asarray(values, dtype=np.float64))[:, positions]
    return W4_STATS_CATALOG.standardize_aligned_matrix(
        source,
        selected,
        positions,
        scale_variant=ACTIVE_W4_SCALE_VARIANT,
    )



@dataclass(frozen=True)
class W4PreparedSignatureStratum:
    key: tuple[str, ...]
    compounds: np.ndarray
    raw_matrix: np.ndarray
    standardized_matrix: np.ndarray
    prepared_spearman: object
    total_sums: np.ndarray
    total_finite_counts: np.ndarray
    population_means: np.ndarray
    population_sds: np.ndarray
    population_valid_mask: np.ndarray


W4_SIGNATURE_STRATUM_CACHE: dict[tuple[str, ...], W4PreparedSignatureStratum] = {}
W4_SIGNATURE_STRATUM_CACHE_LIMIT = 4
W4_ASSERTED_CENTROID_STRATA: set[tuple[str, ...]] = set()


def get_w4_prepared_signature_stratum(
    source: LineSource,
    *,
    dose_key: str,
    time_key: str,
    gene_positions: np.ndarray,
) -> W4PreparedSignatureStratum:
    positions = np.asarray(gene_positions, dtype=np.int64)
    position_hash = hashlib.sha256(positions.tobytes()).hexdigest()
    key = (
        ACTIVE_W4_SCALE_VARIANT,
        source.dataset_name,
        source.cell_type,
        str(dose_key),
        str(time_key),
        position_hash,
    )
    if key in W4_SIGNATURE_STRATUM_CACHE:
        return W4_SIGNATURE_STRATUM_CACHE[key]

    compounds, raw_full = baseline_peer_stratum(
        source,
        dose_key=str(dose_key),
        time_key=str(time_key),
    )
    raw_matrix = np.asarray(raw_full[:, positions], dtype=np.float64)
    standardized_matrix = w4_standardize_selected_matrix(
        source,
        raw_full,
        positions,
    )
    total_sums, total_finite_counts = finite_column_totals(
        standardized_matrix
    )
    stats = get_w4_population_stats(source)
    prepared = W4PreparedSignatureStratum(
        key=key,
        compounds=np.asarray(compounds).astype(str),
        raw_matrix=raw_matrix,
        standardized_matrix=standardized_matrix,
        prepared_spearman=prepare_spearman_rows(standardized_matrix),
        total_sums=total_sums,
        total_finite_counts=total_finite_counts,
        population_means=stats.means[positions],
        population_sds=stats.population_sds[positions],
        population_valid_mask=stats.valid_mask[positions],
    )
    if len(W4_SIGNATURE_STRATUM_CACHE) >= W4_SIGNATURE_STRATUM_CACHE_LIMIT:
        W4_SIGNATURE_STRATUM_CACHE.pop(next(iter(W4_SIGNATURE_STRATUM_CACHE)))
    W4_SIGNATURE_STRATUM_CACHE[key] = prepared
    print(
        f"[w4_signature] prepared {source.dataset_name}/{source.cell_type}/"
        f"time={time_key}/dose={dose_key}: "
        f"{standardized_matrix.shape[0]:,} rows x "
        f"{standardized_matrix.shape[1]:,} shared genes"
    )
    return prepared


def w4_signature_peer_selection(
    prepared: W4PreparedSignatureStratum,
    source: LineSource,
    obs_id: str,
    lookup: dict[str, str],
) -> tuple[np.ndarray, int, int, Optional[np.ndarray], np.ndarray]:
    row_pos = source.resolve_row_pos(obs_id, **lookup)
    row = source.obs.loc[row_pos]
    compound = str(row["pubchem_cid"])
    excluded_mask = prepared.compounds == compound
    peer_positions = np.flatnonzero(~excluded_mask)
    n_total = int(peer_positions.size)
    if n_total == 0:
        return np.empty(0, dtype=np.int64), 0, 0, None, peer_positions

    selected_offsets = select_peer_indices(
        n_total,
        MAX_BASELINE_PEERS,
        "|".join(
            [
                source.dataset_name,
                source.cell_type,
                str(row["dose_key"]),
                str(row["time_key"]),
                compound,
            ]
        ),
        sampling_seed=PEER_SAMPLING_SEED,
    )
    selected_positions = peer_positions[selected_offsets]

    excluded_sums, excluded_counts = finite_column_totals(
        prepared.standardized_matrix[excluded_mask]
    )
    remaining_sums = prepared.total_sums - excluded_sums
    remaining_counts = prepared.total_finite_counts - excluded_counts
    centroid = np.full(prepared.standardized_matrix.shape[1], np.nan)
    fully_finite = remaining_counts == n_total
    centroid[fully_finite] = remaining_sums[fully_finite] / n_total
    return selected_positions, n_total, int(selected_positions.size), centroid, peer_positions


def assert_w4_centroid_equivalence(
    prepared: W4PreparedSignatureStratum,
    peer_positions: np.ndarray,
    standardized_centroid: Optional[np.ndarray],
) -> None:
    """Check affine equivalence once per prepared source-context stratum."""
    if standardized_centroid is None or prepared.key in W4_ASSERTED_CENTROID_STRATA:
        return
    raw_centroid = prepared.raw_matrix[peer_positions].mean(
        axis=0,
        dtype=np.float64,
    )
    expected = np.full(raw_centroid.shape, np.nan, dtype=np.float64)
    valid = prepared.population_valid_mask & np.isfinite(raw_centroid)
    with np.errstate(invalid="ignore", divide="ignore", over="ignore"):
        expected[valid] = (
            raw_centroid[valid] - prepared.population_means[valid]
        ) / prepared.population_sds[valid]
    if not np.allclose(
        expected,
        standardized_centroid,
        rtol=1e-6,
        atol=1e-6,
        equal_nan=True,
    ):
        raise AssertionError(
            f"W4 centroid affine-equivalence check failed for {prepared.key}"
        )
    W4_ASSERTED_CENTROID_STRATA.add(prepared.key)

def w4_source_inventory_fingerprint() -> str:
    inventory: list[dict[str, object]] = []
    for dataset_name in matched_active_datasets:
        for cell_type in matched_lines.get(dataset_name, []):
            source_path = resolve_line_path(dataset_name, cell_type)
            source_stat = source_path.stat()
            inventory.append(
                {
                    "dataset": dataset_name,
                    "cell_type": cell_type,
                    "name": source_path.name,
                    "path": str(source_path.resolve()),
                    "size": int(source_stat.st_size),
                    "mtime_ns": int(source_stat.st_mtime_ns),
                }
            )
    population_inventory: list[dict[str, object]] = []
    for dataset_name in matched_active_datasets:
        for cell_type, source_path in w4_dataset_population_source_paths(
            dataset_name
        ).items():
            source_stat = source_path.stat()
            population_inventory.append(
                {
                    "dataset": dataset_name,
                    "cell_type": cell_type,
                    "path": str(source_path.resolve()),
                    "size": int(source_stat.st_size),
                    "mtime_ns": int(source_stat.st_mtime_ns),
                }
            )
    payload = {
        "w4_engine": W4_ENGINE_VERSION,
        "datasets": list(matched_active_datasets),
        "sources": inventory,
        "population_sources": population_inventory,
        "population_policy": W4_POPULATION_POLICY,
        "max_baseline_peers": MAX_BASELINE_PEERS,
        "peer_sampling_seed": PEER_SAMPLING_SEED,
        "metric": "table6_all_gene_spearman_logfc",
        "scale_variants": list(W4_SCALE_VARIANTS),
    }
    return hashlib.sha256(
        json.dumps(payload, sort_keys=True, separators=(",", ":")).encode("utf-8")
    ).hexdigest()


W4_SIGNATURE_FINGERPRINT = w4_source_inventory_fingerprint()
print(f"W4 signature fingerprint: {W4_SIGNATURE_FINGERPRINT[:12]}")

# %%
def compute_w4_signature_record(match_row: pd.Series) -> dict[str, object]:
    dataset_a = str(match_row["dataset_a"])
    dataset_b = str(match_row["dataset_b"])
    cell_type = str(match_row["cell_type"])
    left_source = get_line_source(dataset_a, cell_type)
    right_source = get_line_source(dataset_b, cell_type)
    shared_genes, left_gene_pos, right_gene_pos = shared_gene_positions(
        left_source,
        right_source,
    )

    left_obs_id = str(match_row["left_obs_id"])
    right_obs_id = str(match_row["right_obs_id"])
    pubchem_cid = str(match_row["pubchem_cid"])
    time_key = str(match_row["time_key"])
    left_lookup = {
        "pubchem_cid": pubchem_cid,
        "dose_key": str(match_row["left_dose_key"]),
        "time_key": time_key,
    }
    right_lookup = {
        "pubchem_cid": pubchem_cid,
        "dose_key": str(match_row["right_dose_key"]),
        "time_key": time_key,
    }

    left_stats = get_w4_population_stats(left_source)
    right_stats = get_w4_population_stats(right_source)
    left_logfc = w4_standardize_selected_vector(
        left_source,
        left_source.get_vector(left_obs_id, "logFC", **left_lookup),
        left_gene_pos,
    )
    right_logfc = w4_standardize_selected_vector(
        right_source,
        right_source.get_vector(right_obs_id, "logFC", **right_lookup),
        right_gene_pos,
    )
    observed = signed_spearman(left_logfc, right_logfc)

    left_prepared = get_w4_prepared_signature_stratum(
        left_source,
        dose_key=left_lookup["dose_key"],
        time_key=left_lookup["time_key"],
        gene_positions=left_gene_pos,
    )
    right_prepared = get_w4_prepared_signature_stratum(
        right_source,
        dose_key=right_lookup["dose_key"],
        time_key=right_lookup["time_key"],
        gene_positions=right_gene_pos,
    )
    (
        left_peer_positions,
        left_n_total,
        left_n_scored,
        left_centroid,
        left_all_peer_positions,
    ) = w4_signature_peer_selection(
        left_prepared,
        left_source,
        left_obs_id,
        left_lookup,
    )
    (
        right_peer_positions,
        right_n_total,
        right_n_scored,
        right_centroid,
        right_all_peer_positions,
    ) = w4_signature_peer_selection(
        right_prepared,
        right_source,
        right_obs_id,
        right_lookup,
    )

    assert_w4_centroid_equivalence(
        left_prepared,
        left_all_peer_positions,
        left_centroid,
    )
    assert_w4_centroid_equivalence(
        right_prepared,
        right_all_peer_positions,
        right_centroid,
    )

    record: dict[str, object] = {
        **match_row.to_dict(),
        "scale_variant": ACTIVE_W4_SCALE_VARIANT,
        "n_common_genes": int(shared_genes.size),
        "n_w4_common_genes": int(
            np.sum(np.isfinite(left_logfc) & np.isfinite(right_logfc))
        ),
        "left_population_row_count": left_stats.population_row_count,
        "right_population_row_count": right_stats.population_row_count,
        "left_population_valid_genes": left_stats.n_valid_genes,
        "right_population_valid_genes": right_stats.n_valid_genes,
        "left_peer_total_count": left_n_total,
        "right_peer_total_count": right_n_total,
        "left_peer_scored_count": left_n_scored,
        "right_peer_scored_count": right_n_scored,
        "peer_sampling_seed": PEER_SAMPLING_SEED,
        "max_baseline_peers": MAX_BASELINE_PEERS,
        "w4_observed_spearman_logfc": observed,
    }

    side_specs = {
        "left": {
            "sample": left_logfc,
            "source_centroid": left_centroid,
            "target_centroid": right_centroid,
            "source_peer": (left_prepared.prepared_spearman, left_peer_positions),
            "target_peer": (right_prepared.prepared_spearman, right_peer_positions),
        },
        "right": {
            "sample": right_logfc,
            "source_centroid": right_centroid,
            "target_centroid": left_centroid,
            "source_peer": (right_prepared.prepared_spearman, right_peer_positions),
            "target_peer": (left_prepared.prepared_spearman, left_peer_positions),
        },
    }
    for variant in PEER_BASELINE_VARIANTS:
        side_means: list[float] = []
        side_sds: list[float] = []
        side_fractions: list[float] = []
        side_percentiles: list[float] = []
        for side, spec in side_specs.items():
            stem = f"w4_{variant}_spearman_logfc_{side}"
            if variant.endswith("_centroid"):
                centroid = spec[variant]
                value = (
                    float("nan")
                    if centroid is None
                    else signed_spearman(spec["sample"], centroid)
                )
                record[stem] = value
                side_means.append(value)
                continue

            prepared_spearman, peer_positions = spec[variant]
            if len(peer_positions) == 0:
                record.update(empty_peer_score_summary(stem))
                summary = {
                    f"{stem}_mean_score": float("nan"),
                    f"{stem}_sd_score": float("nan"),
                    f"{stem}_fraction_below_observed": float("nan"),
                    f"{stem}_corrected_percentile": float("nan"),
                }
            else:
                peer_scores = spearman_against_prepared_peers(
                    spec["sample"],
                    prepared_spearman,
                    row_indices=peer_positions,
                )
                summary = summarize_peer_scores(observed, peer_scores, stem)
                record.update(summary)
            side_means.append(summary[f"{stem}_mean_score"])
            side_sds.append(summary[f"{stem}_sd_score"])
            side_fractions.append(summary[f"{stem}_fraction_below_observed"])
            side_percentiles.append(summary[f"{stem}_corrected_percentile"])

        pair_stem = f"w4_{variant}_spearman_logfc_pair"
        pair_mean = mean_available(side_means)
        record[pair_stem] = pair_mean
        record[f"w4_delta_vs_{variant}_spearman_logfc"] = (
            float("nan")
            if pd.isna(observed) or pd.isna(pair_mean)
            else float(observed - pair_mean)
        )
        if not variant.endswith("_centroid"):
            record[f"{pair_stem}_sd_score"] = mean_available(side_sds)
            record[f"{pair_stem}_fraction_below_observed"] = mean_available(
                side_fractions
            )
            record[f"{pair_stem}_corrected_percentile"] = mean_available(
                side_percentiles
            )
    return record


# W4 must use the rows that the raw Table 6 metric stage successfully resolved.
# matched_pairs also contains candidates that were skipped there because their
# h5ad observation IDs could not be resolved.
w4_signature_missing_input_columns = sorted(
    set(matched_pairs.columns) - set(matched_pair_metrics.columns)
)
if w4_signature_missing_input_columns:
    raise AssertionError(
        "The raw Table 6 metric cache is missing matched-pair input columns: "
        f"{w4_signature_missing_input_columns}"
    )
w4_signature_input_pairs = matched_pair_metrics.loc[:, matched_pairs.columns].copy()
w4_signature_excluded_count = len(matched_pairs) - len(w4_signature_input_pairs)
if w4_signature_excluded_count < 0:
    raise AssertionError("Raw Table 6 contains more rows than the matched-pair input")
print(
    f"W4 Table 6 input: {len(w4_signature_input_pairs):,} resolved raw pairs; "
    f"excluded {w4_signature_excluded_count:,} unresolved candidates"
)


def build_w4_signature_metrics() -> pd.DataFrame:
    global ACTIVE_W4_SCALE_VARIANT
    records: list[dict[str, object]] = []
    n_completed = 0
    n_total = len(w4_signature_input_pairs) * len(W4_SCALE_VARIANTS)
    progress = notebook_cache_module.ProgressReporter(
        total=n_total,
        label="w4_signature",
        every=100,
        min_interval_seconds=20.0,
    )
    for scale_variant in W4_SCALE_VARIANTS:
        ACTIVE_W4_SCALE_VARIANT = scale_variant
        W4_SIGNATURE_STRATUM_CACHE.clear()
        W4_ASSERTED_CENTROID_STRATA.clear()
        print(f"[w4_signature] starting {scale_variant}", flush=True)
        for context_key, group in w4_signature_input_pairs.groupby(
            context_join_columns,
            sort=False,
        ):
            dataset_a, dataset_b, cell_type, time_key, left_dose, right_dose = context_key
            print(
                f"W4 Table 6 ({scale_variant}) for {pretty_label(dataset_a)} vs "
                f"{pretty_label(dataset_b)} / {cell_type} / time={time_key} / "
                f"doses={left_dose} vs {right_dose}: {len(group)} pairs",
                flush=True,
            )
            for _, match_row in group.iterrows():
                records.append(compute_w4_signature_record(match_row))
                n_completed += 1
                progress.update(
                    completed=n_completed,
                    detail=scale_variant,
                )
    return pd.DataFrame(records)


w4_signature_metrics_path = OUTPUT_DIR / "w4_matched_sample_pair_metrics.tsv"
W4_SIGNATURE_METRICS_FINGERPRINT = (
    f"w4-signature-v5|source={W4_SIGNATURE_FINGERPRINT}"
    f"|cap={MAX_BASELINE_PEERS}|seed={PEER_SAMPLING_SEED}"
)
w4_signature_metrics = cached_frame(
    "w4_signature_metrics",
    w4_signature_metrics_path,
    build_w4_signature_metrics,
    fingerprint=W4_SIGNATURE_METRICS_FINGERPRINT,
    required_columns=[
        "scale_variant",
        "w4_observed_spearman_logfc",
        "w4_source_centroid_spearman_logfc_pair",
        "w4_target_centroid_spearman_logfc_pair",
        "w4_source_peer_spearman_logfc_pair",
        "w4_target_peer_spearman_logfc_pair",
    ],
)

w4_identity_columns = [
    "dataset_a",
    "dataset_b",
    "cell_type",
    "time_key",
    "pubchem_cid",
    "left_obs_id",
    "right_obs_id",
    "left_dose_key",
    "right_dose_key",
]
expected_w4_keys = {
    (scale_variant, *identity)
    for scale_variant in W4_SCALE_VARIANTS
    for identity in map(
        tuple,
        w4_signature_input_pairs[w4_identity_columns].astype(str).to_numpy(),
    )
}
observed_w4_keys = set(
    map(
        tuple,
        w4_signature_metrics[["scale_variant", *w4_identity_columns]].astype(str).to_numpy(),
    )
)
if (
    expected_w4_keys != observed_w4_keys
    or len(w4_signature_metrics) != len(w4_signature_input_pairs) * len(W4_SCALE_VARIANTS)
):
    raise AssertionError(
        "W4 Table 6 did not preserve the successfully scored raw matched-pair population"
    )

# The existing raw parity result must remain intact; W4 is appended, never substituted.
if "worst_parity_diff" in globals() and float(worst_parity_diff) > 1e-6:
    raise AssertionError("Raw Table 6 parity was not preserved before W4 scoring")

print(
    f"W4 Table 6 scored {len(w4_signature_metrics):,} rows across "
    f"{len(W4_SCALE_VARIANTS)} standardization scopes"
)

# %%
w4_signature_value_columns = [
    column
    for column in w4_signature_metrics.columns
    if column.startswith("w4_")
    or column.endswith("_peer_total_count")
    or column.endswith("_peer_scored_count")
    or column
    in {
        "n_common_genes",
        "n_w4_common_genes",
        "left_population_row_count",
        "right_population_row_count",
        "left_population_valid_genes",
        "right_population_valid_genes",
    }
]
w4_signature_drug_agg: dict[str, tuple[str, object]] = {
    "n_matched_sample_pairs": ("left_obs_id", "size"),
    "n_matching_conditions": ("matched_condition_key", "nunique"),
}
for column in w4_signature_value_columns:
    w4_signature_drug_agg[f"mean_{column}"] = (column, "mean")

w4_signature_drug_summary = (
    w4_signature_metrics.groupby(["scale_variant", *drug_line_time_group_columns], as_index=False)
    .agg(**w4_signature_drug_agg)
    .sort_values(drug_line_time_group_columns)
    .reset_index(drop=True)
)
w4_signature_mean_columns = [
    column
    for column in w4_signature_drug_summary.columns
    if column.startswith("mean_")
]
w4_signature_pair_agg: dict[str, tuple[str, object]] = {
    "n_matched_sample_pairs": ("n_matched_sample_pairs", "sum"),
    "n_matching_lines": ("cell_type", "nunique"),
    "n_matching_drugs": ("pubchem_cid", "nunique"),
    "n_matching_conditions": ("n_matching_conditions", "sum"),
    "n_matching_drug_line_times": ("pubchem_cid", "size"),
}
for column in w4_signature_mean_columns:
    w4_signature_pair_agg[column] = (column, "mean")
w4_signature_pair_summary = (
    w4_signature_drug_summary.groupby(["dataset_a", "dataset_b", "scale_variant"], as_index=False)
    .agg(**w4_signature_pair_agg)
    .sort_values(["dataset_a", "dataset_b"])
    .reset_index(drop=True)
)
w4_signature_pair_summary.to_csv(
    OUTPUT_DIR / "w4_dataset_pair_summary.tsv",
    sep="\t",
    index=False,
)

w4_signature_ci_stems = ["w4_observed_spearman_logfc"]
for variant in PEER_BASELINE_VARIANTS:
    w4_signature_ci_stems.extend(
        [
            f"w4_{variant}_spearman_logfc_pair",
            f"w4_delta_vs_{variant}_spearman_logfc",
        ]
    )
    if not variant.endswith("_centroid"):
        w4_signature_ci_stems.extend(
            [
                f"w4_{variant}_spearman_logfc_pair_sd_score",
                f"w4_{variant}_spearman_logfc_pair_fraction_below_observed",
                f"w4_{variant}_spearman_logfc_pair_corrected_percentile",
            ]
        )
w4_signature_ci_metrics = {
    stem: f"mean_{stem}" for stem in w4_signature_ci_stems
}


def build_w4_signature_ci() -> pd.DataFrame:
    return cluster_bca_nested_mean_ci_table(
        w4_signature_drug_summary,
        group_cols=["dataset_a", "dataset_b", "scale_variant"],
        metric_cols=w4_signature_ci_metrics,
        cluster_col="pubchem_cid",
        n_boot=BOOTSTRAP_ITERATIONS,
        seed=BOOTSTRAP_RANDOM_SEED,
        summary_level="w4_signature_dataset_pair",
    )


w4_signature_ci_path = OUTPUT_DIR / "w4_cluster_bca_ci.tsv"
W4_SIGNATURE_CI_FINGERPRINT = cross_source_core.ci_fingerprint(
    version="w4-signature-ci-v4",
    upstream_fingerprint=W4_SIGNATURE_METRICS_FINGERPRINT,
    n_boot=BOOTSTRAP_ITERATIONS,
    seed=BOOTSTRAP_RANDOM_SEED,
    metric_columns=list(w4_signature_ci_metrics),
    group_columns=["dataset_a", "dataset_b", "scale_variant"],
)
w4_signature_ci = cached_frame(
    "w4_signature_ci",
    w4_signature_ci_path,
    build_w4_signature_ci,
    fingerprint=W4_SIGNATURE_CI_FINGERPRINT,
)


def w4_ci_lookup(frame: pd.DataFrame) -> dict[tuple[str, str, str, str], str]:
    lookup_frame = frame.copy()
    lookup_frame["cell"] = lookup_frame.apply(format_ci_cell, axis=1)
    return {
        (str(row["dataset_a"]), str(row["dataset_b"]), str(row["scale_variant"]), str(row["metric"])): str(
            row["cell"]
        )
        for _, row in lookup_frame.iterrows()
    }


w4_signature_lookup = w4_ci_lookup(w4_signature_ci)
w4_standardized_rows: list[dict[str, object]] = []
for _, pair_row in w4_signature_pair_summary.iterrows():
    dataset_a = str(pair_row["dataset_a"])
    dataset_b = str(pair_row["dataset_b"])
    scale_variant = str(pair_row["scale_variant"])
    row: dict[str, object] = {
        "dataset_a": pretty_label(dataset_a),
        "dataset_b": pretty_label(dataset_b),
        "metric": "all_gene_spearman_logfc",
        "scale_variant": scale_variant,
        "n_compounds": int(pair_row["n_matching_drugs"]),
        "n_drug_line_times": int(pair_row["n_matching_drug_line_times"]),
        "mean_peers_source": float(
            np.nanmean(
                [
                    pair_row["mean_left_peer_scored_count"],
                    pair_row["mean_right_peer_scored_count"],
                ]
            )
        ),
        "observed": w4_signature_lookup.get(
            (dataset_a, dataset_b, scale_variant, "w4_observed_spearman_logfc"),
            "",
        ),
    }
    for variant in PEER_BASELINE_VARIANTS:
        row[variant] = w4_signature_lookup.get(
            (dataset_a, dataset_b, scale_variant, f"w4_{variant}_spearman_logfc_pair"),
            "",
        )
        row[f"delta_vs_{variant}"] = w4_signature_lookup.get(
            (dataset_a, dataset_b, scale_variant, f"w4_delta_vs_{variant}_spearman_logfc"),
            "",
        )
    for variant in ("source_peer", "target_peer"):
        row[f"{variant}_fraction_below_observed"] = w4_signature_lookup.get(
            (
                dataset_a,
                dataset_b,
                scale_variant,
                f"w4_{variant}_spearman_logfc_pair_fraction_below_observed",
            ),
            "",
        )
        row[f"{variant}_corrected_percentile"] = w4_signature_lookup.get(
            (
                dataset_a,
                dataset_b,
                scale_variant,
                f"w4_{variant}_spearman_logfc_pair_corrected_percentile",
            ),
            "",
        )
    w4_standardized_rows.append(row)

w4_raw_table6 = peer_baseline_rebuttal_table.copy()
w4_raw_table6["scale_variant"] = "raw_logfc"
w4_table6 = pd.concat(
    [w4_raw_table6, pd.DataFrame(w4_standardized_rows)],
    ignore_index=True,
    sort=False,
)
if w4_table6.loc[
    w4_table6["scale_variant"] != "raw_logfc", "mean_peers_source"
].isna().any():
    raise AssertionError("Standardized Table 6 rows are missing source peer counts")
w4_table6["w4_population_policy"] = W4_POPULATION_POLICY
w4_table6_path = OUTPUT_DIR / "w4_table_6_standardization.tsv"
w4_table6.to_csv(w4_table6_path, sep="\t", index=False)

# Materialize a transparent QC manifest even when the metric stage was reloaded.
for scale_variant in W4_SCALE_VARIANTS:
    ACTIVE_W4_SCALE_VARIANT = scale_variant
    for dataset_name in matched_active_datasets:
        for cell_type in matched_lines.get(dataset_name, []):
            get_w4_population_stats(get_line_source(dataset_name, cell_type))
w4_stats_qc = pd.DataFrame(
    [
        {
            **stats_qc_record(stats),
            "scale_variant": cache_key[0],
            "applied_cell_type": cache_key[2],
            "population_policy": W4_POPULATION_POLICY,
        }
        for cache_key, stats in sorted(W4_STATS_BY_SOURCE.items())
    ]
)
w4_stats_qc.to_csv(
    OUTPUT_DIR / "w4_population_stats_qc.tsv",
    sep="\t",
    index=False,
)

print(f"Saved raw-versus-standardized Table 6 to {w4_table6_path}")
display(w4_table6)
display(cache_summary())
