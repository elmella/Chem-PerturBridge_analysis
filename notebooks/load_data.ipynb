# %%
import anndata as ad

# %%
# !ls /lustre/groups/ml01/workspace/olga.novitskaia/data_updated/tahoe/deg_data/group_rep/full/qc_false/filter_min_cells_50/results
# Out:
# CVCL_0023_de.h5ad  CVCL_0334_de.h5ad  CVCL_1056_de.h5ad  CVCL_1547_de.h5ad
# CVCL_0028_de.h5ad  CVCL_0359_de.h5ad  CVCL_1094_de.h5ad  CVCL_1550_de.h5ad
# CVCL_0069_de.h5ad  CVCL_0366_de.h5ad  CVCL_1097_de.h5ad  CVCL_1577_de.h5ad
# CVCL_0099_de.h5ad  CVCL_0371_de.h5ad  CVCL_1098_de.h5ad  CVCL_1635_de.h5ad
# CVCL_0131_de.h5ad  CVCL_0397_de.h5ad  CVCL_1119_de.h5ad  CVCL_1666_de.h5ad
# CVCL_0152_de.h5ad  CVCL_0399_de.h5ad  CVCL_1125_de.h5ad  CVCL_1693_de.h5ad
# CVCL_0179_de.h5ad  CVCL_0428_de.h5ad  CVCL_1239_de.h5ad  CVCL_1715_de.h5ad
# CVCL_0218_de.h5ad  CVCL_0459_de.h5ad  CVCL_1285_de.h5ad  CVCL_1716_de.h5ad
# CVCL_0292_de.h5ad  CVCL_0480_de.h5ad  CVCL_1381_de.h5ad  CVCL_1717_de.h5ad
# CVCL_0293_de.h5ad  CVCL_0504_de.h5ad  CVCL_1478_de.h5ad  CVCL_1724_de.h5ad
# CVCL_0320_de.h5ad  CVCL_0546_de.h5ad  CVCL_1495_de.h5ad  CVCL_1731_de.h5ad
# CVCL_0332_de.h5ad  CVCL_1055_de.h5ad  CVCL_1517_de.h5ad  CVCL_C466_de.h5ad

# %%
# !ls /lustre/groups/ml01/workspace/olga.novitskaia/data_updated/sciplex/deg_data/group_rep/full/qc_false/filter_min_cells_10/results
# Out:
# CVCL_0004_de.h5ad  CVCL_0023_de.h5ad  CVCL_0031_de.h5ad

# %%
# !ls /lustre/groups/ml01/workspace/olga.novitskaia/data_updated/l1000_phase2/deg_data/group_rep/full/qc_false/filter_min_cells_0/results
# Out:
# ASC.C_de.h5ad	   CVCL_0062_de.h5ad  CVCL_1794_de.h5ad  NEU_de.h5ad
# CD34_de.h5ad	   CVCL_0065_de.h5ad  CVCL_2959_de.h5ad  NPC.CAS9_de.h5ad
# CVCL_0023_de.h5ad  CVCL_0132_de.h5ad  CVCL_3383_de.h5ad  NPC.TAK_de.h5ad
# CVCL_0027_de.h5ad  CVCL_0178_de.h5ad  CVCL_5136_de.h5ad  NPC_de.h5ad
# CVCL_0030_de.h5ad  CVCL_0320_de.h5ad  CVCL_B161_de.h5ad  SKL.C_de.h5ad
# CVCL_0031_de.h5ad  CVCL_0332_de.h5ad  CVCL_U602_de.h5ad  SKL_de.h5ad
# CVCL_0033_de.h5ad  CVCL_0395_de.h5ad  CVCL_VU89_de.h5ad
# CVCL_0035_de.h5ad  CVCL_0598_de.h5ad  MNEU.E_de.h5ad

# %%
CVCL_0002_de_adata = ad.read_h5ad("/lustre/groups/ml01/workspace/olga.novitskaia/data_updated/l1000_phase1/deg_data/group_rep/full/qc_false/filter_min_cells_0/results/CVCL_0002_de.h5ad")

# %%
CVCL_0002_de_adata.obs.columns
# Out:
# Index(['id', 'plate', 'well', 'cell_type', 'perturbagen', 'pert_type',
#        'is_control', 'pert_dose_uM', 'pert_time_h', 'suspension_type',
#        'tissue', 'tissue_type', 'disease', 'library', 'stimulation', 'guide',
#        'dataset', 'assay', 'development_stage', 'organism', 'sex',
#        'self_reported_ethnicity', 'pubchem_cid', 'psbulk_cells',
#        'psbulk_counts', 'perturbagen_name', 'perturbation_label',
#        'processing_batch'],
#       dtype='object')

# %%
CVCL_0002_de_adata.obs.pubchem_cid
# Out:
# 3237298_10uM_6h - 679_6h           3237298
# 3237298_3_3333uM_6h - 679_6h       3237298
# 3237298_1_1111uM_6h - 679_6h       3237298
# 3237298_0_3704uM_6h - 679_6h       3237298
# 16307489_10uM_6h - 679_6h         16307489
#                                     ...
# 5311181_0_3704uM_24h - 679_24h     5311181
# 6376322_3_3333uM_24h - 679_24h     6376322
# 6376322_10uM_24h - 679_24h         6376322
# 6376322_1_1111uM_24h - 679_24h     6376322
# 6376322_0_3704uM_24h - 679_24h     6376322
# Name: pubchem_cid, Length: 315, dtype: category
# Categories (41, object): ['679', '5691', '27924', '30323', ..., '25405916', '25529404', '46902718', '51360697']

# %%
AnnData object with n_obs × n_vars = 315 × 978
    obs: 'id', 'plate', 'well', 'cell_type', 'perturbagen', 'pert_type', 'is_control', 'pert_dose_uM', 'pert_time_h', 'suspension_type', 'tissue', 'tissue_type', 'disease', 'library', 'stimulation', 'guide', 'dataset', 'assay', 'development_stage', 'organism', 'sex', 'self_reported_ethnicity', 'pubchem_cid', 'psbulk_cells', 'psbulk_counts', 'perturbagen_name', 'perturbation_label', 'processing_batch'
    var: 'symbol', 'is_merged'
    uns: 'qc_filtering_enabled', 'threshold_filter_cells'
    layers: 'AveExpr', 'B', 'CI.L', 'CI.R', 'P.Value', 'adj.P.Value.across_all_contrasts', 'adj.P.Value.within_one_contrast', 'logFC', 'stdev.scaled', 'stdev.unscaled', 't'

# %%
CVCL_0002_de_adata.obs
# Out:
#                                  id                     plate well  cell_type  \
# 3237298_10uM_6h - 679_6h          1   AML001_HL60_6H_X1_F1B10  I03  CVCL_0002
# 3237298_3_3333uM_6h - 679_6h      2   AML001_HL60_6H_X1_F1B10  I04  CVCL_0002
# 3237298_1_1111uM_6h - 679_6h      3   AML001_HL60_6H_X1_F1B10  J03  CVCL_0002
# 3237298_0_3704uM_6h - 679_6h      4   AML001_HL60_6H_X1_F1B10  J04  CVCL_0002
# 16307489_10uM_6h - 679_6h         5   AML001_HL60_6H_X1_F1B10  G03  CVCL_0002
# ...                             ...                       ...  ...        ...
# 5311181_0_3704uM_24h - 679_24h  311  AML001_HL60_24H_X1_F1B10  J24  CVCL_0002
# 6376322_3_3333uM_24h - 679_24h  312  AML001_HL60_24H_X1_F1B10  E06  CVCL_0002
# 6376322_10uM_24h - 679_24h      313  AML001_HL60_24H_X1_F1B10  E17  CVCL_0002
# 6376322_1_1111uM_24h - 679_24h  314  AML001_HL60_24H_X1_F1B10  F05  CVCL_0002
# 6376322_0_3704uM_24h - 679_24h  315  AML001_HL60_24H_X1_F1B10  F06  CVCL_0002
#
# ...

# %%
# Out:
# AnnData object with n_obs × n_vars = 315 × 978
#     obs: 'id', 'plate', 'well', 'cell_type', 'perturbagen', 'pert_type', 'is_control', 'pert_dose_uM', 'pert_time_h', 'suspension_type', 'tissue', 'tissue_type', 'disease', 'library', 'stimulation', 'guide', 'dataset', 'assay', 'development_stage', 'organism', 'sex', 'self_reported_ethnicity', 'pubchem_cid', 'psbulk_cells', 'psbulk_counts', 'perturbagen_name', 'perturbation_label', 'processing_batch'
#     var: 'symbol', 'is_merged'
#     uns: 'qc_filtering_enabled', 'threshold_filter_cells'
#     layers: 'AveExpr', 'B', 'CI.L', 'CI.R', 'P.Value', 'adj.P.Value.across_all_contrasts', 'adj.P.Value.within_one_contrast', 'logFC', 'stdev.scaled', 'stdev.unscaled', 't'

# %%
# Out:
# AnnData object with n_obs × n_vars = 315 × 978
#     obs: 'id', 'plate', 'well', 'cell_type', 'perturbagen', 'pert_type', 'is_control', 'pert_dose_uM', 'pert_time_h', 'suspension_type', 'tissue', 'tissue_type', 'disease', 'library', 'stimulation', 'guide', 'dataset', 'assay', 'development_stage', 'organism', 'sex', 'self_reported_ethnicity', 'pubchem_cid', 'psbulk_cells', 'psbulk_counts', 'perturbagen_name', 'perturbation_label', 'processing_batch'
#     var: 'symbol', 'is_merged'
#     uns: 'qc_filtering_enabled', 'threshold_filter_cells'
#     layers: 'AveExpr', 'B', 'CI.L', 'CI.R', 'P.Value', 'adj.P.Value.across_all_contrasts', 'adj.P.Value.within_one_contrast', 'logFC', 'stdev.scaled', 'stdev.unscaled', 't'

# %%
# Out:
# AnnData object with n_obs × n_vars = 315 × 978
#     obs: 'id', 'plate', 'well', 'cell_type', 'perturbagen', 'pert_type', 'is_control', 'pert_dose_uM', 'pert_time_h', 'suspension_type', 'tissue', 'tissue_type', 'disease', 'library', 'stimulation', 'guide', 'dataset', 'assay', 'development_stage', 'organism', 'sex', 'self_reported_ethnicity', 'pubchem_cid', 'psbulk_cells', 'psbulk_counts', 'perturbagen_name', 'perturbation_label', 'processing_batch'
#     var: 'symbol', 'is_merged'
#     uns: 'qc_filtering_enabled', 'threshold_filter_cells'
#     layers: 'AveExpr', 'B', 'CI.L', 'CI.R', 'P.Value', 'adj.P.Value.across_all_contrasts', 'adj.P.Value.within_one_contrast', 'logFC', 'stdev.scaled', 'stdev.unscaled', 't'

# %%
# Out:
# AnnData object with n_obs × n_vars = 315 × 978
#     obs: 'id', 'plate', 'well', 'cell_type', 'perturbagen', 'pert_type', 'is_control', 'pert_dose_uM', 'pert_time_h', 'suspension_type', 'tissue', 'tissue_type', 'disease', 'library', 'stimulation', 'guide', 'dataset', 'assay', 'development_stage', 'organism', 'sex', 'self_reported_ethnicity', 'pubchem_cid', 'psbulk_cells', 'psbulk_counts', 'perturbagen_name', 'perturbation_label', 'processing_batch'
#     var: 'symbol', 'is_merged'
#     uns: 'qc_filtering_enabled', 'threshold_filter_cells'
#     layers: 'AveExpr', 'B', 'CI.L', 'CI.R', 'P.Value', 'adj.P.Value.across_all_contrasts', 'adj.P.Value.within_one_contrast', 'logFC', 'stdev.scaled', 'stdev.unscaled', 't'

# %%
# Out:
# AnnData object with n_obs × n_vars = 315 × 978
#     obs: 'id', 'plate', 'well', 'cell_type', 'perturbagen', 'pert_type', 'is_control', 'pert_dose_uM', 'pert_time_h', 'suspension_type', 'tissue', 'tissue_type', 'disease', 'library', 'stimulation', 'guide', 'dataset', 'assay', 'development_stage', 'organism', 'sex', 'self_reported_ethnicity', 'pubchem_cid', 'psbulk_cells', 'psbulk_counts', 'perturbagen_name', 'perturbation_label', 'processing_batch'
#     var: 'symbol', 'is_merged'
#     uns: 'qc_filtering_enabled', 'threshold_filter_cells'
#     layers: 'AveExpr', 'B', 'CI.L', 'CI.R', 'P.Value', 'adj.P.Value.across_all_contrasts', 'adj.P.Value.within_one_contrast', 'logFC', 'stdev.scaled', 'stdev.unscaled', 't'

# %%
# Out:
# AnnData object with n_obs × n_vars = 315 × 978
#     obs: 'id', 'plate', 'well', 'cell_type', 'perturbagen', 'pert_type', 'is_control', 'pert_dose_uM', 'pert_time_h', 'suspension_type', 'tissue', 'tissue_type', 'disease', 'library', 'stimulation', 'guide', 'dataset', 'assay', 'development_stage', 'organism', 'sex', 'self_reported_ethnicity', 'pubchem_cid', 'psbulk_cells', 'psbulk_counts', 'perturbagen_name', 'perturbation_label', 'processing_batch'
#     var: 'symbol', 'is_merged'
#     uns: 'qc_filtering_enabled', 'threshold_filter_cells'
#     layers: 'AveExpr', 'B', 'CI.L', 'CI.R', 'P.Value', 'adj.P.Value.across_all_contrasts', 'adj.P.Value.within_one_contrast', 'logFC', 'stdev.scaled', 'stdev.unscaled', 't'

# %%
# Out:
# AnnData object with n_obs × n_vars = 315 × 978
#     obs: 'id', 'plate', 'well', 'cell_type', 'perturbagen', 'pert_type', 'is_control', 'pert_dose_uM', 'pert_time_h', 'suspension_type', 'tissue', 'tissue_type', 'disease', 'library', 'stimulation', 'guide', 'dataset', 'assay', 'development_stage', 'organism', 'sex', 'self_reported_ethnicity', 'pubchem_cid', 'psbulk_cells', 'psbulk_counts', 'perturbagen_name', 'perturbation_label', 'processing_batch'
#     var: 'symbol', 'is_merged'
#     uns: 'qc_filtering_enabled', 'threshold_filter_cells'
#     layers: 'AveExpr', 'B', 'CI.L', 'CI.R', 'P.Value', 'adj.P.Value.across_all_contrasts', 'adj.P.Value.within_one_contrast', 'logFC', 'stdev.scaled', 'stdev.unscaled', 't'

# %%
# Out:
# AnnData object with n_obs × n_vars = 315 × 978
#     obs: 'id', 'plate', 'well', 'cell_type', 'perturbagen', 'pert_type', 'is_control', 'pert_dose_uM', 'pert_time_h', 'suspension_type', 'tissue', 'tissue_type', 'disease', 'library', 'stimulation', 'guide', 'dataset', 'assay', 'development_stage', 'organism', 'sex', 'self_reported_ethnicity', 'pubchem_cid', 'psbulk_cells', 'psbulk_counts', 'perturbagen_name', 'perturbation_label', 'processing_batch'
#     var: 'symbol', 'is_merged'
#     uns: 'qc_filtering_enabled', 'threshold_filter_cells'
#     layers: 'AveExpr', 'B', 'CI.L', 'CI.R', 'P.Value', 'adj.P.Value.across_all_contrasts', 'adj.P.Value.within_one_contrast', 'logFC', 'stdev.scaled', 'stdev.unscaled', 't'
